# %% [markdown]
# # 3REQ system
#
# Requirement analysis system.
#
# The flow is presented in the following figure:
#
# <img src="flow.png" alt="drawing" width="700"/>
#
# Summary:
# 1. Extract sections that contain words like "latency"
# 2. Find if they resemble requirements or not
# 3. Check if they are specific kinds of requirements (like signalling)
# 4. Write new requirements based on the text in these sections.

# %%
# Importing required libraries

# docx2python is used to extract text, images, tables, and other data from .docx files
from docx2python import docx2python

# os module provides functions for interacting with the operating system
import os

# numpy is used for mathematical operations on large, multi-dimensional arrays and matrices
import numpy as np

# pandas is used for data manipulation and analysis
import pandas as pd

# TSNE from sklearn.manifold is used for dimensionality reduction
from sklearn.manifold import TSNE

# matplotlib.pyplot is used for creating static, animated, and interactive visualizations in Python
import matplotlib.pyplot as plt

# SentenceTransformer is used for training and using transformer models for generating sentence embeddings
from sentence_transformers import SentenceTransformer

# tqdm is used to make loops show a smart progress meter
from tqdm import tqdm

# torch is the main package in PyTorch, it provides a multi-dimensional array with support for autograd operations like backward()
import torch

# AutoModelForCausalLM, AutoTokenizer, pipeline are from the transformers library by Hugging Face which provides state-of-the-art machine learning models like BERT, GPT-2, etc.
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# euclidean distance and cosine distance
from scipy.spatial import distance

# %%
# suppress warnings
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Step 1: List the documents's sections with "latency"
#
# In the first step, we go through the documents in the folder "input_standards" and we extract which sections of these documents contain th word "latency". We store the results in a dictionary.

# %%
def extractLatencySections(doc):
    strSectionTitle = ""
    dictSections = {}
    listLatency = []
    skippedSections = 0

    doc_result = docx2python(doc,paragraph_styles = True, html=True)

    # we iterate over all lines
    # look for the section titles (which have the tag <h1>, <h2>, <h3>, etc.)
    # then we add the content of each section to the dictionary
    # and if there is a word "latency" somewhere in the section, we add the section title to the listLatency
    for oneLine in tqdm(doc_result.text.split('\n')):
        if "<h" in oneLine:
            strSectionTitle = oneLine
            dictSections[strSectionTitle] = []

        if strSectionTitle != "":  
            dictSections[strSectionTitle].append(oneLine)

        keywordsInLine = ["latency", "latencies", "delay", "bandwidth"]
        keywordsInSections = ["references", "introduction", "definition", "abstract", "conclusion", "acknowledgements", "appendix", "table of contents", "table of figures", "table of tables", "table of contents", "table of figures", "table of tables", "bibliography", "index", "glossary", "list of figures", "list of tables", "list of abbreviations", "list of symbols", "list of terms", "list of equations", "list of algorithms", "list of acronyms", "list of illustrations", "list of appendices"]

        if any(word in oneLine.lower() for word in keywordsInLine) and not any(word in strSectionTitle.lower() for word in keywordsInSections): 
            listLatency.append(strSectionTitle)
        else:
            skippedSections += 1

            
    # remove the keys from the dictionary if they are not part of the listLatency
    # as we want to get only the relevant sections, i.e., the one with the word latency
    for key in list(dictSections.keys()):
        if key not in listLatency:
            del dictSections[key]

    # print("Skipped sections: ", skippedSections)

    # return the dictionary with the relevant sections
    return dictSections

# %%
docInputFolder = "./input_standards"

# this is the return list of all the lines in the document
lstAllLines = []

# for each .docx file in the input folder
# extract the sections with latency using the extractLatencySections function
# and print the sections
for doc in tqdm(os.listdir(docInputFolder)):    

    if doc.endswith(".docx"):
        #print(f"Processing {doc}")

        # since things can go wrong with the latency library, 
        # we use a try except block to avoid the program to stop
        try: 
            dictSections = extractLatencySections(os.path.join(docInputFolder, doc))
        
            # we list the content
            # as a long list of sections 
            for key in dictSections:

                lstOneLine = [key, doc]

                for line in dictSections[key]:
                    lstOneLine.append(line)
                    
                lstAllLines.append(lstOneLine)

        except Exception as e:
            print(f"Error with {doc}: {e}")
# Out:
# 100%|██████████| 13952/13952 [00:00<00:00, 376117.09it/s]
# 100%|██████████| 8165/8165 [00:00<00:00, 273606.40it/s]
# 100%|██████████| 8183/8183 [00:00<00:00, 228400.62it/s]
# 100%|██████████| 2001/2001 [00:00<00:00, 477026.39it/s]
# 100%|██████████| 17829/17829 [00:00<00:00, 371071.81it/s]
# 100%|██████████| 16594/16594 [00:00<00:00, 276092.98it/s]
# 100%|██████████| 16650/16650 [00:00<00:00, 374016.09it/s]
# 100%|██████████| 16666/16666 [00:00<00:00, 284988.53it/s]
# 100%|██████████| 3862/3862 [00:00<00:00, 284342.12it/s]
# 100%|██████████| 4047/4047 [00:00<00:00, 281395.65it/s]
# 100%|██████████| 15401/15401 [00:00<00:00, 133069.53it/s]
# 100%|██████████| 7526/7526 [00:00<00:00, 146357.25it/s]
# 100%|██████████| 4133/4133 [00:00<00:00, 80720.16it/s]
# 100%|██████████| 8896/8896 [00:00<00:00, 97953.20it/s]
# 100%|██████████| 21863/21863 [00:00<00:00, 185311.06it/s]
# 100%|██████████| 14778/14778 [00:00<00:00, 209009.45it/s]
# 100%|██████████| 21672/21672 [00:00<00:00, 368199.80it/s]
# 100%|██████████| 7348/7348 [00:00<00:00, 249312.37it/s]
# 100%|██████████| 4526/4526 [00:00<00:00, 182366.30it/s]
# 100%|██████████| 2440/2440 [00:00<00:00, 227550.90it/s]
# 100%|██████████| 4663/4663 [00:00<00:00, 316780.69it/s]
# 100%|██████████| 2135/2135 [00:00<00:00, 148413.73it/s]
# 100%|██████████| 8848/8848 [00:00<00:00, 227079.83it/s]
# 100%|██████████| 14094/14094 [00:00<00:00, 247151.85it/s]
# 100%|██████████| 6576/6576 [00:00<00:00, 305320.56it/s]
# 100%|██████████| 8303/8303 [00:00<00:00, 224049.17it/s]
# 100%|██████████| 8514/8514 [00:00<00:00, 291056.50it/s]
# 100%|██████████| 1544/1544 [00:00<00:00, 202173.00it/s]
# 100%|██████████| 2593/2593 [00:00<00:00, 311049.06it/s]
# 100%|██████████| 1494/1494 [00:00<00:00, 339176.73it/s]
# 100%|██████████| 1815/1815 [00:00<00:00, 185132.82it/s]
# 100%|██████████| 1866/1866 [00:00<00:00, 177332.53it/s]
# 100%|██████████| 14880/14880 [00:00<00:00, 267033.10it/s]
# 100%|██████████| 4378/4378 [00:00<00:00, 372113.05it/s]
# 100%|██████████| 8203/8203 [00:00<00:00, 215685.13it/s]
# 100%|██████████| 5600/5600 [00:00<00:00, 437729.04it/s]
# 100%|██████████| 8016/8016 [00:00<00:00, 240232.80it/s]
# 100%|██████████| 1726/1726 [00:00<00:00, 228898.37it/s]
# 100%|██████████| 97/97 [04:18<00:00,  2.67s/it]

# %%
# model = SentenceTransformer("all-MiniLM-L6-v2")
model = SentenceTransformer("sentence-t5-large")

# list with all embeddings for the sections
lstEmbeddings = []
iCounter = 0

for oneLine in tqdm(lstAllLines):

    # the content of the section starts on the third position of the list
    sentences = oneLine[3:]

    # Sentences are encoded by calling model.encode()
    embeddings = model.encode(sentences)
    
    # Print the average embeddings for all the sentences 
    # in this section
    avg_embeddings = embeddings.mean(axis=0)
    
    lstOneLine = [oneLine[0], oneLine[1], 2, str(sentences).replace("$", "_").replace("\n", "_"), avg_embeddings]

    lstEmbeddings.append(lstOneLine)

    iCounter += 1
    # the code below is for debug only
    # in case we want to stop the loop after a certain number of iterations
    #if iCounter == 100:
    #    break
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 model = SentenceTransformer("all-MiniLM-L6-v2")
#       2 #model = SentenceTransformer("sentence-t5-large")
#       3
#       4 # list with all embeddings for the sections
#       5 lstEmbeddings = []
#
# File /mnt/d/venvs/standards/lib/python3.11/site-packages/sentence_transformers/SentenceTransformer.py:214, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, cache_folder, trust_remote_code, revision, token, use_auth_token)
#     211     device = get_device_name()
#     212     logger.info("Use pytorch device_name: {}".format(device))
# --> 214 self.to(device)
#     216 if self.default_prompt_name is not None and self.default_prompt_name not in self.prompts:
#     217     raise ValueError(
#     218         f"Default prompt name '{self.default_prompt_name}' not found in the configured prompts "
#     219         f"dictionary with keys {list(self.prompts.keys())!r}."
#     220     )
#
# File /mnt/d/venvs/standards/lib/python3.11/site-packages/torch/nn/modules/module.py:1173, in Module.to(self, *args, **kwargs)
#    1170         else:
#    1171             raise
# -> 1173 return self._apply(convert)
#
# File /mnt/d/venvs/standards/lib/python3.11/site-packages/torch/nn/modules/module.py:779, in Module._apply(self, fn, recurse)
#     777 if recurse:
#     778     for module in self.children():
# --> 779         module._apply(fn)
#     781 def compute_should_use_set_data(tensor, tensor_applied):
#     782     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     783         # If the new tensor has compatible tensor type as the existing tensor,
#     784         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     789         # global flag to let the user control whether they want the future
#     790         # behavior of overwriting the existing tensor or not.
#
# File /mnt/d/venvs/standards/lib/python3.11/site-packages/torch/nn/modules/module.py:779, in Module._apply(self, fn, recurse)
#     777 if recurse:
#     778     for module in self.children():
# --> 779         module._apply(fn)
#     781 def compute_should_use_set_data(tensor, tensor_applied):
#     782     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     783         # If the new tensor has compatible tensor type as the existing tensor,
#     784         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     789         # global flag to let the user control whether they want the future
#     790         # behavior of overwriting the existing tensor or not.
#
#     [... skipping similar frames: Module._apply at line 779 (1 times)]
#
# File /mnt/d/venvs/standards/lib/python3.11/site-packages/torch/nn/modules/module.py:779, in Module._apply(self, fn, recurse)
#     777 if recurse:
#     778     for module in self.children():
# --> 779         module._apply(fn)
#     781 def compute_should_use_set_data(tensor, tensor_applied):
#     782     if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     783         # If the new tensor has compatible tensor type as the existing tensor,
#     784         # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     789         # global flag to let the user control whether they want the future
#     790         # behavior of overwriting the existing tensor or not.
#
# File /mnt/d/venvs/standards/lib/python3.11/site-packages/torch/nn/modules/module.py:804, in Module._apply(self, fn, recurse)
#     800 # Tensors stored in modules are graph leaves, and we don't want to
#     801 # track autograd history of `param_applied`, so we have to use
#     802 # `with torch.no_grad():`
#     803 with torch.no_grad():
# --> 804     param_applied = fn(param)
#     805 p_should_use_set_data = compute_should_use_set_data(param, param_applied)
#     807 # subclasses may have multiple child tensors so we need to use swap_tensors
#
# File /mnt/d/venvs/standards/lib/python3.11/site-packages/torch/nn/modules/module.py:1159, in Module.to.<locals>.convert(t)
#    1152     if convert_to_format is not None and t.dim() in (4, 5):
#    1153         return t.to(
#    1154             device,
#    1155             dtype if t.is_floating_point() or t.is_complex() else None,
#    1156             non_blocking,
#    1157             memory_format=convert_to_format,
#    1158         )
# -> 1159     return t.to(
#    1160         device,
#    1161         dtype if t.is_floating_point() or t.is_complex() else None,
#    1162         non_blocking,
#    1163     )
#    1164 except NotImplementedError as e:
#    1165     if str(e) == "Cannot copy out of meta tensor; no data!":
#
# RuntimeError: CUDA error: unknown error
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
# let's plot these average embeddings using t-SNE

# we create a list with the embeddings
lstEmbeddingsNP = np.array([x[4] for x in lstEmbeddings])

# we use t-SNE to reduce the dimensionality of the embeddings
tsne = TSNE(n_components=2, verbose=0, perplexity=12, n_iter=300)
tsne_results = tsne.fit_transform(lstEmbeddingsNP)

# we plot the t-SNE results
plt.figure(figsize=(16,10))

plt.scatter(tsne_results[:,0], tsne_results[:,1])

# Add labels to each dot
for i, label in enumerate([x[0] for x in lstEmbeddings]):
    plt.text(tsne_results[i, 0], tsne_results[i, 1], label[3:10])


plt.show()

# %% [markdown]
# ## Step 2: Find the relevant sections
#
# In this step, we take the sections identified in Step 1 and we compare them to a list of right and wrong requirements. The list is stored in the file List.xlsx

# %%
# open the file List.xlsx using pandas
# and read the workshop NR
df = pd.read_excel("List.xlsx", sheet_name="R_NR")

# convert the dataframe to a list of lists
lstReference = df.values.tolist()

lstReference[0]
# Out:
# ['The 5G system shall support an end-to-end latency of less than 5 ms or 10 ms, as requested by the UE initiating the communication.',
#  1]

# %%
# list with all embeddings for the sections
lstEmbeddingsRef = []

for oneLine in tqdm(lstReference):

    # the content of the section starts on the third position of the list
    sentences = oneLine[0]

    # Sentences are encoded by calling model.encode()
    embeddings = model.encode(sentences)
    
    # Print the average embeddings for all the sentences 
    # in this section
    avg_embedding = embeddings
    
    lstOneLine = [oneLine[0], 'REF', oneLine[1], oneLine[1], avg_embedding]

    lstEmbeddingsRef.append(lstOneLine)
# Out:
# 100%|██████████| 19/19 [00:00<00:00, 23.68it/s]

# %%
# concatenate the two lists
lstEmbeddingsAll = lstEmbeddings + lstEmbeddingsRef

# %%
# let's plot these average embeddings using t-SNE

# we create a list with the embeddings
lstEmbeddingsNP = np.array([x[4] for x in lstEmbeddingsAll])

# we use t-SNE to reduce the dimensionality of the embeddings
tsne = TSNE(n_components=2, verbose=0, perplexity=12, n_iter=300)
tsne_results = tsne.fit_transform(lstEmbeddingsNP)

# Create a color map based on x[2]
color_map = {0: 'red', 1: 'green', 2: 'blue'}
colors = [color_map[x[2]] for x in lstEmbeddingsAll]

# we plot the t-SNE results
plt.figure(figsize=(16,10))

plt.scatter(tsne_results[:,0], tsne_results[:,1],c=colors, s=100, alpha=0.5)

# Add labels to each dot
for i, label in enumerate([x[0] for x in lstEmbeddingsAll]):
    plt.text(tsne_results[i, 0], tsne_results[i, 1], label[:10]+'...')


plt.show()

# %%
from sklearn.metrics.pairwise import euclidean_distances

# for each line in lstEmbeddings
# we calculate the euclidean distance with each line in lstEmbeddingsRef

lstDistPos = []
lstDistNeg = []

lstRelevant = []

for oneLine in tqdm(lstEmbeddings):    
    for oneLineRef in lstEmbeddingsRef:
        if oneLineRef[2] == 1:
            # euclidean distance between the two embeddings
            dist = distance.cosine(oneLine[4], oneLineRef[4])
            lstDistPos.append(dist)
        if oneLineRef[2] == 0:
            # euclidean distance between the two embeddings
            dist = distance.cosine(oneLine[4], oneLineRef[4])
            lstDistNeg.append(dist)
    
    # now calculate the average for both lists
    avgDistPos = np.mean(lstDistPos)
    avgDistNeg = np.mean(lstDistNeg)

    if avgDistPos < avgDistNeg:
        #print(f"Section {oneLine[0]} is relevant")
        # add the class to the list
        oneLine.append(1)
        lstRelevant.append(oneLine)
    else:
        #print(f"Section {oneLine[0]} is not relevant")
        # add the class to the list
        oneLine.append(0)
# Out:
# 100%|██████████| 95/95 [00:00<00:00, 3216.41it/s]

# %%
print(f'Relevant sections: {len(lstRelevant)}')
# Out:
# Relevant sections: 95

# %%
lstEmbeddings[0]
# Out:
# ['<h3>4.2.2\tMobile Terminated Short Message</h3>',
#  '23007-i20.docx',
#  2,
#  '[\'\', \'a)\\tSend Routing Information for MT SMS (SMS-GMSC-&gt;HLR):\', \'\', \'\\tThe HLR returns the MSC number as for normal operation.\', \'\', \'b)\\tSend Information for MT SMS (MSC-&gt;VLR) - MAP version 2:\', \'\', \'-\\tIf the VLR has no IMSI record, or if the record is marked "Subscriber Data Not Confirmed by HLR", the VLR proceeds as follows:\', \'\', \'-\\tthe VLR returns an "Unidentified Subscriber" error. This causes the MSC to report a short message delivery failure, with cause "Unidentified Subscriber", to the SMS gateway MSC. The Gateway MSC sends a "Report SM Delivery Status" request, with a cause of "Absent Subscriber", to the HLR. This causes the HLR to set the "Mobile Station Not Reachable Flag" for the MS, as described in Technical Specifications 3GPP\\xa0TS\\xa023.040\\xa0[4] and 3GPP\\xa0TS\\xa029.002\\xa0[6]; or\', \'\', \'-\\tthe VLR performs the data restoration procedure as specified in clause\\xa04.2.1 for an incoming call and delay the mobile terminating SMS until the data restoration procedure is complete. During the data restoration procedure, the HLR shall send to the VLR the MME name or/and the SGSN Number if the subscriber is registered on this VLR and is registered to EPS or/and GPRS services respectively.\', \'\', \'-\\tIf the VLR has an IMSI record marked "Subscriber Data Confirmed by HLR" and "Not Confirmed by Radio Contact", the VLR handles the request in the normal way, except that the "Search for MS" procedure is used instead of the "Page MS" procedure.\', \'\', \'-\\tIf the VLR has an IMSI record marked "Subscriber Data Confirmed by HLR" and "Confirmed by Radio Contact", the VLR handles the request in the normal way; for this MS, VLR restoration is complete.\', \'\', \'-\\tThe state of the indicator "Location Information Confirmed in HLR" does not affect the "Send Information for MT SMS" procedure.\', \'\', \'c)\\tSend Information for I/C Call Setup (MSC-&gt;VLR) - MAP version\\xa01:\', \'\', \'-\\tIf the VLR has no IMSI record, or if the record is marked "Subscriber Data Not Confirmed by HLR", the VLR proceeds as follows:\', \'\', \'-\\tthe VLR returns a "System Failure" error. This causes the MSC to report a short message delivery failure, with cause "System Failure", to the SMS gateway MSC; or\', \'\', \'-\\tthe VLR performs the data restoration procedure as specified in clause\\xa04.2.1 for an incoming call and delay the mobile terminating SMS until the data restoration procedure is complete. During the data restoration procedure, the HLR shall send to the VLR the MME name or/and the SGSN Number if the subscriber is registered on this VLR and is registered to EPS or/and GPRS services respectively.\', \'\', \'-\\tIf the VLR has an IMSI record marked "Subscriber Data Confirmed by HLR" and "Not Confirmed by Radio Contact", the VLR handles the request in the normal way, except that the "Search for MS" procedure is used instead of the "Page MS" procedure.\', \'\', \'-\\tIf the VLR has an IMSI record marked "Subscriber Data Confirmed by HLR" and "Confirmed by Radio Contact", the VLR handles the request in the normal way; for this MS, VLR restoration is complete.\', \'\', \'-\\tThe state of the indicator "Location Information Confirmed in HLR" does not affect the "Send Information for MT SMS" procedure.\', \'\', \'d)\\tProcess Access Request in Response to Search (MSC-&gt;VLR):\', \'\', \'-\\tIf the MS responds to paging, the MSC sends a positive response to the search request and a "Process Access Request" to the VLR. After successful authentication, if required, the VLR sets the indicator "Confirmed by Radio Contact" to "Confirmed", sets the location area information for the MS, and handles the request in the normal way.\', \'\', \'-\\tThe VLR checks the indicator "Location Information Confirmed in HLR". If it indicates "Not Confirmed" the VLR starts an "Update Location" procedure to the HLR. When this procedure is successfully completed, the VLR sets the indicator "Location Informa ...
#  array([-3.09961736e-02, -5.91633515e-03,  3.10866139e-03,  1.88437440e-02,
#          3.24106961e-02,  2.13680789e-02, -1.91570502e-02,  8.22440069e-03,
#         -1.50729427e-02,  3.53935435e-02,  5.05445413e-02, -2.53182855e-02,
#          3.81041132e-02,  3.79193760e-02, -2.91210916e-02,  8.85885768e-03,
#         -2.05919538e-02,  4.25796304e-03, -3.00475489e-02,  4.59089223e-03,
#          3.81443612e-02, -1.09772831e-02, -1.99948270e-02,  2.75051277e-02,
#         -8.01682845e-03,  2.39905976e-02, -4.35364479e-03,  1.19209690e-02,
#          5.25820889e-02, -3.83473225e-02,  2.23684423e-02, -4.32819910e-02,
#         -5.40042259e-02, -2.90119592e-02, -2.64827581e-03,  1.12118607e-03,
#          1.93034615e-02, -7.75934523e-03, -1.37276361e-02,  4.47418354e-02,
#         -6.10137451e-03,  1.28586302e-02,  2.54720505e-02, -3.71033028e-02,
#          4.15748209e-02, -1.60680208e-02, -3.47261466e-02, -3.27738188e-02,
#          4.48338408e-03, -4.25080024e-02, -3.20428014e-02, -5.55331595e-02,
#         -2.64826510e-02, -9.29185096e-03,  8.75326339e-03, -3.81984673e-02,
#         -3.62576582e-02,  6.01357548e-03,  5.58193401e-02, -2.90056095e-02,
#         -3.76211368e-02,  2.01641843e-02, -6.84297979e-02,  1.99645907e-02,
#          1.30622080e-02, -4.37933430e-02,  4.04101275e-02, -5.14036864e-02,
#          1.93487573e-02, -2.52646282e-02,  2.78812349e-02, -2.07284130e-02,
#          6.53138533e-02, -4.28243838e-02, -7.58209229e-02,  6.73692897e-02,
#         -4.90545575e-03, -7.78384805e-02,  3.04342192e-02,  1.06684351e-02,
#          1.42588876e-02,  2.44901981e-02,  7.22456723e-03, -4.50717881e-02,
#          6.98295422e-03, -6.78869933e-02,  4.35243845e-02, -4.26344089e-02,
#         -1.52079677e-02,  1.74732450e-02,  2.97546806e-03, -5.39062638e-03,
#          5.53189106e-02,  1.20990991e-03,  3.31788957e-02,  3.53619643e-02,
#         -3.10698766e-02, -6.71549141e-02,  2.13577040e-02,  2.94558499e-02,
#          7.17113260e-03, -2.31764205e-02, -3.46001424e-02, -5.10921748e-03,
#          1.01454947e-02, -1.00029185e-02, -4.15191539e-02,  2.03653686e-02,
#          7.39692198e-03, -6.54933527e-02, -1.28899822e-02,  2.70603560e-02,
#         -1.03507109e-03, -2.47932784e-02,  1.88524127e-02,  1.78892631e-02,
#          1.64293796e-02,  2.96092667e-02,  2.44290717e-02,  1.79110561e-02,
#         -5.54043390e-02, -1.85662955e-02,  1.01697827e-02,  7.71420775e-03,
#          4.67847921e-02, -3.12773734e-02,  2.96880901e-02,  4.23170328e-02,
#          1.61455628e-02,  4.18166444e-02, -3.35872024e-02, -2.56510805e-02,
#          1.59480833e-02, -3.46502922e-02,  2.25243680e-02, -2.74058208e-02,
#         -4.01523970e-02, -1.50972232e-02, -1.80169549e-02, -1.85713954e-02,
#          3.46391723e-02, -2.87343003e-02,  1.92805603e-02,  3.89175192e-02,
#          3.49919572e-02, -5.75221553e-02, -6.12437464e-02, -2.62261871e-02,
#         -2.29345635e-02,  2.93429755e-02,  2.51355805e-02, -3.15313898e-02,
#         -1.28510436e-02, -3.13861296e-02, -1.53910369e-02,  6.51742741e-02,
#         -1.69704892e-02, -5.24586514e-02,  5.02262637e-02,  5.78834489e-02,
#         -4.42224331e-02,  1.12545341e-02,  5.60894422e-02, -3.33802290e-02,
#          4.30254936e-02,  2.75733657e-02,  2.23364495e-02,  3.17035951e-02,
#          4.23274450e-02, -2.29030531e-02, -3.06579489e-02, -5.53653203e-02,
#         -2.33512186e-02, -1.64491069e-02,  5.71636949e-03,  5.17467447e-02],
#        dtype=float32),
#  1]

# %%
# here we save all the relevant sections to an Excel file
# and the non-relevant ones too
import pandas as pd

dfOutput = pd.DataFrame(lstEmbeddings, columns=["Section", "Document", "Class", "Content", "Embedding", "Relevance"])

dfOutput.to_excel("./output.xlsx", index=False)

# %% [markdown]
# ## Step 3: Find which requirements are impacted
#
# In this step, we compare the relevant sections with the existing requirements. Based on the distance, we can determine which requirements are impacted. The requirements are provided as a separete list.

# %%
print(f'Percentage relevant: {len(lstRelevant)/len(lstEmbeddings)*100:.2f}%')
# Out:
# Percentage relevant: 100.00%

# %%
# read the requirements from the excel file requirements.xlsx, worksheet LR
df = pd.read_excel("List.xlsx", sheet_name="LR")

# convert to list
lstRequirements = df.values.tolist()
lstRequirements[0]

# now we calculate the embeddings for each of these requirements
lstEmbeddingsReq = []

for oneLine in tqdm(lstRequirements):
    
        # the content of the section starts on the third position of the list
        sentences = oneLine[1]
    
        # Sentences are encoded by calling model.encode()
        embeddings = model.encode(sentences)
        
        # Print the average embeddings for all the sentences 
        # in this section
        avg_embedding = embeddings
        
        lstOneLine = [oneLine[0], 'latency', oneLine[1], oneLine[1], avg_embedding]
    
        lstEmbeddingsReq.append(lstOneLine)
# Out:
# 100%|██████████| 38/38 [00:01<00:00, 25.39it/s]

# %%
# now we calculate the euclidean distance between the requirements and the sections
# that are relevant
lstDist = []
lstRelevantDist = []

for oneLine in tqdm(lstRelevant):
    for oneLineReq in lstEmbeddingsReq:
        # euclidean distance between the two embeddings
        dist = distance.cosine(oneLine[4], oneLineReq[4])
        lstDist.append([oneLine[0], oneLine[1], oneLineReq[0], dist, oneLine[3]])

# now we sort the list by the distance
lstDist.sort(key=lambda x: x[2])

# and we print them
for i in range(len(lstDist)):
    print(f"Section {lstDist[i][0]} is close to requirement {lstDist[i][2]} with distance {lstDist[i][3]:.2f}")
    # add this to a list
    lstRelevantDist.append([lstDist[i][0], lstDist[i][1], lstDist[i][2], lstDist[i][3], lstDist[i][4]])

# save the list to an Excel file
dfOutput = pd.DataFrame(lstRelevantDist, columns=["Section", "Document", "Requirement", "Distance", "Content"])

# sort it by section and document
dfOutput = dfOutput.sort_values(by=["Section", "Document"])

dfOutput.to_excel("./output_requirements_distances_b.xlsx", index=False)
# Out:
# 100%|██████████| 95/95 [00:00<00:00, 2646.65it/s]
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>25.2.1	General</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR1_signalling with distance 0.22
# Section <h3>31.6.1	General</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR1_signalling with distance 0.28
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>25.2.1	General</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR1_signalling with distance 0.22
# Section <h3>31.6.1	General</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR1_signalling with distance 0.28
# Section <h1>C.8	Stage-2 flow for providing UE with list of preferred PLMN/access technology combinations in SNPN after registration</h1> is close to requirement LR1_signalling with distance 0.29
# Section <h1>C.8	Stage-2 flow for providing UE with list of preferred PLMN/access technology combinations in SNPN after registration</h1> is close to requirement LR1_signalling with distance 0.29
# Section <h1>C.8	Stage-2 flow for providing UE with list of preferred PLMN/access technology combinations in SNPN after registration</h1> is close to requirement LR1_signalling with distance 0.29
# Section <h3>4.2.5	The QoS requirements for an IM CN subsystem session</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>5.4.4	Requirements for IP multi-media session control</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h4>5.4.6.1	Objectives</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h3>5.4.8	QoS-Assured Preconditions</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h3>5.6.4	(NI-O) Non-IMS Origination procedure from an external SIP client</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>5.7a.2	Procedures for the establishment of sessions without preconditions - no resource reservation required before session becomes active</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h4>5.11.3.0	General</h4> is close to requirement LR1_signalling with distance 0.26
# Section <h4>5.11.3.1	Codec and media characteristics flow negotiation during initial session establishment</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>5.11.3.3	Codec or media characteristics flow change requiring new resources and/or authorization</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>5.11.3.4	Sample MM session flow - addition of another media</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h3>5.19.1	General</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h2>G.1.1	General requirements</h2> is close to requirement LR1_signalling with distance 0.25
# Section <h2>G.3.1	Required functions of the PCSCF</h2> is close to requirement LR1_signalling with distance 0.23
# Section <h2>G.3.2	Required functions of the IMS Access Gateway</h2> is close to requirement LR1_signalling with distance 0.24
# Section <h3>G.5.2.2	Required functions of the UE</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h2>G.6.5	Policy and Charging Control procedures</h2> is close to requirement LR1_signalling with distance 0.23
# Section <h1>Q.1	General</h1> is close to requirement LR1_signalling with distance 0.23
# Section <h3>AA.4.1.1	General</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>AC.7.4.2	DCMF Registration and Discovery</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h2>6.14	MBS Service Information</h2> is close to requirement LR1_signalling with distance 0.22
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR1_signalling with distance 0.21
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR1_signalling with distance 0.22
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h1>B.1	LCS privacy selection flow rule</h1> is close to requirement LR1_signalling with distance 0.29
# Section <h4>5.2.9.2	PLMN utilisation</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>5.2.9.3	SIP core / IMS utilisation</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>5.2.10.2	Connectivity</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h3>10.3.1	General</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h4>10.3.2.3	Pre-established session modification</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>10.7.2.4	Discover bearer request</h4> is close to requirement LR1_signalling with distance 0.25
# Section <h4>10.7.2.6	Media distribution request</h4> is close to requirement LR1_signalling with distance 0.25
# Section <h4>10.7.2.7	Media distribution response</h4> is close to requirement LR1_signalling with distance 0.25
# Section <h4>10.7.2.10	Media distribution release</h4> is close to requirement LR1_signalling with distance 0.25
# Section <h6>10.7.3.9.2.1	MBMS bearer coordination independent on broadcasted media</h6> is close to requirement LR1_signalling with distance 0.23
# Section <h6>10.7.3.9.2.2	MBMS bearer coordination within one group call</h6> is close to requirement LR1_signalling with distance 0.23
# Section <h5>10.7.3.11.1	General</h5> is close to requirement LR1_signalling with distance 0.21
# Section <h5>10.7.3.11.2	FEC encoding by the BM-SC</h5> is close to requirement LR1_signalling with distance 0.23
# Section <h3>10.11.2	Request for unicast resources at session establishment</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h4>10.11.2a.1	General</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>10.11.6.1	General</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>10.11.6.2	Procedure</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h3>7.17.1	General</h3> is close to requirement LR1_signalling with distance 0.25
# Section <h4>7.17.3.1	MCVideo adaptation during group communication procedure – transmitting client triggered</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h5>7.5.2.10.2	Procedure</h5> is close to requirement LR1_signalling with distance 0.23
# Section <h4>5.2.2.2	V2X message reception via MBS</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>5.2.3.1	General</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h5>5.4.1.1.2	Deriving PC5 QoS parameters and assigning PFI for PC5 QoS Flow</h5> is close to requirement LR1_signalling with distance 0.21
# Section <h4>5.4.3.1	General</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>5.4.3.3	Priority Level</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>5.4.3.4	Packet Delay Budget</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h3>5.4.4	Standardized PQI to QoS characteristics mapping</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h4>5.4.5.1	General</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>5.4.5.3	QoS Change based on Extended NG-RAN Notification to support Alternative Service Requirements</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h3>6.1.3	Contents of Analytics Exposure</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h4>6.1A.3.1	Procedure for analytics aggregation with Provision of Area of Interest</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>6.1A.3.2	Procedure for Analytics Aggregation without Provision of Area of Interest</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>6.2C.2.2	General procedure for Federated Learning among Multiple NWDAF Instances</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.2F.2	Contents of ML Model Training</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.4.2	Input Data</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.6.1	General</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.6.3	Output Analytics</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.8.2	Input data</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h3>6.9.1	General</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>6.9.2	Input data</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h4>6.9.4.2	Procedure for QoS Sustainability in a fine granularity area</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>6.10.3.1	Data Volume Dispersion Analytics</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h3>6.13.1	General</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.13.2	Input Data</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h3>6.13.3	Output Analytics</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.14.1	General</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h3>6.14.2	Input Data</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.14.3	Output Analytics</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.18.1	General</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>6.18.2	Input Data</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>7.10.4	Nnwdaf_MLModelTraining_Notify service operation</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h3>7.11.2	Nnwdaf_MLModelTrainingInfo_Request service operation</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.24
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.18
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.24
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.16
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.24
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.17
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.25
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.18
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.17
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.17
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.18
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.23
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.21
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.20
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.20
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.20
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.22
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.21
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.20
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.21
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.21
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.22
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.19
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.21
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.21
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.21
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.20
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.22
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.22
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.18
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.19
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.21
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.21
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.22
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.17
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.16
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.18
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.20
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.21
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.20
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.19
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.25
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.18
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.18
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>31.6.1	General</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.28
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.28
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.27
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.27
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.28
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.28
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.28
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.27
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.28
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.27
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.28
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.26
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.27
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.27
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.28
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.26
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.29
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.28
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.25
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.26
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.27
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.26
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.28
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.25
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.25
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.28
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.28
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.26
# Section <h3>31.6.4	Restoration of PFCP sessions associated with an FQ-CSID, Group ID or PGW-C/SMF IP Address</h3> is close to requirement LR2_payload with distance 0.25
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.24
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.18
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>4.2.2	Mobile Terminated Short Message</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.24
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.16
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>5.2.4	Procedures in the SGSN</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.24
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.17
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>5.2.5	Procedures in the MME</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.25
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.18
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.17
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.17
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>25.2.1	General</h3> is close to requirement LR2_payload with distance 0.18
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.23
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.21
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.20
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.20
# Section <h1>26	Mobile terminated CS service delivery via an alternative MME in MME pool</h1> is close to requirement LR2_payload with distance 0.20
# ...
# Section <h4>10.7.2.4	Discover bearer request</h4> is close to requirement LR4_calculation with distance 0.24
# Section <h4>10.7.2.4	Discover bearer request</h4> is close to requirement LR4_calculation with distance 0.23
# Section <h4>10.7.2.4	Discover bearer request</h4> is close to requirement LR4_calculation with distance 0.21
# Section <h4>10.7.2.6	Media distribution request</h4> is close to requirement LR4_calculation with distance 0.24
# Section <h4>10.7.2.6	Media distribution request</h4> is close to requirement LR4_calculation with distance 0.23
# Section <h4>10.7.2.6	Media distribution request</h4> is close to requirement LR4_calculation with distance 0.21
# Section <h4>10.7.2.7	Media distribution response</h4> is close to requirement LR4_calculation with distance 0.24
# Section <h4>10.7.2.7	Media distribution response</h4> is close to requirement LR4_calculation with distance 0.23
# Section <h4>10.7.2.7	Media distribution response</h4> is close to requirement LR4_calculation with distance 0.21
# Section <h4>10.7.2.10	Media distribution release</h4> is close to requirement LR4_calculation with distance 0.24
# Section <h4>10.7.2.10	Media distribution release</h4> is close to requirement LR4_calculation with distance 0.23
# Section <h4>10.7.2.10	Media distribution release</h4> is close to requirement LR4_calculation with distance 0.21
# Section <h6>10.7.3.9.2.1	MBMS bearer coordination independent on broadcasted media</h6> is close to requirement LR4_calculation with distance 0.24
# Section <h6>10.7.3.9.2.1	MBMS bearer coordination independent on broadcasted media</h6> is close to requirement LR4_calculation with distance 0.22
# Section <h6>10.7.3.9.2.1	MBMS bearer coordination independent on broadcasted media</h6> is close to requirement LR4_calculation with distance 0.20
# Section <h6>10.7.3.9.2.2	MBMS bearer coordination within one group call</h6> is close to requirement LR4_calculation with distance 0.24
# Section <h6>10.7.3.9.2.2	MBMS bearer coordination within one group call</h6> is close to requirement LR4_calculation with distance 0.22
# Section <h6>10.7.3.9.2.2	MBMS bearer coordination within one group call</h6> is close to requirement LR4_calculation with distance 0.20
# Section <h5>10.7.3.11.1	General</h5> is close to requirement LR4_calculation with distance 0.22
# Section <h5>10.7.3.11.1	General</h5> is close to requirement LR4_calculation with distance 0.20
# Section <h5>10.7.3.11.1	General</h5> is close to requirement LR4_calculation with distance 0.19
# Section <h5>10.7.3.11.2	FEC encoding by the BM-SC</h5> is close to requirement LR4_calculation with distance 0.23
# Section <h5>10.7.3.11.2	FEC encoding by the BM-SC</h5> is close to requirement LR4_calculation with distance 0.21
# Section <h5>10.7.3.11.2	FEC encoding by the BM-SC</h5> is close to requirement LR4_calculation with distance 0.20
# Section <h3>10.11.2	Request for unicast resources at session establishment</h3> is close to requirement LR4_calculation with distance 0.24
# Section <h3>10.11.2	Request for unicast resources at session establishment</h3> is close to requirement LR4_calculation with distance 0.22
# Section <h3>10.11.2	Request for unicast resources at session establishment</h3> is close to requirement LR4_calculation with distance 0.20
# Section <h4>10.11.2a.1	General</h4> is close to requirement LR4_calculation with distance 0.24
# Section <h4>10.11.2a.1	General</h4> is close to requirement LR4_calculation with distance 0.22
# Section <h4>10.11.2a.1	General</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h4>10.11.6.1	General</h4> is close to requirement LR4_calculation with distance 0.24
# Section <h4>10.11.6.1	General</h4> is close to requirement LR4_calculation with distance 0.22
# Section <h4>10.11.6.1	General</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h4>10.11.6.2	Procedure</h4> is close to requirement LR4_calculation with distance 0.23
# Section <h4>10.11.6.2	Procedure</h4> is close to requirement LR4_calculation with distance 0.22
# Section <h4>10.11.6.2	Procedure</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h3>7.17.1	General</h3> is close to requirement LR4_calculation with distance 0.25
# Section <h3>7.17.1	General</h3> is close to requirement LR4_calculation with distance 0.23
# Section <h3>7.17.1	General</h3> is close to requirement LR4_calculation with distance 0.21
# Section <h4>7.17.3.1	MCVideo adaptation during group communication procedure – transmitting client triggered</h4> is close to requirement LR4_calculation with distance 0.24
# Section <h4>7.17.3.1	MCVideo adaptation during group communication procedure – transmitting client triggered</h4> is close to requirement LR4_calculation with distance 0.22
# Section <h4>7.17.3.1	MCVideo adaptation during group communication procedure – transmitting client triggered</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h5>7.5.2.10.2	Procedure</h5> is close to requirement LR4_calculation with distance 0.23
# Section <h5>7.5.2.10.2	Procedure</h5> is close to requirement LR4_calculation with distance 0.21
# Section <h5>7.5.2.10.2	Procedure</h5> is close to requirement LR4_calculation with distance 0.19
# Section <h4>5.2.2.2	V2X message reception via MBS</h4> is close to requirement LR4_calculation with distance 0.22
# Section <h4>5.2.2.2	V2X message reception via MBS</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h4>5.2.2.2	V2X message reception via MBS</h4> is close to requirement LR4_calculation with distance 0.18
# Section <h4>5.2.3.1	General</h4> is close to requirement LR4_calculation with distance 0.23
# Section <h4>5.2.3.1	General</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h4>5.2.3.1	General</h4> is close to requirement LR4_calculation with distance 0.18
# Section <h5>5.4.1.1.2	Deriving PC5 QoS parameters and assigning PFI for PC5 QoS Flow</h5> is close to requirement LR4_calculation with distance 0.22
# Section <h5>5.4.1.1.2	Deriving PC5 QoS parameters and assigning PFI for PC5 QoS Flow</h5> is close to requirement LR4_calculation with distance 0.20
# Section <h5>5.4.1.1.2	Deriving PC5 QoS parameters and assigning PFI for PC5 QoS Flow</h5> is close to requirement LR4_calculation with distance 0.18
# Section <h4>5.4.3.1	General</h4> is close to requirement LR4_calculation with distance 0.21
# Section <h4>5.4.3.1	General</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h4>5.4.3.1	General</h4> is close to requirement LR4_calculation with distance 0.19
# Section <h4>5.4.3.3	Priority Level</h4> is close to requirement LR4_calculation with distance 0.22
# Section <h4>5.4.3.3	Priority Level</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h4>5.4.3.3	Priority Level</h4> is close to requirement LR4_calculation with distance 0.19
# Section <h4>5.4.3.4	Packet Delay Budget</h4> is close to requirement LR4_calculation with distance 0.21
# Section <h4>5.4.3.4	Packet Delay Budget</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h4>5.4.3.4	Packet Delay Budget</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h3>5.4.4	Standardized PQI to QoS characteristics mapping</h3> is close to requirement LR4_calculation with distance 0.25
# Section <h3>5.4.4	Standardized PQI to QoS characteristics mapping</h3> is close to requirement LR4_calculation with distance 0.23
# Section <h3>5.4.4	Standardized PQI to QoS characteristics mapping</h3> is close to requirement LR4_calculation with distance 0.22
# Section <h4>5.4.5.1	General</h4> is close to requirement LR4_calculation with distance 0.22
# Section <h4>5.4.5.1	General</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h4>5.4.5.1	General</h4> is close to requirement LR4_calculation with distance 0.19
# Section <h4>5.4.5.3	QoS Change based on Extended NG-RAN Notification to support Alternative Service Requirements</h4> is close to requirement LR4_calculation with distance 0.21
# Section <h4>5.4.5.3	QoS Change based on Extended NG-RAN Notification to support Alternative Service Requirements</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h4>5.4.5.3	QoS Change based on Extended NG-RAN Notification to support Alternative Service Requirements</h4> is close to requirement LR4_calculation with distance 0.18
# Section <h3>6.1.3	Contents of Analytics Exposure</h3> is close to requirement LR4_calculation with distance 0.21
# Section <h3>6.1.3	Contents of Analytics Exposure</h3> is close to requirement LR4_calculation with distance 0.20
# Section <h3>6.1.3	Contents of Analytics Exposure</h3> is close to requirement LR4_calculation with distance 0.18
# Section <h4>6.1A.3.1	Procedure for analytics aggregation with Provision of Area of Interest</h4> is close to requirement LR4_calculation with distance 0.21
# Section <h4>6.1A.3.1	Procedure for analytics aggregation with Provision of Area of Interest</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h4>6.1A.3.1	Procedure for analytics aggregation with Provision of Area of Interest</h4> is close to requirement LR4_calculation with distance 0.18
# Section <h4>6.1A.3.2	Procedure for Analytics Aggregation without Provision of Area of Interest</h4> is close to requirement LR4_calculation with distance 0.21
# Section <h4>6.1A.3.2	Procedure for Analytics Aggregation without Provision of Area of Interest</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h4>6.1A.3.2	Procedure for Analytics Aggregation without Provision of Area of Interest</h4> is close to requirement LR4_calculation with distance 0.19
# Section <h4>6.2C.2.2	General procedure for Federated Learning among Multiple NWDAF Instances</h4> is close to requirement LR4_calculation with distance 0.21
# Section <h4>6.2C.2.2	General procedure for Federated Learning among Multiple NWDAF Instances</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h4>6.2C.2.2	General procedure for Federated Learning among Multiple NWDAF Instances</h4> is close to requirement LR4_calculation with distance 0.18
# Section <h3>6.2F.2	Contents of ML Model Training</h3> is close to requirement LR4_calculation with distance 0.21
# Section <h3>6.2F.2	Contents of ML Model Training</h3> is close to requirement LR4_calculation with distance 0.20
# Section <h3>6.2F.2	Contents of ML Model Training</h3> is close to requirement LR4_calculation with distance 0.18
# Section <h3>6.4.2	Input Data</h3> is close to requirement LR4_calculation with distance 0.23
# Section <h3>6.4.2	Input Data</h3> is close to requirement LR4_calculation with distance 0.21
# Section <h3>6.4.2	Input Data</h3> is close to requirement LR4_calculation with distance 0.20
# Section <h3>6.6.1	General</h3> is close to requirement LR4_calculation with distance 0.21
# Section <h3>6.6.1	General</h3> is close to requirement LR4_calculation with distance 0.20
# Section <h3>6.6.1	General</h3> is close to requirement LR4_calculation with distance 0.18
# Section <h3>6.6.3	Output Analytics</h3> is close to requirement LR4_calculation with distance 0.21
# Section <h3>6.6.3	Output Analytics</h3> is close to requirement LR4_calculation with distance 0.20
# Section <h3>6.6.3	Output Analytics</h3> is close to requirement LR4_calculation with distance 0.18
# Section <h3>6.8.2	Input data</h3> is close to requirement LR4_calculation with distance 0.22
# Section <h3>6.8.2	Input data</h3> is close to requirement LR4_calculation with distance 0.21
# Section <h3>6.8.2	Input data</h3> is close to requirement LR4_calculation with distance 0.19
# Section <h3>6.9.1	General</h3> is close to requirement LR4_calculation with distance 0.20
# Section <h3>6.9.1	General</h3> is close to requirement LR4_calculation with distance 0.19
# Section <h3>6.9.1	General</h3> is close to requirement LR4_calculation with distance 0.17
# Section <h3>6.9.2	Input data</h3> is close to requirement LR4_calculation with distance 0.22
# Section <h3>6.9.2	Input data</h3> is close to requirement LR4_calculation with distance 0.20
# Section <h3>6.9.2	Input data</h3> is close to requirement LR4_calculation with distance 0.19
# Section <h4>6.9.4.2	Procedure for QoS Sustainability in a fine granularity area</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h4>6.9.4.2	Procedure for QoS Sustainability in a fine granularity area</h4> is close to requirement LR4_calculation with distance 0.19
# Section <h4>6.9.4.2	Procedure for QoS Sustainability in a fine granularity area</h4> is close to requirement LR4_calculation with distance 0.17
# Section <h4>6.10.3.1	Data Volume Dispersion Analytics</h4> is close to requirement LR4_calculation with distance 0.22
# Section <h4>6.10.3.1	Data Volume Dispersion Analytics</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h4>6.10.3.1	Data Volume Dispersion Analytics</h4> is close to requirement LR4_calculation with distance 0.18
# Section <h3>6.13.1	General</h3> is close to requirement LR4_calculation with distance 0.21
# Section <h3>6.13.1	General</h3> is close to requirement LR4_calculation with distance 0.20
# Section <h3>6.13.1	General</h3> is close to requirement LR4_calculation with distance 0.18
# Section <h3>6.13.2	Input Data</h3> is close to requirement LR4_calculation with distance 0.21
# Section <h3>6.13.2	Input Data</h3> is close to requirement LR4_calculation with distance 0.20
# Section <h3>6.13.2	Input Data</h3> is close to requirement LR4_calculation with distance 0.18
# Section <h3>6.13.3	Output Analytics</h3> is close to requirement LR4_calculation with distance 0.20
# Section <h3>6.13.3	Output Analytics</h3> is close to requirement LR4_calculation with distance 0.19
# Section <h3>6.13.3	Output Analytics</h3> is close to requirement LR4_calculation with distance 0.17
# Section <h3>6.14.1	General</h3> is close to requirement LR4_calculation with distance 0.22
# Section <h3>6.14.1	General</h3> is close to requirement LR4_calculation with distance 0.20
# Section <h3>6.14.1	General</h3> is close to requirement LR4_calculation with distance 0.18
# Section <h3>6.14.2	Input Data</h3> is close to requirement LR4_calculation with distance 0.22
# Section <h3>6.14.2	Input Data</h3> is close to requirement LR4_calculation with distance 0.21
# Section <h3>6.14.2	Input Data</h3> is close to requirement LR4_calculation with distance 0.19
# Section <h3>6.14.3	Output Analytics</h3> is close to requirement LR4_calculation with distance 0.20
# Section <h3>6.14.3	Output Analytics</h3> is close to requirement LR4_calculation with distance 0.19
# Section <h3>6.14.3	Output Analytics</h3> is close to requirement LR4_calculation with distance 0.17
# Section <h3>6.18.1	General</h3> is close to requirement LR4_calculation with distance 0.21
# Section <h3>6.18.1	General</h3> is close to requirement LR4_calculation with distance 0.19
# Section <h3>6.18.1	General</h3> is close to requirement LR4_calculation with distance 0.17
# Section <h3>6.18.2	Input Data</h3> is close to requirement LR4_calculation with distance 0.22
# Section <h3>6.18.2	Input Data</h3> is close to requirement LR4_calculation with distance 0.21
# Section <h3>6.18.2	Input Data</h3> is close to requirement LR4_calculation with distance 0.19
# Section <h3>7.10.4	Nnwdaf_MLModelTraining_Notify service operation</h3> is close to requirement LR4_calculation with distance 0.22
# Section <h3>7.10.4	Nnwdaf_MLModelTraining_Notify service operation</h3> is close to requirement LR4_calculation with distance 0.21
# Section <h3>7.10.4	Nnwdaf_MLModelTraining_Notify service operation</h3> is close to requirement LR4_calculation with distance 0.20
# Section <h3>7.11.2	Nnwdaf_MLModelTrainingInfo_Request service operation</h3> is close to requirement LR4_calculation with distance 0.22
# Section <h3>7.11.2	Nnwdaf_MLModelTrainingInfo_Request service operation</h3> is close to requirement LR4_calculation with distance 0.21
# Section <h3>7.11.2	Nnwdaf_MLModelTrainingInfo_Request service operation</h3> is close to requirement LR4_calculation with distance 0.19

# %%
# average the distance in dfOutput per section, document and requirement
dfOutput["Distance"] = dfOutput["Distance"].astype(float)
dfGrouped = dfOutput.groupby(["Section", "Document", "Requirement", "Content"])

#convert dfGrouped to a dataframe
dfGrouped = dfGrouped.agg({"Distance": "mean"}).reset_index()

dfGrouped.to_excel("./output_requirements_distances_g.xlsx", index=False)

# %%
# now check the minimum distance per section and document
dfGrouped = dfGrouped.sort_values(by=["Section", "Document", "Distance"])

dfGrouped = dfGrouped.groupby(["Section", "Document"]).first().reset_index()

dfGrouped.to_excel("./output_requirements_distances_g_min.xlsx", index=False)

# %%
# now we turn this into a list of lists
lstRelevantDist = dfGrouped.values.tolist()

print(len(lstRelevantDist))
# Out:
# 95

# %%
# convert to dataframe and save to excel lstRelevantDist
dfRelevantDist = pd.DataFrame(lstRelevantDist, columns=["Section", "Document", "Requirement", "Distance", "Content"])

dfRelevantDist.to_excel("./output_requirements_temp.xlsx", index=False)

# %% [markdown]
# ## Step 4: Check if the requirements exist in the database
#
# In this step, we check if the text that we identified so far is covered by the requirements that exist in the database. We use the sentence transformers to get the embeddings of the text and then we compare them to the existin sections.

# %%
# read the requirements from the Excel file
dfRelevantSections = pd.read_excel("./output_requirements_temp.xlsx")

lstRelevantSections = dfRelevantSections.values.tolist()

# %%
lstRelevantSections[0]
# Out:
# ['<h1>26\tMobile terminated CS service delivery via an alternative MME in MME pool</h1>',
#  '23007-i20.docx',
#  'LR2_payload',
#  '[\'\', \'This procedure is an optional feature for VLR and MME. It enables the network to continue delivering mobile terminated CS services to UEs via an alternative MME in the MME pool where the UE is located when the MME to which the UE was registered fails without restart or fails for a long duration.\', \'\', \'NOTE 1:\\tUEs in idle mode are not aware of an MME failure until they need to send some uplink data or signalling (e.g. a periodic Tracking Area Update) or until they are forced to re-attach e.g. via the network trigerred service restoration procedure. Without support of the procedure defined in this clause, UEs that remain under LTE may not be able to receive mobile terminated CS services for a long duration after an MME failure without restart or a long MME failure.\', \'\', \'The following requirements shall apply if the VLR and MME support this feature.\', \'\', \'When the VLR has to page the UE for a mobile terminated CS service (e.g. upon receipt of an incoming CS call), if the VLR detects that the MME serving the UE is no longer in service, the VLR should send an SGs paging request with a CS restoration indicator to one alternative MME in the same MME pool. The VLR should load-balance the paging requests among the available MMEs in the pool during the restoration procedure.\', \'\', \'The VLR may know the set of MMEs pertaining to the same MME pool by local configuration or by checking the MME Group ID within the MME name that MMEs signal to the VLR in the SGsAP-LOCATION-UDATE-REQUEST, SGsAP-RESET-INDICATION or SGsAP-RESET-ACK messages. The MME should send an SGsAP-RESET-INDICATION message to the VLR after restart.\', \'\', \'The VLR may detect that an MME is no longer in service if there are no more SCTP associations in service with that MME.\', \'\', \'NOTE 2:\\tSemi-permanent SCTP associations are established between the MME and VLR, i.e. the SCTP associations remain up under normal circumstances.\', \'\', \'The VLR should adjust its paging retransmission delay to avoid requesting again the UE to re-attach before the restoration procedure completes.\', \'\', \'The MME shall behave as specified in clause\\xa014.1.3 upon receipt of an SGs paging request not including the CS restoration indicator.\', \'\', \'The MME shall accept the SGs paging request and proceed as follows upon receipt of an SGs paging request including the CS restoration indicator:\', \'\', \'-\\tif the IMSI is unknown by the MME, or if the IMSI is known and the UE is marked as EMM-DEREGISTERED, the MME shall send the paging request with the location information provided by the VLR, regardless of the value of the "MME-Reset" indicator. If no such location information is provided, the MME may either page the UE in all the tracking areas corresponding to that MME or in the tracking areas served by the MME and by the VLR, or reject the paging request per operator policy. The paging request shall include the IMSI and the CN domain indicator set to "PS" to request the UE to re-attach;\', \'\', "-\\tif the IMSI is known by the MME and the UE is considered to be attached to both EPS and non-EPS services or for SMS only (for an SGs paging request with an \'SMS indicator\'), the MME shall page the UE based on the location information stored in the MME.", \'\', \'The MME may support and apply this procedure to a UE using extended idle mode DRX for MT-SMS service, and if so, the MME shall page the UE with the S-TMSI.\', \'\', "NOTE 3:\\tHow the alternative MME knows the UE\'s DRX parameter or the extended DRX parameters to page the UE is implementation dependent.", \'\', \'Upon receipt of a paging request including the IMSI and the CN domain indicator set to "PS", or upon receipt of a Service Reject with Cause #10 – Implicitly detached (when using S-TMSI paging), the UE re-attaches to one MME of the pool (that may not be necessarily the MME that initiated the paging procedure towards the UE) and a new SGs association is established with the VLR. Thi ...
#  0.2041588387027271]

# %%
model = SentenceTransformer("sentence-t5-large")

# list with all embeddings for the sections
lstRelevantEmbeddings = []
iCounter = 0

for oneLine in tqdm(lstRelevantSections):

    # the content of the section starts on the third position of the list
    sentences = oneLine[3]

    # Sentences are encoded by calling model.encode()
    embeddings = model.encode(sentences)
    
    # Print the average embeddings for all the sentences 
    # in this section
    # avg_embedding = np.mean(embeddings, axis=0)
    
    lstOneLine = [oneLine[0], oneLine[1], 2, str(sentences).replace("$", "_").replace("\n", "_"), embeddings]

    lstRelevantEmbeddings.append(lstOneLine)

    iCounter += 1
# Out:
# 100%|██████████| 95/95 [00:04<00:00, 23.13it/s]

# %%
# now, read the requirements from the requirements database, file 20_requirements.xlsx
dfTRequirements = pd.read_excel("20_requirements.xlsx")

# convert to list
lstTRequirements = dfTRequirements.values.tolist()

# %%
lstTRequirements[0]
# Out:
# ['Req_1',
#  'Regarding support for infrastructure protection of electrical transmission, the 5G system shall support an end-to-end latency of less than 5 ms or 10 ms, as requested by the UE initiating the communication. ',
#  'NOTE 1: This requirement relates to TS 22.104, chapter 5.6C Support for infrastructure protection of electrical transmission.\nNOTE 2: Whether the end-to-end latency is 5 ms or 10 ms depends on the applied voltage level. \nNOTE 3: The end-to-end latency is between two UEs, including two wireless links.',
#  'Payload',
#  nan]

# %%
# make the embeddings
model = SentenceTransformer("sentence-t5-large")

# list with all embeddings for the sections
lstTRequirementsEmbeddings = []
iCounter = 0

for oneLine in tqdm(lstTRequirements):

    # the content of the section starts on the requirement text
    sentences = oneLine[1]

    # Sentences are encoded by calling model.encode()
    embeddings = model.encode(sentences)
    
    # Print the average embeddings for all the sentences 
    # in this section
    #avg_embedding = np.mean(embeddings, axis=0)
    
    lstOneLine = [oneLine[0], oneLine[1], 2, str(sentences).replace("$", "_").replace("\n", "_"), embeddings]

    lstTRequirementsEmbeddings.append(lstOneLine)

    iCounter += 1
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 27.25it/s]

# %%
# average the embeddings for all the lstTRequirementsEmbeddings
lstTRequirementsEmbeddingsNP = np.array([x[4] for x in lstTRequirementsEmbeddings])

tRequirementsAvgEmbeddings = np.mean(lstTRequirementsEmbeddingsNP, axis=0)

# %%
# now, calculate the average distance of all the relevant sections to the average requirements
lstDist = []

for oneLine in tqdm(lstRelevantEmbeddings):
    # euclidean distance between the two embeddings
    dist = distance.cosine(oneLine[4], tRequirementsAvgEmbeddings)
    lstDist.append([oneLine[0], oneLine[1], dist, oneLine[3]])

# now we sort the list by the distance
lstDist.sort(key=lambda x: x[3])
# Out:
# 100%|██████████| 95/95 [00:00<00:00, 9095.57it/s]

# %%
lstDist[10]
# Out:
# ['<h3>6.18.1\tGeneral</h3>',
#  '23288-i20.docx',
#  0.12833312352660764,
#  '[\'\', \'Clause\\xa06.18 describes how NWDAF can provide E2E data volume transfer time analytics, in the form of statistics or predictions or both, to a service consumer. NWDAF collects E2E data volume transfer time related input data from 5GC NFs, OAM and AF. The consumer can either subscribe to analytics notifications (i.e. a Subscribe-Notify model) or request a single notification (i.e. a Request-Response model).\', \'\', \'The E2E data volume transfer time refers to a time delay for completing the transmission of a specific data volume from UE to AF, or from AF to UE. If a target number of repeating data transmissions or a target time interval between data transmissions is given, the E2E data volume transfer time can be provided as an average value of every data volume transfer time within the Analytics target period. The E2E data volume transfer time analytics may be used to assist an AF hosting AI/ML-based services, e.g. for member selection of federated learning.\', \'\', \'The E2E data volume transfer time analytics may be provided as defined in clause\\xa06.18.3 for a UE individually or a list of UEs.\', \'\', \'More than one E2E data volume transfer time classes might be assigned by operator or AF for a group of UEs. The UEs might be classified to high-, medium-, and low-transfer time classes with respect to the threshold(s) of the corresponding class.\', \'\', \'The service consumer may be an NF (e.g. AF, or NEF).\', \'\', \'The consumer of these analytics may indicate in the request:\', \'\', \'-\\tAnalytics ID = "E2E data volume transfer time ".\', \'\', \'-\\tTarget of Analytics Reporting: a single UE (SUPI/GPSI) or a group of UEs (a list of SUPIs/GPSIs).\', \'\', \'-\\tAnalytics Filter Information optionally including:\', \'\', \'-\\tDNN;\', \'\', \'-\\tS-NSSAI;\', \'\', \'-\\tApplication ID;\', \'\', \'-\\tArea of Interest (AOI(s)): restricts the scope of the E2E data volume transfer time analytics to the provided area;\', \'\', \'-\\tAn optional list of analytics subsets that are requested (see clause\\xa06.18.3);\', \'\', \'-\\tData Volume UL/DL: indicates a specific data volume transmitted once from UE to AF and/or from AF to UE;\', \'\', \'-\\tQoS requirements (e.g. 5QI, QoS Characteristics);\', \'\', \'-\\tOptionally, either a target number of repeating data transmissions or a target time interval between data transmissions within the Analytics target period;\', \'\', \'-\\tOptionally, a request for geographical distribution (i.e. the AoIs) of the UEs.\', \'\', \'-\\tAn Analytics target period indicates the time period over which the statistics or predictions are requested.\', \'\', \'-\\tIn a subscription, the Notification Correlation Id and the Notification Target Address are included.\', \'\', \'-\\tOptionally, preferred level of accuracy of the analytics.\', \'\', \'-\\tOptional preferred order of results for the list of E2E data volume transfer time:\', \'\', \'-\\tordering criterion: "E2E data volume transfer time",\', \'\', \'-\\torder: ascending or descending.\', \'\', \'-\\tOptionally, Reporting Thresholds, which indicate conditions on the level to be reached for respective analytics subsets (see clause\\xa06.18.3)\', \'\', \'-\\tOptionally, maximum number of UEs.\', \'\']']

# %%
# Visualize the results using the scatter plot, where
# the x-axis is the distance to the average requirement
# the y-axis is always 1
# the color is red for the requirements

# Create a color map based on x[2]
color_map = {0: 'red', 1: 'green', 2: 'blue'}
colors = [color_map[0] for x in lstDist]

# we plot the t-SNE results
plt.figure(figsize=(16,10))

plt.scatter([x[2] for x in lstDist], [1 for x in lstDist], c=colors, s=100, alpha=0.5)

# Add labels to each dot
for i, label in enumerate([x[3] for x in lstDist]):
    plt.text([x[2] for x in lstDist][i], 1, label[:20]+'...', rotation='vertical')

# Add vertical lines at 0.33 and 1.0
plt.axvline(x=0.33, color='r', linestyle='--')
plt.axvline(x=1.0, color='g', linestyle='--')

# Set the limits of the x-axis
plt.xlim(0, 2)
plt.ylim(0, 2)

plt.show()

# %%
# now we separate them into three lists:
# - with distance below 0.33 -- these requirements are covered
# - with distance between 0.33 and 1.0 -- these requirements are partially covered
# - with distance above 1.0 -- these requirements are not covered

lstCovered = []
lstPartiallyCovered = []
lstNotCovered = []

for oneLine in lstDist:
    if oneLine[2] < 0.33:
        lstCovered.append(oneLine)
    elif oneLine[2] < 1.0:
        lstPartiallyCovered.append(oneLine)
    else:
        lstNotCovered.append(oneLine)

# %% [markdown]
# ## Step 5: create requirements based on each of these sections
#
# In the last step, we create new requirements based on the sections identified in the previous steps.

# %%
torch.random.manual_seed(0)

modelInstr = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3-mini-4k-instruct", 
    device_map="cuda", 
    torch_dtype="auto", 
    trust_remote_code=True, 
)
tokenizerInstr = AutoTokenizer.from_pretrained("microsoft/Phi-3-mini-4k-instruct")
# Out:
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3-mini-4k-instruct:
# - configuration_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/microsoft/Phi-3-mini-4k-instruct:
# - modeling_phi3.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# `flash-attention` package not found, consider installing for better performance: No module named 'flash_attn'.
# Current `flash-attenton` does not support `window_size`. Either upgrade or use `attn_implementation='eager'`.
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
def createRequirement(content, type, model, tokenizer):

    content1 = content.split(",")
    content1 = [x for x in content1[1:] if x not in ['', " ''", " '']"]]
    content_str = " ".join(content1)
    
    strContent = f"Based on this : {content_str[:200]}. Write the requirement in the following format 'The {type} of the system shall ' "

    messages = [
        {"role": "user", "content": strContent},
    ]

    pipe = pipeline(
        "text-generation",
        model=model,
        tokenizer=tokenizer,
    )

    generation_args = {
        "max_new_tokens": 500,
        "return_full_text": False,
        "temperature": 0.0,
        "do_sample": False,
    }

    output = pipe(messages, **generation_args)
    
    return output[0]['generated_text']

# %%
lstPartiallyCovered[0]
# Out:
# ['<h3>6.27.2\tDescription</h3>',
#  '23700-60-i00.docx',
#  0.38694578,
#  "['', 'RT (Round-Trip) latency requirement is the latency requirements between UE and N6 termination point at the UPF, as defined in SP-211646. To provide good service experience for users, the XR services with real-time interaction typically require very low RT latency (RT latency refers to the remaining part of the end-to-end motion-to-photon (MTP) delay excluding the processing/rending time at the UE and server side). Thus, it is necessary to study how to meet the very low RT latency requirements in 5GS. But the challenge is how to meet the very low Round-Trip latency requirement with a variable or unequal uplink/downlink latency. Since the AF lacks dynamic information of the current UL/DL situation, it is difficult for AF to split the RT latency requirement into UL and DL delay requirements in an optimized way. It is assumed that the AF to provide the RT latency requirements to 5GC.', '', 'The solution is based on the existing QoS model and policy framework with the following enhancements and special configurations:', '', '-\\tThe AF provides RT latency requirements to the PCF together with the AF session information directly when the AF is trusted or via NEF when the AF is untrusted.', '', '-\\tThe PCF split the RT latency requirement into an UL PDB and a DL PDB part. The UL PDB and DL PDB are can be unequal but their sum shall not exceed the RT latency requirement. The PCF shall generate two PCC rules for the media stream, one for the UL and one for the DL direction, and assigns the 5QIs according to the PDBs respectively.', '', '-\\tThe PCF may also issues two QoS monitoring policies to request monitor UL delay and DL delay respectively.', '', '-\\tBased on the received QoS monitoring result, the PCF can semi-statically adjusts the UL PDB and the DL PDB, so that UL/DL PDB fits better to the new situation while the RT latency is not exceeded .', '']"]

# %%
from tqdm import tqdm

# for every requirement from the list, we generate a requirement
# and we add it to the list

lstGenerated = []
iCounter = 0

for oneLine in tqdm(lstPartiallyCovered):
    iCounter += 1
    if (len(oneLine[3]) < 10000):
        strRequirement = createRequirement(oneLine[3], oneLine[2], modelInstr, tokenizerInstr)
        lstGenerated.append([oneLine[0], oneLine[1], oneLine[2], oneLine[3], oneLine[4], strRequirement])
    if iCounter % 10 == 0:
        # convert the list to a dataframe and save to excel
        dfOutput = pd.DataFrame(lstGenerated, columns=["Section", "Document", "Requirement type", "Content", "Distance", "Generated requirements"])
        dfOutput.to_excel("./output_partially_covered_generated_cont.xlsx", index=False)
# Out:
#   0%|          | 0/873 [00:00<?, ?it/s]You are not running the flash-attention implementation, expect numerical differences.

# %%
dfOutput = pd.DataFrame(lstGenerated, columns=["Section", "Document", "Requirement type", "Content", "Distance", "Generated requirements"])
dfOutput.to_excel("./output_partially_covered_generated.xlsx", index=False)

# %%
# check which GPUs are available 
import torch
torch.cuda.get_device_name(1)
