# %% [markdown]
# # 3REQ system
#
# Requirement analysis system.
#
# The flow is presented in the following figure:
#
# <img src="flow.png" alt="drawing" width="700"/>
#
# Summary:
# 1. Extract sections that contain words like "latency"
# 2. Find if they resemble requirements or not
# 3. Check if they are specific kinds of requirements (like signalling)
# 4. Write new requirements based on the text in these sections.

# %%
# Importing required libraries

# docx2python is used to extract text, images, tables, and other data from .docx files
from docx2python import docx2python

# os module provides functions for interacting with the operating system
import os

# numpy is used for mathematical operations on large, multi-dimensional arrays and matrices
import numpy as np

# pandas is used for data manipulation and analysis
import pandas as pd

# TSNE from sklearn.manifold is used for dimensionality reduction
from sklearn.manifold import TSNE

# matplotlib.pyplot is used for creating static, animated, and interactive visualizations in Python
import matplotlib.pyplot as plt

# SentenceTransformer is used for training and using transformer models for generating sentence embeddings
from sentence_transformers import SentenceTransformer

# tqdm is used to make loops show a smart progress meter
from tqdm import tqdm

# torch is the main package in PyTorch, it provides a multi-dimensional array with support for autograd operations like backward()
import torch

# AutoModelForCausalLM, AutoTokenizer, pipeline are from the transformers library by Hugging Face which provides state-of-the-art machine learning models like BERT, GPT-2, etc.
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# euclidean distance and cosine distance
from scipy.spatial import distance

# random generator for the last figure
import random

# %%
# suppress warnings
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Step 1: List the documents's sections with "latency"
#
# In the first step, we go through the documents in the folder "input_standards" and we extract which sections of these documents contain th word "latency". We store the results in a dictionary.

# %%
def extractLatencySections(doc):
    strSectionTitle = ""
    dictSections = {}
    listLatency = []
    skippedSections = 0

    doc_result = docx2python(doc,paragraph_styles = True, html=True)

    # we iterate over all lines
    # look for the section titles (which have the tag <h1>, <h2>, <h3>, etc.)
    # then we add the content of each section to the dictionary
    # and if there is a word "latency" somewhere in the section, we add the section title to the listLatency
    for oneLine in tqdm(doc_result.text.split('\n')):
        if "<h" in oneLine:
            strSectionTitle = oneLine
            dictSections[strSectionTitle] = []

        if strSectionTitle != "":  
            dictSections[strSectionTitle].append(oneLine)

        keywordsInLine = ["latency", "latencies", "delay"]
        keywordsInSections = ["references", "introduction", "definition", "abstract", "conclusion", "acknowledgements", "appendix", "table of contents", "table of figures", "table of tables", "table of contents", "table of figures", "table of tables", "bibliography", "index", "glossary", "list of figures", "list of tables", "list of abbreviations", "list of symbols", "list of terms", "list of equations", "list of algorithms", "list of acronyms", "list of illustrations", "list of appendices"]

        if any(word in oneLine.lower() for word in keywordsInLine) and not any(word in strSectionTitle.lower() for word in keywordsInSections): 
            listLatency.append(strSectionTitle)
        else:
            skippedSections += 1

            
    # remove the keys from the dictionary if they are not part of the listLatency
    # as we want to get only the relevant sections, i.e., the one with the word latency
    for key in list(dictSections.keys()):
        if key not in listLatency:
            del dictSections[key]

    # print("Skipped sections: ", skippedSections)

    # return the dictionary with the relevant sections
    return dictSections

# %%
docInputFolder = "./23_standards"

# this is the return list of all the lines in the document
lstAllLines = []

# for each .docx file in the input folder
# extract the sections with latency using the extractLatencySections function
# and print the sections
for doc in tqdm(os.listdir(docInputFolder)):    

    if doc.endswith(".docx"):
        #print(f"Processing {doc}")

        # since things can go wrong with the latency library, 
        # we use a try except block to avoid the program to stop
        try: 
            dictSections = extractLatencySections(os.path.join(docInputFolder, doc))
        
            # we list the content
            # as a long list of sections 
            for key in dictSections:

                lstOneLine = [key, doc]

                for line in dictSections[key]:
                    lstOneLine.append(line)
                    
                lstAllLines.append(lstOneLine)

        except Exception as e:
            print(f"Error with {doc}: {e}")
# Out:
# 100%|██████████| 13952/13952 [00:00<00:00, 1249416.69it/s]
# 100%|██████████| 25005/25005 [00:00<00:00, 1636937.28it/s]
# 100%|██████████| 2171/2171 [00:00<00:00, 1232016.50it/s]
# 100%|██████████| 17829/17829 [00:00<00:00, 1836314.76it/s]
# 100%|██████████| 20633/20633 [00:00<00:00, 1658319.75it/s]
# 100%|██████████| 9996/9996 [00:00<00:00, 1996393.64it/s]
# 100%|██████████| 995/995 [00:00<00:00, 1470000.87it/s]
# 100%|██████████| 17526/17526 [00:00<00:00, 1299349.03it/s]
# 100%|██████████| 1025/1025 [00:00<00:00, 1193548.47it/s]
# 100%|██████████| 4646/4646 [00:00<00:00, 1415364.35it/s]
# 100%|██████████| 7526/7526 [00:00<00:00, 1119850.00it/s]
# 100%|██████████| 4133/4133 [00:00<00:00, 1105834.30it/s]
# 100%|██████████| 8896/8896 [00:00<00:00, 990957.65it/s]
# 100%|██████████| 4221/4221 [00:00<00:00, 1124216.23it/s]
# 100%|██████████| 23365/23365 [00:00<00:00, 1196653.19it/s]
# 100%|██████████| 5611/5611 [00:00<00:00, 1147619.82it/s]
# 100%|██████████| 7979/7979 [00:00<00:00, 987353.64it/s]
# 100%|██████████| 5327/5327 [00:00<00:00, 1051289.58it/s]
# 100%|██████████| 2991/2991 [00:00<00:00, 1181054.72it/s]
# 100%|██████████| 4453/4453 [00:00<00:00, 1180086.92it/s]
# 100%|██████████| 18108/18108 [00:00<00:00, 1301524.41it/s]
# 100%|██████████| 8476/8476 [00:00<00:00, 1490667.14it/s]
# 100%|██████████| 4412/4412 [00:00<00:00, 1298433.15it/s]
# 100%|██████████| 64744/64744 [00:00<00:00, 1202426.58it/s]
# 100%|██████████| 70210/70210 [00:00<00:00, 1147528.02it/s]
# 100%|██████████| 17918/17918 [00:00<00:00, 1106370.56it/s]
# 100%|██████████| 2419/2419 [00:00<00:00, 1161935.57it/s]
# 100%|██████████| 1933/1933 [00:00<00:00, 1272577.25it/s]
# 100%|██████████| 7282/7282 [00:00<00:00, 1435085.36it/s]
# 100%|██████████| 1587/1587 [00:00<00:00, 1184827.42it/s]
# 100%|██████████| 3820/3820 [00:00<00:00, 903934.63it/s]
# 100%|██████████| 9286/9286 [00:00<00:00, 1454271.78it/s]
# 100%|██████████| 21731/21731 [00:00<00:00, 1341493.29it/s]
# 100%|██████████| 1885/1885 [00:00<00:00, 884765.34it/s]
# 100%|██████████| 2947/2947 [00:00<00:00, 1374012.22it/s]
# 100%|██████████| 37/37 [00:44<00:00,  1.21s/it]

# %%
# model = SentenceTransformer("all-MiniLM-L6-v2")
# model = SentenceTransformer("sentence-transformers/gtr-t5-xxl")
model = SentenceTransformer("sentence-t5-large")

# list with all embeddings for the sections
lstEmbeddings = []
iCounter = 0

for oneLine in tqdm(lstAllLines):

    # the content of the section starts on the third position of the list
    sentences = oneLine[3:]

    # Sentences are encoded by calling model.encode()
    embeddings = model.encode(sentences)
    
    # Print the average embeddings for all the sentences 
    # in this section
    avg_embeddings = embeddings.mean(axis=0)
    
    lstOneLine = [oneLine[0], oneLine[1], 2, str(sentences).replace("$", "_").replace("\n", "_"), avg_embeddings]

    lstEmbeddings.append(lstOneLine)

    iCounter += 1
    # the code below is for debug only
    # in case we want to stop the loop after a certain number of iterations
    #if iCounter == 100:
    #    break
# Out:
# 100%|██████████| 258/258 [03:12<00:00,  1.34it/s]

# %%
# let's plot these average embeddings using t-SNE

# we create a list with the embeddings
lstEmbeddingsNP = np.array([x[4] for x in lstEmbeddings])

# we use t-SNE to reduce the dimensionality of the embeddings
tsne = TSNE(n_components=2, verbose=0, perplexity=12, n_iter=300)
tsne_results = tsne.fit_transform(lstEmbeddingsNP)

# we plot the t-SNE results
plt.figure(figsize=(16,10))

plt.scatter(tsne_results[:,0], tsne_results[:,1])

# Add labels to each dot
for i, label in enumerate([x[0] for x in lstEmbeddings]):
    plt.text(tsne_results[i, 0], tsne_results[i, 1], label[3:10])


plt.show()

# %% [markdown]
# ## Step 2: Find the relevant sections
#
# In this step, we take the sections identified in Step 1 and we compare them to a list of right and wrong requirements. The list is stored in the file List.xlsx

# %%
# open the file List.xlsx using pandas
# and read the workshop NR
df = pd.read_excel("List.xlsx", sheet_name="R_NR")

# convert the dataframe to a list of lists
lstReference = df.values.tolist()

lstReference[0]
# Out:
# ['The 5G system shall support an end-to-end latency of less than 5 ms or 10 ms, as requested by the UE initiating the communication.',
#  1]

# %%
# list with all embeddings for the sections
lstEmbeddingsRef = []

for oneLine in tqdm(lstReference):

    # the content of the section starts on the third position of the list
    sentences = oneLine[0]

    # Sentences are encoded by calling model.encode()
    embeddings = model.encode(sentences)
    
    # Print the average embeddings for all the sentences 
    # in this section
    avg_embedding = embeddings
    
    lstOneLine = [oneLine[0], 'REF', oneLine[1], oneLine[1], avg_embedding]

    lstEmbeddingsRef.append(lstOneLine)
# Out:
# 100%|██████████| 19/19 [00:00<00:00, 37.27it/s]

# %%
# concatenate the two lists
lstEmbeddingsAll = lstEmbeddings + lstEmbeddingsRef

# %%
# let's plot these average embeddings using t-SNE

# we create a list with the embeddings
lstEmbeddingsNP = np.array([x[4] for x in lstEmbeddingsAll])

# we use t-SNE to reduce the dimensionality of the embeddings
tsne = TSNE(n_components=2, verbose=0, perplexity=12, n_iter=300)
tsne_results = tsne.fit_transform(lstEmbeddingsNP)

# Create a color map based on x[2]
color_map = {0: 'red', 1: 'green', 2: 'blue'}
colors = [color_map[x[2]] for x in lstEmbeddingsAll]

# we plot the t-SNE results
plt.figure(figsize=(16,10))

plt.scatter(tsne_results[:,0], tsne_results[:,1],c=colors, s=100, alpha=0.5)

# Add labels to each dot
for i, label in enumerate([x[0] for x in lstEmbeddingsAll]):
    plt.text(tsne_results[i, 0], tsne_results[i, 1], label[:10]+'...')


plt.show()

# %%
from sklearn.metrics.pairwise import euclidean_distances

# for each line in lstEmbeddings
# we calculate the euclidean distance with each line in lstEmbeddingsRef

lstDistPos = []
lstDistNeg = []

lstRelevant = []

for oneLine in tqdm(lstEmbeddings):    
    for oneLineRef in lstEmbeddingsRef:
        if oneLineRef[2] == 1:
            # euclidean distance between the two embeddings
            dist = distance.cosine(oneLine[4], oneLineRef[4])
            lstDistPos.append(dist)
        if oneLineRef[2] == 0:
            # euclidean distance between the two embeddings
            dist = distance.cosine(oneLine[4], oneLineRef[4])
            lstDistNeg.append(dist)
    
    # now calculate the average for both lists
    avgDistPos = np.mean(lstDistPos)
    avgDistNeg = np.mean(lstDistNeg)

    if avgDistPos < avgDistNeg:
        #print(f"Section {oneLine[0]} is relevant")
        # add the class to the list
        oneLine.append(1)
        lstRelevant.append(oneLine)
    else:
        #print(f"Section {oneLine[0]} is not relevant")
        # add the class to the list
        oneLine.append(0)
# Out:
# 100%|██████████| 258/258 [00:00<00:00, 6694.69it/s]

# %%
print(f'Relevant sections: {len(lstRelevant)}')
# Out:
# Relevant sections: 258

# %%
lstEmbeddings[0]
# Out:
# ['<h4>4.1a.5.1\tTypes of event</h4>',
#  '23273-i20.docx',
#  2,
#  "['', 'The following types of event are defined for a deferred location request.', '', 'a)\\tUE availability: Any event in which the 5GCN has established a contact with the UE. This event is considered to be applicable when the UE is temporarily unavailable due to inaction by the user, or for temporarily loss of radio connectivity or IMSI detach and so on. The UE Available event only requires one response to an LCS client/AF and after this response, the UE Available event is concluded.', '', 'b)\\tArea: An event where the UE enters, leaves or remains within a pre-defined geographical area. At least one type of area event can be defined (i.e. entering, leaving or remaining within the area). The LCS client or AF may define the target area as a geographical area or as a geopolitical name of an area. The PLMN may translate and define the target area as the identities of one or more radio cells or tracking areas. The LCS client or AF may request an additional check about whether the UE is located within the provisioned target area. The area event may be reported one time only, or multiple times. The area event report shall contain an indication of the event occurrence. The location estimate may be included in the report. If an area event is detected by the UE but an event report cannot be sent (e.g. because the UE cannot access the network or due to a minimum reporting interval), a report shall be sent later when possible irrespective of whether the area event still applies for the current UE location. Area event reporting is controlled by a minimum and a maximum reporting time. The minimum reporting time defines the minimum allowed time between successive area events. The maximum reporting time defines the maximum time between successive reports. When a UE sends a report due to expiration of the maximum reporting time, the UE indicates expiration of the maximum reporting time as the trigger event. The maximum reporting time enables the AF, LCS client and HGMLC to remain aware of continuing support by the UE for the area event (e.g. to detect if area event reporting may have been aborted due to UE power off).', '', 'NOTE:\\tTo achieve more precise usage of area event in some scenario, e.g. for small target area, it may be useful if LCS Client/AF requests UE location estimate and compares the location estimate with the target area.', '', 'c)\\tPeriodic Location: An event where a defined periodic timer expires in the UE and activates a location report. If a periodic event is detected by the UE but an event report cannot be sent (e.g. because the UE cannot access the network temporarily), a report shall be sent later when possible and the periodic timer for the next event shall then be started. The reporting duration for periodic location shall equal the requested number of reports multiplied by the periodic interval even when reports are delayed.', '', 'd)\\tMotion: An event where the UE moves by more than some predefined straight line distance from a previous location. The motion event may be reported one time only, or multiple times. The motion event report shall contain an indication of the event occurrence. A location estimate may be included in the report if requested by the LCS client or AF. For successive motion event reports, motion is determined relative to the UE location corresponding to the immediately preceding event report (including an event report triggered by expiration of the maximum reporting time). If a motion event is detected by the UE but an event report is deferred (e.g. because the UE cannot access the network temporarily), a report shall be sent later when possible irrespective of whether the motion event still applies to the current UE location. Motion reporting is controlled by a minimum and a maximum reporting time. The minimum reporting time defines the minimum allowed time between successive event reports. The maximum reporting time defines the maximum time between successive reports. When a UE sends a ...
#  array([-2.08613537e-02,  4.91080456e-04,  8.82071385e-04,  1.12052923e-02,
#          3.26076932e-02,  2.43348181e-02, -6.31824322e-03, -2.55440013e-04,
#         -2.65260022e-02,  3.36574540e-02,  4.88069654e-02, -1.86098590e-02,
#          2.64639817e-02,  4.22373191e-02, -3.01903859e-02, -8.07304960e-03,
#         -1.38252843e-02, -1.55674439e-04, -1.99109092e-02,  7.35409837e-03,
#          5.44960424e-02, -1.14570996e-02, -1.21251922e-02,  3.25955674e-02,
#         -4.17103944e-03,  3.15282419e-02,  5.01158880e-03,  1.30371368e-02,
#          4.45382148e-02, -5.82987592e-02,  2.39115562e-02, -2.57325806e-02,
#         -5.47976084e-02, -3.31318900e-02, -8.77840866e-05, -7.04994134e-04,
#          1.63463671e-02,  2.05174857e-03, -1.83523388e-03,  4.65320684e-02,
#          3.49636329e-03,  9.69853892e-04,  2.63365638e-02, -4.12208363e-02,
#          3.73927578e-02, -9.63181164e-03, -3.91948186e-02, -3.36918496e-02,
#          9.74508002e-03, -4.17899266e-02, -4.43133377e-02, -5.91929406e-02,
#         -1.78874098e-02, -2.58945511e-03,  3.73847992e-03, -3.88334803e-02,
#         -4.15997952e-02, -1.94795383e-03,  6.74092621e-02, -3.87620255e-02,
#         -4.84711453e-02,  2.81200577e-02, -8.47851485e-02,  1.58436447e-02,
#          2.40294356e-02, -4.10684124e-02,  4.44129929e-02, -5.07912450e-02,
#          2.35633366e-02, -3.99328880e-02,  1.32263862e-02, -2.04537138e-02,
#         -5.77405887e-03, -6.23451620e-02, -3.56619917e-02, -2.69014165e-02,
#          4.69229557e-02,  5.08599430e-02, -2.06712745e-02,  3.59609388e-02,
#          2.17454117e-02,  5.06313238e-03,  2.73757614e-02, -2.96003688e-02,
#         -2.94321356e-03,  3.27998661e-02, -3.49892974e-02,  5.56940865e-03,
#          8.52088537e-03,  3.44849080e-02, -2.06938963e-02, -4.57746163e-02,
#         -3.38352732e-02, -1.53535111e-02, -1.63380094e-02,  1.37466984e-02,
#          3.63631994e-02, -3.30820158e-02,  3.56735438e-02,  4.76872735e-02,
#          4.42333445e-02,  3.43080685e-02, -2.86637414e-02,  3.65169682e-02,
#         -2.86288541e-02,  9.74771753e-03, -2.59877071e-02, -3.34003940e-02,
#         -2.12175660e-02,  3.96016873e-02, -1.69065651e-02, -2.47522965e-02,
#         -2.09558420e-02,  1.86247099e-02,  2.00329237e-02, -1.92953348e-02,
#          5.45234010e-02, -2.54166946e-02, -3.99542265e-02, -2.63393652e-02,
#          3.73872407e-02,  3.20283361e-02,  7.35090638e-04,  8.03140178e-03,
#         -5.22158816e-02,  1.88014861e-02, -2.39180345e-02, -1.94880050e-02,
#         -3.74510847e-02, -1.05730528e-02,  2.80444454e-02,  3.80030163e-02,
#          5.14375158e-02, -8.87399241e-02,  2.35236865e-02,  2.42002867e-02,
#         -5.64614721e-02,  2.40862668e-02,  6.97994558e-03,  7.53970668e-02,
#         -6.36474490e-02, -3.52054425e-02,  1.50461181e-03, -1.46193421e-02,
#         -8.95391963e-03,  3.54737276e-03, -3.06094484e-03, -4.42396812e-02,
#         -3.22622918e-02, -2.28105392e-02,  2.02213936e-02, -3.72408368e-02,
#         -2.56549623e-02,  6.15867302e-02,  2.17882916e-05,  3.68757248e-02,
#         -1.80511433e-03,  7.37515185e-03,  1.17392710e-03,  2.64610304e-03,
#         -4.66940813e-02,  6.33442476e-02, -2.16964185e-02, -2.78243190e-03,
#         -3.78246456e-02, -9.99315456e-03, -1.62180234e-02,  1.00752518e-01,
#          1.71886222e-03, -2.56066341e-02, -6.36187047e-02,  2.53835488e-02,
#          3.51385474e-02,  2.56464947e-02, -4.49645612e-03,  4.16966528e-02,
#          2.71849856e-02,  1.15554314e-02, -1.13187544e-02,  4.56440076e-02,
#          3.03709391e-03, -3.12739499e-02, -2.01324634e-02,  3.11531685e-02,
#          4.09721360e-02, -4.07630131e-02, -1.77884027e-02,  3.06791198e-02,
#         -5.34872012e-03, -4.80918065e-02, -6.36822823e-03,  3.15216631e-02,
#         -1.20686349e-02,  5.26964664e-03,  1.93991847e-02, -3.11176311e-02,
#         -2.78003551e-02,  2.83925068e-02, -3.49831991e-02,  7.34180119e-03,
#          4.78223106e-03,  3.32881464e-03,  2.51076603e-03,  2.16005072e-02,
#          3.01050767e-02,  2.93012764e-02, -8.61845724e-03,  9.34083164e-02,
#         -2.51589902e-02, -7.59783480e-03, -4.67195101e-02, -5.25106229e-02,
#          6.95391209e-04,  4.90880050e-02,  3.10448371e-02,  5.33661507e-02,
#         -1.92325506e-02, -6.74400330e-02,  2.47932579e-02,  3.72508839e-02,
#          2.20079981e-02, -1.11932438e-02, -5.48088290e-02, -1.23933954e-02,
#          3.76347974e-02,  2.03036554e-02, -3.29804160e-02, -4.48496789e-02,
#          1.23842787e-02,  1.05762500e-02, -1.34849977e-02, -3.03941127e-03,
#         -1.04673067e-02,  9.85467620e-03, -3.55167538e-02, -5.90194687e-02,
#          2.30041109e-02,  4.67898063e-02, -1.48794139e-02,  4.58724983e-03,
#         -3.38189080e-02,  1.76976193e-02,  4.58715148e-02,  5.36800362e-03,
#         -3.58744548e-03, -3.37871946e-02,  2.10407153e-02, -4.84046899e-03,
#          6.31173626e-02, -4.63437028e-02,  3.05870995e-02,  2.17619259e-02,
#          2.27989424e-02, -1.22684501e-02, -1.88052729e-02,  1.70318317e-02,
#          5.94034605e-02,  1.46598984e-02, -1.70788970e-02,  8.38763174e-03,
#          5.93703706e-03,  4.38676514e-02,  6.96035475e-02,  2.58409255e-03,
#          9.31799710e-02, -1.69948712e-02,  2.10586004e-02,  2.77028419e-02,
#          5.85778989e-03, -1.62106939e-02,  4.28282209e-02,  5.68835139e-02,
#          8.39916873e-04,  1.03967255e-02,  2.83359159e-02, -5.53733706e-02,
#          2.09208205e-02, -2.53031589e-02, -7.73427449e-03, -2.57198848e-02,
#         -2.16048099e-02,  6.44488037e-02, -9.00774729e-03, -1.34991752e-02,
#          5.36313094e-03, -1.01030814e-02,  6.32987299e-04,  1.75688788e-02,
#         -1.81170572e-02,  1.27438894e-02, -1.29347062e-02, -3.19875255e-02,
#          2.40509994e-02, -4.57228646e-02,  2.61798385e-03, -3.25283557e-02,
#         -3.04427855e-02, -9.59681871e-04, -8.17146972e-02, -2.44241045e-03,
#         -5.37363328e-02, -3.03144939e-02,  4.44440916e-02,  2.61060558e-02,
#          9.47690196e-03, -1.43552162e-02,  1.99835040e-02, -3.04808058e-02,
#         -5.71516342e-02, -5.97575977e-02, -2.77404152e-02, -2.21883934e-02,
#         -5.51375225e-02,  2.65957788e-02,  4.91533279e-02,  2.47110724e-02,
#          3.55745107e-02,  1.52617460e-02, -5.92123009e-02, -1.61355697e-02,
#          5.43907471e-02,  5.11965388e-03, -6.42322097e-03, -5.63359484e-02,
#          3.31851207e-02,  4.90906602e-03,  8.15753173e-03, -3.37792821e-02,
#         -2.99528036e-02,  6.41882569e-02,  6.97129294e-02,  2.71761548e-02,
#         -1.71431084e-03,  1.12057805e-05, -4.18736674e-02, -3.80662680e-02,
#         -3.63574550e-02, -1.53373480e-02, -4.94582858e-03, -2.90081371e-02,
#         -1.95518211e-02, -1.84136853e-02, -2.10726857e-02, -2.62345169e-02,
#         -1.86825618e-02, -7.42979115e-03,  2.61427145e-02,  4.29412052e-02,
#          3.63227800e-02,  2.24689953e-02, -7.77208479e-03, -2.97566056e-02,
#          5.32225892e-02,  9.72530153e-03, -1.71974283e-02, -4.94076014e-02,
#         -2.74499469e-02,  4.76052761e-02,  3.11284941e-02,  6.49645273e-03,
#         -5.35397604e-02,  2.84486599e-02,  1.76893454e-02, -2.89715570e-03,
#          1.12809837e-02, -2.80980002e-02, -2.96790935e-02,  1.46801220e-02,
#         -2.58821566e-02, -3.03828605e-02, -4.54639383e-02,  1.31368078e-02,
#          1.69143174e-02,  3.72044593e-02, -3.32452804e-02, -2.70888805e-02,
#         -3.01699638e-02,  2.39255633e-02,  1.18186092e-02,  1.00366529e-02,
#         -4.39345799e-02, -1.08119445e-02, -4.19674441e-02, -5.59240347e-03,
#          5.79066994e-03,  4.81508952e-03,  1.06612789e-02,  6.14040084e-02,
#          2.98422016e-02, -1.97133198e-02,  4.17186543e-02,  3.34233022e-03,
#          4.07326184e-02,  2.59891730e-02, -1.62133351e-02,  1.57620534e-02,
#         -2.32604817e-02,  2.23358907e-02,  3.43614118e-03, -1.20025175e-02,
#         -2.92684715e-02, -8.68245661e-02, -4.07090262e-02,  4.80828099e-02,
#         -1.52033065e-02, -7.65008014e-03,  4.31476086e-02, -3.60479243e-02,
#         -2.97301300e-02,  3.85487685e-03,  8.08730256e-03,  4.84989323e-02,
#         -1.44971330e-02,  3.94216739e-02,  1.53337955e-03,  5.90155320e-03,
#         -4.21657898e-02,  7.02847773e-03, -2.29974724e-02, -2.32427735e-02,
#          2.24922579e-02,  4.24783789e-02,  1.55784637e-02,  4.55999747e-02,
#          5.57242893e-02,  3.86773935e-03, -1.58039331e-02,  3.95550095e-02,
#          3.52288857e-02,  1.23895174e-02, -2.29832139e-02,  2.12311768e-03,
#         -5.41665591e-03, -1.52573884e-02, -3.24857584e-03, -4.15838733e-02,
#          3.79273631e-02,  4.55323420e-02, -1.02377003e-02,  7.03844754e-03,
#          1.22225648e-02, -8.26222729e-03, -5.31084128e-02, -3.98638509e-02,
#          8.05340055e-03, -1.46990651e-02, -4.21229042e-02,  1.98718887e-02,
#          2.61741783e-02, -7.03036459e-03,  6.09205328e-02, -1.48332883e-02,
#         -3.79808284e-02, -5.03663756e-02,  1.92383844e-02,  1.35660460e-02,
#         -4.09186706e-02, -6.47208616e-02, -2.51880717e-02,  1.34171937e-02,
#          3.44807953e-02, -9.55701154e-03, -5.05413152e-02,  1.95261855e-02,
#          5.31646982e-02, -3.84160392e-02,  4.19346429e-02,  2.56835651e-02,
#          3.13896276e-02,  3.62010784e-02, -1.36253685e-02,  2.22893376e-02,
#         -3.93310189e-02, -1.43423874e-03, -1.99369192e-02,  4.96053509e-02,
#         -3.84232233e-04, -3.71462144e-02, -2.23016348e-02,  1.87129956e-02,
#          3.23386043e-02,  4.85101119e-02,  4.39414755e-02, -4.93068472e-02,
#         -4.34781499e-02, -3.80969793e-02,  5.46915717e-02, -4.45456244e-02,
#          1.78704876e-02,  3.52102853e-02,  4.17040437e-02, -3.86484824e-02,
#         -2.63428912e-02, -1.12394299e-02,  1.77463330e-02,  4.40803431e-02,
#         -1.53638273e-02, -3.78344283e-02, -1.34855257e-02,  2.23411322e-02,
#          2.66656764e-02, -2.58669294e-02, -9.55191553e-02,  2.11030357e-02,
#          4.17108135e-03, -4.65599447e-02,  5.58831021e-02,  3.08108907e-02,
#          2.23583654e-02,  9.09450576e-02,  1.47973197e-02,  1.08343447e-02,
#         -2.48540808e-02,  3.56023163e-02, -4.00655270e-02, -4.47801761e-02,
#         -1.71046406e-02, -5.80720641e-02, -2.15192549e-02, -4.25462760e-02,
#         -3.50135118e-02, -2.14936100e-02,  9.50954296e-03,  3.26171555e-02,
#          2.34902487e-03,  4.42331508e-02,  1.79461576e-02,  2.51600351e-02,
#          1.79416575e-02, -3.02939136e-02, -2.30970792e-02, -2.03546472e-02,
#         -6.77054375e-02, -1.96596216e-02,  2.60497052e-02, -1.13230362e-03,
#          4.52900631e-03,  8.26165732e-03,  1.10284546e-02,  9.25801462e-04,
#          1.87077522e-02, -3.82582396e-02,  4.17215973e-02,  3.36355008e-02,
#         -5.53126857e-02, -6.38271589e-03, -1.14396149e-02,  7.27588497e-03,
#          2.79327910e-02, -2.91394126e-02,  4.31819372e-02, -1.85058881e-02,
#         -1.96177941e-02, -7.10669346e-03,  2.33903937e-02,  1.86769944e-02,
#         -5.39699830e-02, -3.60126002e-03, -1.31086465e-02, -2.12445040e-03,
#          2.35066395e-02, -1.54294539e-02, -2.42340397e-02,  1.28046190e-02,
#          4.22971994e-02,  3.02188024e-02,  8.60637799e-03, -2.18281727e-02,
#          3.06479372e-02, -3.58744822e-02,  7.52009219e-03, -6.20153211e-02,
#          2.80686915e-02, -2.99137868e-02,  1.09539041e-02, -1.45941293e-02,
#          2.84844562e-02, -5.93982711e-02,  4.50693518e-02, -2.20233873e-02,
#         -1.80769172e-02, -8.33663996e-03,  9.12901666e-03, -1.35607868e-02,
#          1.81321893e-02, -2.82398276e-02, -8.77964124e-03, -4.55128476e-02,
#          5.17252684e-02, -1.78628396e-02,  1.37304943e-02,  1.37016852e-03,
#         -2.09759790e-02, -3.91795076e-02, -1.60724716e-03, -2.56866310e-02,
#         -5.59056811e-02,  3.12840417e-02,  4.47606258e-02,  1.12313991e-02,
#         -4.76375269e-03,  2.96613527e-03, -1.95074007e-02,  5.65888081e-03,
#         -4.42245528e-02, -1.29264612e-02, -9.73814726e-03, -2.51616351e-02,
#         -6.05450897e-03,  1.50454408e-02,  3.87620144e-02, -5.59500605e-02,
#         -1.93378460e-02,  3.27055790e-02,  2.98194624e-02,  9.96211264e-03,
#          6.27998821e-03,  5.64327464e-04,  2.79719066e-02,  5.76946186e-03,
#         -1.59105696e-02, -9.62474849e-03, -2.83813998e-02, -1.04618976e-02,
#         -2.00420525e-03, -2.99997348e-02,  1.76935159e-02, -2.92322412e-03,
#         -2.84658056e-02, -1.32775437e-02,  8.25274885e-02,  1.96663029e-02,
#          3.30984443e-02, -2.44189817e-02, -4.51586284e-02,  5.45284748e-02,
#          4.25413344e-03, -2.41834354e-02,  4.35713269e-02,  7.82787148e-03,
#         -5.33423498e-02,  6.02167659e-02, -1.95279550e-02,  2.27358080e-02,
#          3.56342122e-02,  2.80187353e-02, -2.58090179e-02,  9.02776420e-03,
#         -4.43221144e-02,  1.20298993e-02,  3.71835269e-02, -6.38692975e-02,
#          2.61138636e-03, -2.20256541e-02,  4.68831696e-02, -6.00121096e-02,
#          5.13657331e-02,  1.69442892e-02,  4.50079050e-03,  6.56097103e-03,
#         -5.52696511e-02, -1.36392433e-02,  3.00761312e-03, -3.52656841e-02,
#          5.83350509e-02, -4.24930304e-02, -8.98275450e-02,  7.12873191e-02,
#          7.35841366e-03, -8.57377350e-02,  2.31429301e-02,  9.15686414e-03,
#          2.45990567e-02,  3.07382848e-02,  1.17147174e-02, -4.48035263e-02,
#         -4.72491514e-03, -6.18653446e-02,  4.33208346e-02, -3.24274823e-02,
#         -1.23736821e-02,  1.05696851e-02, -6.21109223e-03, -1.69319957e-02,
#          5.83399311e-02,  3.46788159e-03,  2.76249219e-02,  3.10981236e-02,
#         -4.94936779e-02, -8.32814276e-02,  1.87394004e-02,  1.86071619e-02,
#          6.47230912e-03, -1.69156156e-02, -3.29721272e-02, -1.14962552e-02,
#          1.00731682e-02, -3.98486294e-03, -2.98521109e-02,  1.74821652e-02,
#          1.42849386e-02, -6.51450828e-02, -9.95362177e-03,  2.35566925e-02,
#          5.80968475e-03, -2.48973053e-02,  1.01522803e-02,  1.12923933e-02,
#          1.33120483e-02,  1.56967118e-02,  2.66636629e-02,  1.97875425e-02,
#         -5.01523800e-02, -1.48514416e-02,  1.40481880e-02,  1.34576075e-02,
#          4.78236862e-02, -3.28191668e-02,  4.20737676e-02,  4.00850922e-02,
#          1.93392932e-02,  4.25154716e-02, -2.46439204e-02, -2.17587668e-02,
#          2.48744320e-02, -4.54161838e-02,  2.02772524e-02, -1.80256087e-02,
#         -5.23833185e-02, -2.10788157e-02, -1.96763854e-02, -1.76605321e-02,
#          2.21565757e-02, -2.45189928e-02,  1.96912866e-02,  3.09415981e-02,
#          3.18299346e-02, -5.51670790e-02, -6.78133518e-02, -2.70938482e-02,
#         -2.42346562e-02,  3.64552177e-02,  3.13364938e-02, -4.37565446e-02,
#         -1.50891775e-02, -3.61551382e-02, -2.32557040e-02,  5.97681850e-02,
#         -1.55600570e-02, -5.77585958e-02,  4.69443351e-02,  6.10011816e-02,
#         -3.14450897e-02,  1.73569545e-02,  4.21474017e-02, -2.64438521e-02,
#          4.70204689e-02,  1.92900021e-02,  2.27004774e-02,  3.97376157e-02,
#          4.06528749e-02, -1.74192078e-02, -3.46006900e-02, -4.14440557e-02,
#         -2.69501489e-02, -1.82475708e-02,  7.76676601e-03,  6.40965179e-02],
#        dtype=float32),
#  1]

# %%
# here we save all the relevant sections to an Excel file
# and the non-relevant ones too
import pandas as pd

dfOutput = pd.DataFrame(lstEmbeddings, columns=["Section", "Document", "Class", "Content", "Embedding", "Relevance"])

dfOutput.to_excel("./output.xlsx", index=False)

# %% [markdown]
# ## Step 3: Find which requirements are impacted
#
# In this step, we compare the relevant sections with the existing requirements. Based on the distance, we can determine which requirements are impacted. The requirements are provided as a separete list.

# %%
print(f'Percentage relevant: {len(lstRelevant)/len(lstEmbeddings)*100:.2f}%')
# Out:
# Percentage relevant: 100.00%

# %%
# read the requirements from the excel file requirements.xlsx, worksheet LR
df = pd.read_excel("List.xlsx", sheet_name="LR")

# convert to list
lstRequirements = df.values.tolist()
lstRequirements[0]

# now we calculate the embeddings for each of these requirements
lstEmbeddingsReq = []

for oneLine in tqdm(lstRequirements):
    
        # the content of the section starts on the third position of the list
        sentences = oneLine[1]
    
        # Sentences are encoded by calling model.encode()
        embeddings = model.encode(sentences)
        
        # Print the average embeddings for all the sentences 
        # in this section
        avg_embedding = embeddings
        
        lstOneLine = [oneLine[0], 'latency', oneLine[1], oneLine[1], avg_embedding]
    
        lstEmbeddingsReq.append(lstOneLine)
# Out:
# 100%|██████████| 38/38 [00:00<00:00, 43.85it/s]

# %%
# now we calculate the euclidean distance between the requirements and the sections
# that are relevant
lstDist = []
lstRelevantDist = []

for oneLine in tqdm(lstRelevant):
    for oneLineReq in lstEmbeddingsReq:
        # euclidean distance between the two embeddings
        dist = distance.cosine(oneLine[4], oneLineReq[4])
        lstDist.append([oneLine[0], oneLine[1], oneLineReq[0], dist, oneLine[3]])

# now we sort the list by the distance
lstDist.sort(key=lambda x: x[2])

# and we print them
for i in range(len(lstDist)):
    print(f"Section {lstDist[i][0]} is close to requirement {lstDist[i][2]} with distance {lstDist[i][3]:.2f}")
    # add this to a list
    lstRelevantDist.append([lstDist[i][0], lstDist[i][1], lstDist[i][2], lstDist[i][3], lstDist[i][4]])

# save the list to an Excel file
dfOutput = pd.DataFrame(lstRelevantDist, columns=["Section", "Document", "Requirement", "Distance", "Content"])

# sort it by section and document
dfOutput = dfOutput.sort_values(by=["Section", "Document"])

dfOutput.to_excel("./output_requirements_distances_b.xlsx", index=False)
# Out:
# 100%|██████████| 258/258 [00:00<00:00, 7025.32it/s]
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR1_signalling with distance 0.21
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR1_signalling with distance 0.22
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h1>B.1	LCS privacy selection flow rule</h1> is close to requirement LR1_signalling with distance 0.29
# Section <h4>5.2.2.2	V2X message reception via MBS</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>5.2.3.1	General</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h5>5.4.1.1.2	Deriving PC5 QoS parameters and assigning PFI for PC5 QoS Flow</h5> is close to requirement LR1_signalling with distance 0.21
# Section <h4>5.4.3.1	General</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>5.4.3.3	Priority Level</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>5.4.3.4	Packet Delay Budget</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h3>5.4.4	Standardized PQI to QoS characteristics mapping</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h4>5.4.5.1	General</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>5.4.5.3	QoS Change based on Extended NG-RAN Notification to support Alternative Service Requirements</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h3>6.1.3	Contents of Analytics Exposure</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h4>6.1A.3.1	Procedure for analytics aggregation with Provision of Area of Interest</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>6.1A.3.2	Procedure for Analytics Aggregation without Provision of Area of Interest</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>6.2C.2.2	General procedure for Federated Learning among Multiple NWDAF Instances</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.2F.2	Contents of ML Model Training</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.4.2	Input Data</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.6.1	General</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.6.3	Output Analytics</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.9.1	General</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>6.9.2	Input data</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h4>6.9.4.2	Procedure for QoS Sustainability in a fine granularity area</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h3>6.13.1	General</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.13.2	Input Data</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h3>6.13.3	Output Analytics</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.14.1	General</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h3>6.14.2	Input Data</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.14.3	Output Analytics</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.18.1	General</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>6.18.2	Input Data</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>7.10.4	Nnwdaf_MLModelTraining_Notify service operation</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h3>7.11.2	Nnwdaf_MLModelTrainingInfo_Request service operation</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>10.3.4	Nadrf_MLModelManagement_Retrieval Request service operation</h3> is close to requirement LR1_signalling with distance 0.29
# Section <h3>4.6.2	Public network utilization</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h5>7.3.3.13.2	FEC encoding by the MBSTF</h5> is close to requirement LR1_signalling with distance 0.22
# Section <h3>5.2.4	5G ProSe Direct Discovery Characteristics</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>5.6.1	QoS handling for 5G ProSe Direct Communication</h3> is close to requirement LR1_signalling with distance 0.25
# Section <h4>9.7.2.1	Data transmission quality measurement </h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>9.7.2.2	Data transmission quality query</h4> is close to requirement LR1_signalling with distance 0.25
# Section <h4>9.7.2.3	Data transmission quality measurement reported by SEALDD client</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>9.7.3.1	SEALDD enabled data transmission quality measurement subscription request</h4> is close to requirement LR1_signalling with distance 0.25
# Section <h4>9.7.3.3	SEALDD enabled data transmission quality measurement notification</h4> is close to requirement LR1_signalling with distance 0.25
# Section <h4>9.7.3.5	SEALDD enabled data transmission quality query response</h4> is close to requirement LR1_signalling with distance 0.25
# Section <h4>9.7.3.6	Transmission quality measurement subscription request</h4> is close to requirement LR1_signalling with distance 0.25
# Section <h4>9.7.3.8	Transmission quality measurement notification</h4> is close to requirement LR1_signalling with distance 0.26
# Section <h4>9.9.2.2	SEALDD enabled data transmission quality guarantee with redundant transport</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>14.3.2.13	end-to-end QoS management request </h4> is close to requirement LR1_signalling with distance 0.25
# Section <h4>14.3.2.15	QoS downgrade indication</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>14.3.2.20	Unicast QoS monitoring subscription request</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>14.3.2.24	TSC stream availability discovery response</h4> is close to requirement LR1_signalling with distance 0.25
# Section <h4>14.3.2.25	TSC stream creation request</h4> is close to requirement LR1_signalling with distance 0.25
# Section <h4>14.3.2.33	Unicast QoS monitoring data request</h4> is close to requirement LR1_signalling with distance 0.25
# Section <h4>14.3.2.35	Application connectivity request</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h6>14.3.3.4.1.2	Procedure</h6> is close to requirement LR1_signalling with distance 0.23
# Section <h4>14.3.5.1	General</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h5>14.3.5.2.2	Procedure for a group of UEs</h5> is close to requirement LR1_signalling with distance 0.22
# Section <h5>14.3.5.3.1	Procedure for a single pair of UEs</h5> is close to requirement LR1_signalling with distance 0.21
# Section <h4>14.3.7.2	TSC stream availability discovery procedure</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>14.3.7.3	TSC stream creation procedure</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>14.3.8.2	5GS TSN Bridge information reporting</h4> is close to requirement LR1_signalling with distance 0.25
# Section <h5>14.3.9.2.1	Procedure triggered by correlated source and destination requests</h5> is close to requirement LR1_signalling with distance 0.23
# Section <h5>14.3.12.4.3	Network parameter coordination procedure</h5> is close to requirement LR1_signalling with distance 0.22
# Section <h4>14.3.13.2	Request and Select Background Data Transfer Policy </h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>9.1.1.2	Service requirement</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>9.4.2.1	Procedures on slice lifecycle management</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>9.4.3.5	QoE metrics subscribe</h4> is close to requirement LR1_signalling with distance 0.25
# Section <h5>9.5.2.1.1	VAL server policy provisioning </h5> is close to requirement LR1_signalling with distance 0.23
# Section <h4>9.5.2.2	Network slice optimization based on VAL server policy</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>9.7.2.1	Network slice related performance and analytics monitoring job creation request</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>9.7.2.3	Multiple slices related performance and analytics consolidated report request</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>9.8.3.2	Information collection from NSCE server(s) subscribe request</h4> is close to requirement LR1_signalling with distance 0.25
# Section <h4>9.11.2.1	Procedure for VAL server-triggered and network-based network slice adaptation for VAL application</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>9.11.3.1	Network slice adaptation request</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h5>9.12.2.1.1	Slice related Communication Service Creation</h5> is close to requirement LR1_signalling with distance 0.24
# Section <h4>9.12.3.2	Slice related communication service creation </h4> is close to requirement LR1_signalling with distance 0.25
# Section <h4>9.12.3.3	Slice related communication service reconfiguration</h4> is close to requirement LR1_signalling with distance 0.25
# Section <h4>9.17.2.1	Network Slice Information delivery request</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>9.18.3.2	Network Slice Allocation</h4> is close to requirement LR1_signalling with distance 0.25
# Section <h3>8.2.2	Procedure on VAL server performance analytics</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>8<span style="font-size:20pt">.</span>3.2	Procedure</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>8<span style="font-size:20pt">.</span>4.2	Procedure</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h4>8.4.3.4	UE-to-UE analytics request</h4> is close to requirement LR1_signalling with distance 0.25
# Section <h2>3.2	Abbreviations</h2> is close to requirement LR1_signalling with distance 0.23
# Section <h2>4.1	General concepts</h2> is close to requirement LR1_signalling with distance 0.24
# Section <h4>5.4.1.4	Support of Unavailability Period</h4> is close to requirement LR1_signalling with distance 0.20
# Section <h4>5.4.9.1	General</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.4.12.2	Core Network Assistance for PEIPS</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>5.4.13.1	Mobility Management and Power Saving Optimization</h4> is close to requirement LR1_signalling with distance 0.20
# Section <h4>5.6.7.1	General</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.7.1.2a	Alternative QoS Profile</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h5>5.7.2.4.1a	Notification Control without Alternative QoS Profiles</h5> is close to requirement LR1_signalling with distance 0.22
# Section <h5>5.7.2.4.2	Usage of Notification control with Alternative QoS Profiles at handover</h5> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.7.2.5	Flow Bit Rates</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.7.3.1	General</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.7.3.2	Resource Type</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>5.7.3.4	Packet Delay Budget</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.7.3.5	Packet Error Rate</h4> is close to requirement LR1_signalling with distance 0.25
# Section <h4>5.7.3.6	Averaging Window</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.7.3.7	Maximum Data Burst Volume</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h3>5.7.4	Standardized 5QI to QoS characteristics mapping</h3> is close to requirement LR1_signalling with distance 0.25
# Section <h4>5.7.5.3	Reflective QoS Control</h4> is close to requirement LR1_signalling with distance 0.20
# Section <h4>5.7.7.1	General</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>5.7.7.2	PDU Set Delay Budget</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.8.2.17	Data exposure via Service Based interface</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.8.5.6	Forwarding Action Rule</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>5.8.5.8	Multi-Access Rule</h4> is close to requirement LR1_signalling with distance 0.25
# Section <h3>5.9.4	5G Globally Unique Temporary Identifier</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h2>5.13	Support for Edge Computing</h2> is close to requirement LR1_signalling with distance 0.23
# Section <h4>5.15.2.2	Standardised SST values</h4> is close to requirement LR1_signalling with distance 0.25
# Section <h4>5.17.5.1	General</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h2>5.23	Supporting for Asynchronous Type Communication</h2> is close to requirement LR1_signalling with distance 0.20
# Section <h3>5.27.0	General</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.27.1.1	General</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h5>5.27.1.2.2	Distribution of grandmaster clock and time-stamping</h5> is close to requirement LR1_signalling with distance 0.23
# Section <h4>5.27.1.4	DS-TT and NW-TT Time Synchronization functionality</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>5.27.1.9	Support for derivation of Uu time synchronization error budget</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>5.27.1.12	Support for network timing synchronization status monitoring</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.27.2.2	TSC Assistance Container determination based on PSFP</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h3>5.27.3	Support for TSC QoS Flows</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>5.27.5	5G System Bridge delay</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h3>5.28.1	5GS bridge management for TSN</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>5.28.2	5GS Bridge configuration for TSN</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h4>5.28.3.1	General</h4> is close to requirement LR1_signalling with distance 0.26
# Section <h3>5.28.4	QoS mapping tables for TSN</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>5.28a.1	General</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h5>5.31.7.2.1	Overview</h5> is close to requirement LR1_signalling with distance 0.22
# Section <h5>5.31.7.2.4	Paging for extended DRX for RRC_INACTIVE in NR connected to 5GC</h5> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.31.7.5	MICO mode and Periodic Registration Timer Control</h4> is close to requirement LR1_signalling with distance 0.20
# Section <h3>5.31.8	High latency communication</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h4>5.31.14.2	Serving PLMN Rate Control</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>5.31.14.3	Small Data Rate Control</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h3>5.31.16	Service Gap Control</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h3>5.32.2	Multi Access PDU Sessions</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.32.5.1	General principles</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>5.32.5.2	Round Trip Time Measurements</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h3>5.32.8	ATSSS Rules</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h2>5.33	Support for Ultra Reliable Low Latency Communication</h2> is close to requirement LR1_signalling with distance 0.31
# Section <h3>5.33.1	General</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>5.33.3	QoS Monitoring for packet delay</h3> is close to requirement LR1_signalling with distance 0.31
# Section <h4>5.33.3.1	General</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.33.3.2	Per QoS Flow per UE QoS Measurement</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>5.33.3.3	GTP-U Path Measurement</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h3>5.35A.4	MBSR authorization</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h2>5.37	Support for high data rate low latency services, eXtended Reality (XR) and interactive media services</h2> is close to requirement LR1_signalling with distance 0.31
# Section <h3>5.37.1	General</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>5.37.2	Policy control enhancements to support multi-modal services</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.37.3.1	General</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h3>5.37.4	Network Exposure of 5GS information</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h3>5.37.6	UL/DL policy control based on round-trip latency requirement</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h3>5.37.7	5GS Packet Delay Variation monitoring and reporting</h3> is close to requirement LR1_signalling with distance 0.31
# Section <h4>5.37.7.1	General</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>5.43.3.1	General</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h3>5.43.4	Reporting of satellite backhaul to SMF</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h3>5.43.5	QoS monitoring when dynamic Satellite Backhaul is used</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.44.3.4	Non-3GPP delay budget between PINE and PEGC</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h3>5.45.1	General</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h3>5.45.2	Packet delay monitoring</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.2.2	SMF</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.2.3	UPF</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h4>6.2.6.2	NF profile</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h3>6.2.29	TSCTSF</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h4>6.3.3.3	Selection of an UPF for a particular PDU Session</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.3.5	AMF discovery and selection</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h3>6.3.13	NWDAF discovery and selection</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h1>H.4	Path and Link delay measurements</h1> is close to requirement LR1_signalling with distance 0.22
# Section <h2>K.2.1	Capability exchange</h2> is close to requirement LR1_signalling with distance 0.25
# Section <h1>M.1	Mapping of the parameters between 5GS and TSN UNI</h1> is close to requirement LR1_signalling with distance 0.22
# Section <h1>P.2	Session management and traffic routing for PIN</h1> is close to requirement LR1_signalling with distance 0.29
# Section <h3>4.2.6	AN Release</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h4>4.2.11.3	Configuration for Early Admission Control (EAC) update procedure</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h5>4.3.2.2.1	Non-roaming and Roaming with Local Breakout</h5> is close to requirement LR1_signalling with distance 0.21
# Section <h4>4.3.3.2	UE or network requested PDU Session Modification (non-roaming and roaming with local breakout)</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>4.3.6.2	Processing AF requests to influence traffic routing and/or Service Function Chaining for Sessions not identified by an UE address</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>4.3.6.3	Notification of User Plane Management Events</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>4.3.6.4	Transferring an AF request targeting an individual UE address to the relevant PCF</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>4.8.1.1a	Connection Inactive procedure with CN based MT communication handling</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>4.8.2.2b	Network Triggered Connection Resume in RRC_INACTIVE with CN based MT communication handling</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h5>4.9.1.2.2	Xn based inter NG-RAN handover without User Plane function re-allocation</h5> is close to requirement LR1_signalling with distance 0.21
# Section <h5>4.9.1.3.2	Preparation phase</h5> is close to requirement LR1_signalling with distance 0.22
# Section <h3>4.12a.5	UE Requested PDU Session Establishment via Trusted non-3GPP Access</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h4>4.13.4.2	Emergency Services Fallback</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>4.15.3.1	Monitoring Events</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h5>4.15.3.2.3b	Specific NEF service operations information flow for loss of connectivity and UE reachability</h5> is close to requirement LR1_signalling with distance 0.21
# Section <h5>4.15.3.2.5	Information flow for downlink data delivery status with SMF buffering</h5> is close to requirement LR1_signalling with distance 0.21
# Section <h5>4.15.3.2.7	Information flow for Availability after DDN Failure with SMF buffering</h5> is close to requirement LR1_signalling with distance 0.21
# Section <h5>4.15.3.2.8	Information flow for downlink data delivery status with UPF buffering</h5> is close to requirement LR1_signalling with distance 0.22
# Section <h5>4.15.4.5.1	General</h5> is close to requirement LR1_signalling with distance 0.25
# Section <h4>4.15.6.3a	Network Configuration parameters</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>4.15.6.6	Setting up an AF session with required QoS procedure</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>4.15.6.6a	AF session with required QoS update procedure</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h5>4.15.6.13.2	Procedures for Creating a Multi-member AF session with required QoS</h5> is close to requirement LR1_signalling with distance 0.21
# Section <h4>4.15.9.4	Procedures for management of 5G access stratum time distribution</h4> is close to requirement LR1_signalling with distance 0.20
# Section <h4>4.16.5.1	SMF initiated SM Policy Association Modification</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>4.16.5.2	PCF initiated SM Policy Association Modification</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>4.18.2.1	PFD management triggered by AF</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>4.18.3.2	Management of PFDs in the SMF</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>4.22.9.5	Registration procedures for non-3GPP access path switching</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>4.23.5.3	PDU Session modification procedure</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>4.26.5.3	SMF Context Transfer procedure, LBO or no Roaming, no I-SMF</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h5>5.2.5.3.2	Npcf_PolicyAuthorization_Create service operation</h5> is close to requirement LR1_signalling with distance 0.23
# Section <h5>5.2.5.3.3	Npcf_PolicyAuthorization_Update service operation</h5> is close to requirement LR1_signalling with distance 0.23
# Section <h5>5.2.6.3.6	Nnef_PFDManagement_Create service operation</h5> is close to requirement LR1_signalling with distance 0.23
# Section <h5>5.2.6.3.7	Nnef_PFDManagement_Update service operation</h5> is close to requirement LR1_signalling with distance 0.23
# Section <h5>5.2.6.7.2	Nnef_TrafficInfluence_Create operation</h5> is close to requirement LR1_signalling with distance 0.23
# Section <h5>5.2.6.9.2	Nnef_AFsessionWithQoS_Create service operation</h5> is close to requirement LR1_signalling with distance 0.21
# Section <h5>5.2.6.9.3	Nnef_AFsessionWithQoS_Notify service operation</h5> is close to requirement LR1_signalling with distance 0.22
# Section <h5>5.2.6.9.5	Nnef_AFsessionWithQoS_Update service operation</h5> is close to requirement LR1_signalling with distance 0.21
# Section <h5>5.2.6.33.3	Nnef_AF_request_for_QoS_Notify service operation</h5> is close to requirement LR1_signalling with distance 0.23
# Section <h5>5.2.7.2.2	Nnrf_NFManagement_NFRegister service operation</h5> is close to requirement LR1_signalling with distance 0.23
# Section <h5>5.2.7.3.2	Nnrf_NFDiscovery_Request service operation</h5> is close to requirement LR1_signalling with distance 0.23
# Section <h5>5.2.26.2.1	General</h5> is close to requirement LR1_signalling with distance 0.23
# Section <h5>5.2.27.3.5	Ntsctsf_QoSandTSCAssistance_Notify operation</h5> is close to requirement LR1_signalling with distance 0.23
# Section <h1>F.1	5GS Bridge information reporting</h1> is close to requirement LR1_signalling with distance 0.23
# Section <h1>F.2	5GS Bridge configuration</h1> is close to requirement LR1_signalling with distance 0.22
# Section <h1>F.3	BMCA procedure</h1> is close to requirement LR1_signalling with distance 0.23
# Section <h1>F.4	5GS interworking with TSN deployed in the transport network</h1> is close to requirement LR1_signalling with distance 0.23
# Section <h2>H.2.1	Secondary authentication and authorization by DN-AAA at PDN Connection Establishment</h2> is close to requirement LR1_signalling with distance 0.23
# Section <h1>J.1	Procedure for PIN service</h1> is close to requirement LR1_signalling with distance 0.29
# Section <h2>3.2	Abbreviations</h2> is close to requirement LR1_signalling with distance 0.23
# Section <h5>6.1.2.3.1	PFD management</h5> is close to requirement LR1_signalling with distance 0.22
# Section <h5>6.1.3.2.4	QoS Flow binding</h5> is close to requirement LR1_signalling with distance 0.22
# Section <h4>6.1.3.6	Policy control</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>6.1.3.18	Event reporting from the PCF</h4> is close to requirement LR1_signalling with distance 0.26
# Section <h4>6.1.3.20	Access Traffic Steering, Switching and Splitting</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>6.1.3.21	QoS Monitoring control</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>6.1.3.22	AF session with required QoS</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h4>6.1.3.23	Support of integration with Time Sensitive Networking</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>6.1.3.23b	Support of IETF Deterministic Networking</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>6.1.3.26	Packet Delay Variation monitoring and reporting</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h5>6.1.3.27.2	UL/DL policy control based on round-trip latency requirement</h5> is close to requirement LR1_signalling with distance 0.21
# Section <h5>6.1.3.27.3	Support for delivery of multi-modal services</h5> is close to requirement LR1_signalling with distance 0.22
# Section <h5>6.1.3.27.4	PDU Set QoS handling</h5> is close to requirement LR1_signalling with distance 0.23
# Section <h4>6.1.3.28	AF requested QoS for a UE or group of UEs not identified by a UE address</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>6.2.1.2	Input for PCC decisions</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>6.2.2.4	QoS control</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h3>6.3.1	General</h3> is close to requirement LR1_signalling with distance 0.25
# Section <h1>D.2	Reporting for sponsored data connectivity</h1> is close to requirement LR1_signalling with distance 0.29
# Section <h3>4.7.1	General</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h4>8.6.3.2	PIN Communication Create Request</h4> is close to requirement LR1_signalling with distance 0.27
# Section <h4>8.6.3.4	PIN Communication Update Request</h4> is close to requirement LR1_signalling with distance 0.27
# Section <h2>4.1	General</h2> is close to requirement LR1_signalling with distance 0.24
# Section <h3>6.2.1	General</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.3.1	General</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>6.3.6	Edge Relocation Considering User Plane Latency Requirement</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h3>6.4.1	General</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h4>6.4.2.1	Usage of Nupf_EventExposure to Report QoS Monitoring results</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h1>E.4	Session Breakout</h1> is close to requirement LR1_signalling with distance 0.28
# Section <h2>3.1	Terms</h2> is close to requirement LR1_signalling with distance 0.24
# Section <h4>8.5.2.2	Request-response model</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h5>8.6.6.3.2	Session with QoS create request</h5> is close to requirement LR1_signalling with distance 0.24
# Section <h5>8.6.6.3.4	Session with QoS update request</h5> is close to requirement LR1_signalling with distance 0.24
# Section <h3>8.12.1	General</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>5.2.2	Located UE Discovery &amp; Selection</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h5>6.7.1.2.3	Procedure for Ranging/SL Positioning service exposure though 5GC network via control plane</h5> is close to requirement LR1_signalling with distance 0.22
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.22
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.20
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.20
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.20
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.20
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.21
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.21
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.20
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.21
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.20
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.21
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.19
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.20
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.21
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.21
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.20
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.21
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.21
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.17
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.18
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.20
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.20
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.20
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.18
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.16
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.19
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.22
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.21
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.19
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR2_payload with distance 0.18
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.22
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.19
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.19
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.18
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.20
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.20
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.19
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.19
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.20
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.19
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.20
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.18
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.19
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.20
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.20
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.19
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.20
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.20
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.17
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.17
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.19
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.19
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.20
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.17
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.16
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.18
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.19
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.20
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.18
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR2_payload with distance 0.18
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.23
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.21
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.21
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.20
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.22
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.22
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.22
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.20
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.22
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.21
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.22
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.20
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.21
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.22
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.22
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.21
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.22
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.22
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.18
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.19
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.21
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.21
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.22
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.18
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.17
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.19
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.22
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.21
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.20
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR2_payload with distance 0.19
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.24
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.17
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.18
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.17
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.16
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.23
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.18
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.19
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.21
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.22
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.17
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.16
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.20
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR2_payload with distance 0.22
# ...
# Section <h5>5.2.7.2.2	Nnrf_NFManagement_NFRegister service operation</h5> is close to requirement LR4_calculation with distance 0.22
# Section <h5>5.2.7.2.2	Nnrf_NFManagement_NFRegister service operation</h5> is close to requirement LR4_calculation with distance 0.20
# Section <h5>5.2.7.2.2	Nnrf_NFManagement_NFRegister service operation</h5> is close to requirement LR4_calculation with distance 0.18
# Section <h5>5.2.7.3.2	Nnrf_NFDiscovery_Request service operation</h5> is close to requirement LR4_calculation with distance 0.21
# Section <h5>5.2.7.3.2	Nnrf_NFDiscovery_Request service operation</h5> is close to requirement LR4_calculation with distance 0.20
# Section <h5>5.2.7.3.2	Nnrf_NFDiscovery_Request service operation</h5> is close to requirement LR4_calculation with distance 0.18
# Section <h5>5.2.26.2.1	General</h5> is close to requirement LR4_calculation with distance 0.21
# Section <h5>5.2.26.2.1	General</h5> is close to requirement LR4_calculation with distance 0.19
# Section <h5>5.2.26.2.1	General</h5> is close to requirement LR4_calculation with distance 0.17
# Section <h5>5.2.27.3.5	Ntsctsf_QoSandTSCAssistance_Notify operation</h5> is close to requirement LR4_calculation with distance 0.22
# Section <h5>5.2.27.3.5	Ntsctsf_QoSandTSCAssistance_Notify operation</h5> is close to requirement LR4_calculation with distance 0.21
# Section <h5>5.2.27.3.5	Ntsctsf_QoSandTSCAssistance_Notify operation</h5> is close to requirement LR4_calculation with distance 0.20
# Section <h1>F.1	5GS Bridge information reporting</h1> is close to requirement LR4_calculation with distance 0.20
# Section <h1>F.1	5GS Bridge information reporting</h1> is close to requirement LR4_calculation with distance 0.19
# Section <h1>F.1	5GS Bridge information reporting</h1> is close to requirement LR4_calculation with distance 0.18
# Section <h1>F.2	5GS Bridge configuration</h1> is close to requirement LR4_calculation with distance 0.20
# Section <h1>F.2	5GS Bridge configuration</h1> is close to requirement LR4_calculation with distance 0.19
# Section <h1>F.2	5GS Bridge configuration</h1> is close to requirement LR4_calculation with distance 0.17
# Section <h1>F.3	BMCA procedure</h1> is close to requirement LR4_calculation with distance 0.21
# Section <h1>F.3	BMCA procedure</h1> is close to requirement LR4_calculation with distance 0.20
# Section <h1>F.3	BMCA procedure</h1> is close to requirement LR4_calculation with distance 0.18
# Section <h1>F.4	5GS interworking with TSN deployed in the transport network</h1> is close to requirement LR4_calculation with distance 0.21
# Section <h1>F.4	5GS interworking with TSN deployed in the transport network</h1> is close to requirement LR4_calculation with distance 0.20
# Section <h1>F.4	5GS interworking with TSN deployed in the transport network</h1> is close to requirement LR4_calculation with distance 0.18
# Section <h2>H.2.1	Secondary authentication and authorization by DN-AAA at PDN Connection Establishment</h2> is close to requirement LR4_calculation with distance 0.22
# Section <h2>H.2.1	Secondary authentication and authorization by DN-AAA at PDN Connection Establishment</h2> is close to requirement LR4_calculation with distance 0.20
# Section <h2>H.2.1	Secondary authentication and authorization by DN-AAA at PDN Connection Establishment</h2> is close to requirement LR4_calculation with distance 0.19
# Section <h1>J.1	Procedure for PIN service</h1> is close to requirement LR4_calculation with distance 0.27
# Section <h1>J.1	Procedure for PIN service</h1> is close to requirement LR4_calculation with distance 0.26
# Section <h1>J.1	Procedure for PIN service</h1> is close to requirement LR4_calculation with distance 0.24
# Section <h2>3.2	Abbreviations</h2> is close to requirement LR4_calculation with distance 0.22
# Section <h2>3.2	Abbreviations</h2> is close to requirement LR4_calculation with distance 0.21
# Section <h2>3.2	Abbreviations</h2> is close to requirement LR4_calculation with distance 0.19
# Section <h5>6.1.2.3.1	PFD management</h5> is close to requirement LR4_calculation with distance 0.23
# Section <h5>6.1.2.3.1	PFD management</h5> is close to requirement LR4_calculation with distance 0.21
# Section <h5>6.1.2.3.1	PFD management</h5> is close to requirement LR4_calculation with distance 0.20
# Section <h5>6.1.3.2.4	QoS Flow binding</h5> is close to requirement LR4_calculation with distance 0.23
# Section <h5>6.1.3.2.4	QoS Flow binding</h5> is close to requirement LR4_calculation with distance 0.21
# Section <h5>6.1.3.2.4	QoS Flow binding</h5> is close to requirement LR4_calculation with distance 0.20
# Section <h4>6.1.3.6	Policy control</h4> is close to requirement LR4_calculation with distance 0.21
# Section <h4>6.1.3.6	Policy control</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h4>6.1.3.6	Policy control</h4> is close to requirement LR4_calculation with distance 0.18
# Section <h4>6.1.3.18	Event reporting from the PCF</h4> is close to requirement LR4_calculation with distance 0.26
# Section <h4>6.1.3.18	Event reporting from the PCF</h4> is close to requirement LR4_calculation with distance 0.25
# Section <h4>6.1.3.18	Event reporting from the PCF</h4> is close to requirement LR4_calculation with distance 0.23
# Section <h4>6.1.3.20	Access Traffic Steering, Switching and Splitting</h4> is close to requirement LR4_calculation with distance 0.22
# Section <h4>6.1.3.20	Access Traffic Steering, Switching and Splitting</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h4>6.1.3.20	Access Traffic Steering, Switching and Splitting</h4> is close to requirement LR4_calculation with distance 0.18
# Section <h4>6.1.3.21	QoS Monitoring control</h4> is close to requirement LR4_calculation with distance 0.21
# Section <h4>6.1.3.21	QoS Monitoring control</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h4>6.1.3.21	QoS Monitoring control</h4> is close to requirement LR4_calculation with distance 0.18
# Section <h4>6.1.3.22	AF session with required QoS</h4> is close to requirement LR4_calculation with distance 0.21
# Section <h4>6.1.3.22	AF session with required QoS</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h4>6.1.3.22	AF session with required QoS</h4> is close to requirement LR4_calculation with distance 0.18
# Section <h4>6.1.3.23	Support of integration with Time Sensitive Networking</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h4>6.1.3.23	Support of integration with Time Sensitive Networking</h4> is close to requirement LR4_calculation with distance 0.19
# Section <h4>6.1.3.23	Support of integration with Time Sensitive Networking</h4> is close to requirement LR4_calculation with distance 0.18
# Section <h4>6.1.3.23b	Support of IETF Deterministic Networking</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h4>6.1.3.23b	Support of IETF Deterministic Networking</h4> is close to requirement LR4_calculation with distance 0.18
# Section <h4>6.1.3.23b	Support of IETF Deterministic Networking</h4> is close to requirement LR4_calculation with distance 0.17
# Section <h4>6.1.3.26	Packet Delay Variation monitoring and reporting</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h4>6.1.3.26	Packet Delay Variation monitoring and reporting</h4> is close to requirement LR4_calculation with distance 0.19
# Section <h4>6.1.3.26	Packet Delay Variation monitoring and reporting</h4> is close to requirement LR4_calculation with distance 0.18
# Section <h5>6.1.3.27.2	UL/DL policy control based on round-trip latency requirement</h5> is close to requirement LR4_calculation with distance 0.20
# Section <h5>6.1.3.27.2	UL/DL policy control based on round-trip latency requirement</h5> is close to requirement LR4_calculation with distance 0.18
# Section <h5>6.1.3.27.2	UL/DL policy control based on round-trip latency requirement</h5> is close to requirement LR4_calculation with distance 0.17
# Section <h5>6.1.3.27.3	Support for delivery of multi-modal services</h5> is close to requirement LR4_calculation with distance 0.24
# Section <h5>6.1.3.27.3	Support for delivery of multi-modal services</h5> is close to requirement LR4_calculation with distance 0.21
# Section <h5>6.1.3.27.3	Support for delivery of multi-modal services</h5> is close to requirement LR4_calculation with distance 0.19
# Section <h5>6.1.3.27.4	PDU Set QoS handling</h5> is close to requirement LR4_calculation with distance 0.22
# Section <h5>6.1.3.27.4	PDU Set QoS handling</h5> is close to requirement LR4_calculation with distance 0.21
# Section <h5>6.1.3.27.4	PDU Set QoS handling</h5> is close to requirement LR4_calculation with distance 0.19
# Section <h4>6.1.3.28	AF requested QoS for a UE or group of UEs not identified by a UE address</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h4>6.1.3.28	AF requested QoS for a UE or group of UEs not identified by a UE address</h4> is close to requirement LR4_calculation with distance 0.19
# Section <h4>6.1.3.28	AF requested QoS for a UE or group of UEs not identified by a UE address</h4> is close to requirement LR4_calculation with distance 0.18
# Section <h4>6.2.1.2	Input for PCC decisions</h4> is close to requirement LR4_calculation with distance 0.21
# Section <h4>6.2.1.2	Input for PCC decisions</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h4>6.2.1.2	Input for PCC decisions</h4> is close to requirement LR4_calculation with distance 0.18
# Section <h4>6.2.2.4	QoS control</h4> is close to requirement LR4_calculation with distance 0.22
# Section <h4>6.2.2.4	QoS control</h4> is close to requirement LR4_calculation with distance 0.21
# Section <h4>6.2.2.4	QoS control</h4> is close to requirement LR4_calculation with distance 0.19
# Section <h3>6.3.1	General</h3> is close to requirement LR4_calculation with distance 0.24
# Section <h3>6.3.1	General</h3> is close to requirement LR4_calculation with distance 0.22
# Section <h3>6.3.1	General</h3> is close to requirement LR4_calculation with distance 0.21
# Section <h1>D.2	Reporting for sponsored data connectivity</h1> is close to requirement LR4_calculation with distance 0.27
# Section <h1>D.2	Reporting for sponsored data connectivity</h1> is close to requirement LR4_calculation with distance 0.26
# Section <h1>D.2	Reporting for sponsored data connectivity</h1> is close to requirement LR4_calculation with distance 0.24
# Section <h3>4.7.1	General</h3> is close to requirement LR4_calculation with distance 0.23
# Section <h3>4.7.1	General</h3> is close to requirement LR4_calculation with distance 0.21
# Section <h3>4.7.1	General</h3> is close to requirement LR4_calculation with distance 0.20
# Section <h4>8.6.3.2	PIN Communication Create Request</h4> is close to requirement LR4_calculation with distance 0.26
# Section <h4>8.6.3.2	PIN Communication Create Request</h4> is close to requirement LR4_calculation with distance 0.24
# Section <h4>8.6.3.2	PIN Communication Create Request</h4> is close to requirement LR4_calculation with distance 0.22
# Section <h4>8.6.3.4	PIN Communication Update Request</h4> is close to requirement LR4_calculation with distance 0.26
# Section <h4>8.6.3.4	PIN Communication Update Request</h4> is close to requirement LR4_calculation with distance 0.24
# Section <h4>8.6.3.4	PIN Communication Update Request</h4> is close to requirement LR4_calculation with distance 0.22
# Section <h2>4.1	General</h2> is close to requirement LR4_calculation with distance 0.23
# Section <h2>4.1	General</h2> is close to requirement LR4_calculation with distance 0.20
# Section <h2>4.1	General</h2> is close to requirement LR4_calculation with distance 0.18
# Section <h3>6.2.1	General</h3> is close to requirement LR4_calculation with distance 0.22
# Section <h3>6.2.1	General</h3> is close to requirement LR4_calculation with distance 0.20
# Section <h3>6.2.1	General</h3> is close to requirement LR4_calculation with distance 0.19
# Section <h3>6.3.1	General</h3> is close to requirement LR4_calculation with distance 0.21
# Section <h3>6.3.1	General</h3> is close to requirement LR4_calculation with distance 0.19
# Section <h3>6.3.1	General</h3> is close to requirement LR4_calculation with distance 0.18
# Section <h3>6.3.6	Edge Relocation Considering User Plane Latency Requirement</h3> is close to requirement LR4_calculation with distance 0.20
# Section <h3>6.3.6	Edge Relocation Considering User Plane Latency Requirement</h3> is close to requirement LR4_calculation with distance 0.18
# Section <h3>6.3.6	Edge Relocation Considering User Plane Latency Requirement</h3> is close to requirement LR4_calculation with distance 0.18
# Section <h3>6.4.1	General</h3> is close to requirement LR4_calculation with distance 0.21
# Section <h3>6.4.1	General</h3> is close to requirement LR4_calculation with distance 0.19
# Section <h3>6.4.1	General</h3> is close to requirement LR4_calculation with distance 0.18
# Section <h4>6.4.2.1	Usage of Nupf_EventExposure to Report QoS Monitoring results</h4> is close to requirement LR4_calculation with distance 0.21
# Section <h4>6.4.2.1	Usage of Nupf_EventExposure to Report QoS Monitoring results</h4> is close to requirement LR4_calculation with distance 0.19
# Section <h4>6.4.2.1	Usage of Nupf_EventExposure to Report QoS Monitoring results</h4> is close to requirement LR4_calculation with distance 0.18
# Section <h1>E.4	Session Breakout</h1> is close to requirement LR4_calculation with distance 0.27
# Section <h1>E.4	Session Breakout</h1> is close to requirement LR4_calculation with distance 0.25
# Section <h1>E.4	Session Breakout</h1> is close to requirement LR4_calculation with distance 0.24
# Section <h2>3.1	Terms</h2> is close to requirement LR4_calculation with distance 0.23
# Section <h2>3.1	Terms</h2> is close to requirement LR4_calculation with distance 0.20
# Section <h2>3.1	Terms</h2> is close to requirement LR4_calculation with distance 0.18
# Section <h4>8.5.2.2	Request-response model</h4> is close to requirement LR4_calculation with distance 0.23
# Section <h4>8.5.2.2	Request-response model</h4> is close to requirement LR4_calculation with distance 0.20
# Section <h4>8.5.2.2	Request-response model</h4> is close to requirement LR4_calculation with distance 0.19
# Section <h5>8.6.6.3.2	Session with QoS create request</h5> is close to requirement LR4_calculation with distance 0.23
# Section <h5>8.6.6.3.2	Session with QoS create request</h5> is close to requirement LR4_calculation with distance 0.22
# Section <h5>8.6.6.3.2	Session with QoS create request</h5> is close to requirement LR4_calculation with distance 0.21
# Section <h5>8.6.6.3.4	Session with QoS update request</h5> is close to requirement LR4_calculation with distance 0.23
# Section <h5>8.6.6.3.4	Session with QoS update request</h5> is close to requirement LR4_calculation with distance 0.22
# Section <h5>8.6.6.3.4	Session with QoS update request</h5> is close to requirement LR4_calculation with distance 0.20
# Section <h3>8.12.1	General</h3> is close to requirement LR4_calculation with distance 0.24
# Section <h3>8.12.1	General</h3> is close to requirement LR4_calculation with distance 0.22
# Section <h3>8.12.1	General</h3> is close to requirement LR4_calculation with distance 0.20
# Section <h3>5.2.2	Located UE Discovery &amp; Selection</h3> is close to requirement LR4_calculation with distance 0.23
# Section <h3>5.2.2	Located UE Discovery &amp; Selection</h3> is close to requirement LR4_calculation with distance 0.20
# Section <h3>5.2.2	Located UE Discovery &amp; Selection</h3> is close to requirement LR4_calculation with distance 0.19
# Section <h5>6.7.1.2.3	Procedure for Ranging/SL Positioning service exposure though 5GC network via control plane</h5> is close to requirement LR4_calculation with distance 0.22
# Section <h5>6.7.1.2.3	Procedure for Ranging/SL Positioning service exposure though 5GC network via control plane</h5> is close to requirement LR4_calculation with distance 0.20
# Section <h5>6.7.1.2.3	Procedure for Ranging/SL Positioning service exposure though 5GC network via control plane</h5> is close to requirement LR4_calculation with distance 0.19

# %%
# average the distance in dfOutput per section, document and requirement
dfOutput["Distance"] = dfOutput["Distance"].astype(float)
dfGrouped = dfOutput.groupby(["Section", "Document", "Requirement", "Content"])

#convert dfGrouped to a dataframe
dfGrouped = dfGrouped.agg({"Distance": "mean"}).reset_index()

dfGrouped.to_excel("./output_requirements_distances_g.xlsx", index=False)

# %%
# now check the minimum distance per section and document
dfGrouped = dfGrouped.sort_values(by=["Section", "Document", "Distance"])

dfGrouped = dfGrouped.groupby(["Section", "Document"]).first().reset_index()

dfGrouped.to_excel("./output_requirements_distances_g_min.xlsx", index=False)

# %%
# now we turn this into a list of lists
lstRelevantDist = dfGrouped.values.tolist()

print(len(lstRelevantDist))
# Out:
# 258

# %%
# convert to dataframe and save to excel lstRelevantDist
dfRelevantDist = pd.DataFrame(lstRelevantDist, columns=["Section", "Document", "Requirement", "Content", "Distance"])

dfRelevantDist.to_excel("./output_requirements_temp.xlsx", index=False)

# %% [markdown]
# ## Step 4: Check if the requirements exist in the database
#
# In this step, we check if the text that we identified so far is covered by the requirements that exist in the database. We use the sentence transformers to get the embeddings of the text and then we compare them to the existin sections.

# %%
thresholdPartial = 0.2
thresholdCovered = 1.0

# %%
# read the requirements from the Excel file
dfRelevantSections = pd.read_excel("./output_requirements_temp.xlsx")

lstRelevantSections = dfRelevantSections.values.tolist()

# %%
lstRelevantSections[0]
# Out:
# ['<h1>B.1\tLCS privacy selection flow rule</h1>',
#  '23273-i20.docx',
#  'LR4_calculation',
#  '[\'\', \'A 5GS-MT-LR may be applied to more than one LCS privacy data in the LCS privacy profile, e.g. one or more privacy classes as defined in clause\\xa05.4.2.2 and LPI as defined in clause\\xa05.4.2.3. The 5GS-MT-LR may also require POI as defined in clause\\xa05.4.4. The Privacy selection flow is shown in Figure B.1-1.\', \'\', \'----media/image63.emf----\', \'\', \'Figure B.1-1: Privacy selection flow diagram\', \'\', \'\', \'\', \'\', \'Annex C (informative):\', \'PNI-NPN architecture to support location service with signalling optimisation\', \'\', \'Figure C-1 shows the PNI-NPN architecture to support location services with optimisation of signalling latency and privacy, with the corresponding functional descriptions are defined in clause\\xa05.13.\', \'\', \'When UE access the NG-RAN in the local network, during the registration procedure or service request procedure, NG-RAN selects the Serving AMF in the public network. With appropriate configuration, local AMF cannot be selected as the serving AMF for the UE.\', \'\', \'Assuming NG-RAN 1 is the serving RAN of UE. NG-RAN 2 and NG-RAN 3 illustrated in the figure below is for positioning signal measurement.\', \'\', \'----media/image64.emf----\', \'\', \'Figure C-1 PNI-NPN architecture to support location service with signalling optimisation\', \'\', \'\', \'Annex D (informative):\', \'Change history\', \'\', \'<b>Change history</b>\', \'\', \'<span style="font-size:16pt"><b>Date</b></span>\', \'\', \'<span style="font-size:16pt"><b>Meeting</b></span>\', \'\', \'<span style="font-size:16pt"><b>TDoc</b></span>\', \'\', \'<span style="font-size:16pt"><b>CR</b></span>\', \'\', \'<span style="font-size:16pt"><b>Rev</b></span>\', \'\', \'<span style="font-size:16pt"><b>Cat</b></span>\', \'\', \'<span style="font-size:16pt"><b>Subject/Comment</b></span>\', \'\', \'<span style="font-size:16pt"><b>New version</b></span>\', \'\', \'<span style="color:0000FF;font-size:16pt">2019-05</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">SP#84</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">SP-190455</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">MCC Editorial update for presentation to TSG SA#84 for approval</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">1.0.0</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">2019-06</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">SP#84</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">MCC editorial update for publication after approval at TSG SA#84</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">16.0.0</span>\', \'\', \'<span style="font-size:16pt">2019-09</span>\', \'\', \'<span style="font-size:16pt">SP#85</span>\', \'\', \'<span style="font-size:16pt">SP-190606</span>\', \'\', \'<span style="font-size:16pt">0001 </span>\', \'\', \'<span style="font-size:16pt">1</span>\', \'\', \'<span style="font-size:16pt">F</span>\', \'\', \'<span style="font-size:16pt">Correction on UE Assisted and UE Based Positioning Procedure</span>\', \'\', \'<span style="font-size:16pt">16.1.0</span>\', \'\', \'<span style="font-size:16pt">2019-09</span>\', \'\', \'<span style="font-size:16pt">SP#85</span>\', \'\', \'<span style="font-size:16pt">SP-190606</span>\', \'\', \'<span style="font-size:16pt">0002</span>\', \'\', \'<span style="font-size:16pt">1</span>\', \'\', \'<span style="font-size:16pt">F</span>\', \'\', \'<span style="font-size:16pt">Correction on LCS privacy selection flow rule</span>\', \'\', \'<span style="font-size:16pt">16.1.0</span>\ ...
#  0.2575731267790252]

# %%
model = SentenceTransformer("sentence-t5-large")

# list with all embeddings for the sections
lstRelevantEmbeddings = []
iCounter = 0

for oneLine in tqdm(lstRelevantSections):

    # the content of the section starts on the third position of the list
    sentences = oneLine[3]

    # Sentences are encoded by calling model.encode()
    embeddings = model.encode(sentences)
    
    # Print the average embeddings for all the sentences 
    # in this section
    # avg_embedding = np.mean(embeddings, axis=0)
    
    lstOneLine = [oneLine[0], oneLine[1], 2, str(sentences).replace("$", "_").replace("\n", "_"), embeddings]

    lstRelevantEmbeddings.append(lstOneLine)

    iCounter += 1
# Out:
#   0%|          | 0/258 [00:08<?, ?it/s]

# %%
# now, read the requirements from the requirements database, file 20_requirements.xlsx
dfTRequirements = pd.read_excel("20_requirements.xlsx")

# convert to list
lstTRequirements = dfTRequirements.values.tolist()

# %%
lstTRequirements[0]
# Out:
# ['Req_1',
#  'Regarding support for infrastructure protection of electrical transmission, the 5G system shall support an end-to-end latency of less than 5 ms or 10 ms, as requested by the UE initiating the communication. ',
#  'NOTE 1: This requirement relates to TS 22.104, chapter 5.6C Support for infrastructure protection of electrical transmission.\nNOTE 2: Whether the end-to-end latency is 5 ms or 10 ms depends on the applied voltage level. \nNOTE 3: The end-to-end latency is between two UEs, including two wireless links.',
#  'Payload',
#  nan]

# %%
# make the embeddings
model = SentenceTransformer("sentence-t5-large")

# list with all embeddings for the sections
lstTRequirementsEmbeddings = []
iCounter = 0

for oneLine in tqdm(lstTRequirements):

    # the content of the section starts on the requirement text
    sentences = oneLine[1]

    # Sentences are encoded by calling model.encode()
    embeddings = model.encode(sentences)
    
    # Print the average embeddings for all the sentences 
    # in this section
    #avg_embedding = np.mean(embeddings, axis=0)
    
    lstOneLine = [oneLine[0], oneLine[1], 2, str(sentences).replace("$", "_").replace("\n", "_"), embeddings]

    lstTRequirementsEmbeddings.append(lstOneLine)

    iCounter += 1
# Out:
# 100%|██████████| 20/20 [00:02<00:00,  9.21it/s]

# %%
# average the embeddings for all the lstTRequirementsEmbeddings
lstTRequirementsEmbeddingsNP = np.array([x[4] for x in lstTRequirementsEmbeddings])

tRequirementsAvgEmbeddings = np.mean(lstTRequirementsEmbeddingsNP, axis=0)

# %%
# now, calculate the average distance of all the relevant sections to the average requirements
lstDist = []

for oneLine in tqdm(lstRelevantEmbeddings):
    # euclidean distance between the two embeddings
    dist = distance.cosine(oneLine[4], tRequirementsAvgEmbeddings)
    lstDist.append([oneLine[0], oneLine[1], dist, oneLine[3]])

# now we sort the list by the distance
lstDist.sort(key=lambda x: x[3])
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 1918.71it/s]

# %%
lstDist[0]
# Out:
# ['<h1>B.1\tLCS privacy selection flow rule</h1>',
#  '23273-i20.docx',
#  0.13935287230814453,
#  '[\'\', \'A 5GS-MT-LR may be applied to more than one LCS privacy data in the LCS privacy profile, e.g. one or more privacy classes as defined in clause\\xa05.4.2.2 and LPI as defined in clause\\xa05.4.2.3. The 5GS-MT-LR may also require POI as defined in clause\\xa05.4.4. The Privacy selection flow is shown in Figure B.1-1.\', \'\', \'----media/image63.emf----\', \'\', \'Figure B.1-1: Privacy selection flow diagram\', \'\', \'\', \'\', \'\', \'Annex C (informative):\', \'PNI-NPN architecture to support location service with signalling optimisation\', \'\', \'Figure C-1 shows the PNI-NPN architecture to support location services with optimisation of signalling latency and privacy, with the corresponding functional descriptions are defined in clause\\xa05.13.\', \'\', \'When UE access the NG-RAN in the local network, during the registration procedure or service request procedure, NG-RAN selects the Serving AMF in the public network. With appropriate configuration, local AMF cannot be selected as the serving AMF for the UE.\', \'\', \'Assuming NG-RAN 1 is the serving RAN of UE. NG-RAN 2 and NG-RAN 3 illustrated in the figure below is for positioning signal measurement.\', \'\', \'----media/image64.emf----\', \'\', \'Figure C-1 PNI-NPN architecture to support location service with signalling optimisation\', \'\', \'\', \'Annex D (informative):\', \'Change history\', \'\', \'<b>Change history</b>\', \'\', \'<span style="font-size:16pt"><b>Date</b></span>\', \'\', \'<span style="font-size:16pt"><b>Meeting</b></span>\', \'\', \'<span style="font-size:16pt"><b>TDoc</b></span>\', \'\', \'<span style="font-size:16pt"><b>CR</b></span>\', \'\', \'<span style="font-size:16pt"><b>Rev</b></span>\', \'\', \'<span style="font-size:16pt"><b>Cat</b></span>\', \'\', \'<span style="font-size:16pt"><b>Subject/Comment</b></span>\', \'\', \'<span style="font-size:16pt"><b>New version</b></span>\', \'\', \'<span style="color:0000FF;font-size:16pt">2019-05</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">SP#84</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">SP-190455</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">MCC Editorial update for presentation to TSG SA#84 for approval</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">1.0.0</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">2019-06</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">SP#84</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">MCC editorial update for publication after approval at TSG SA#84</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">16.0.0</span>\', \'\', \'<span style="font-size:16pt">2019-09</span>\', \'\', \'<span style="font-size:16pt">SP#85</span>\', \'\', \'<span style="font-size:16pt">SP-190606</span>\', \'\', \'<span style="font-size:16pt">0001 </span>\', \'\', \'<span style="font-size:16pt">1</span>\', \'\', \'<span style="font-size:16pt">F</span>\', \'\', \'<span style="font-size:16pt">Correction on UE Assisted and UE Based Positioning Procedure</span>\', \'\', \'<span style="font-size:16pt">16.1.0</span>\', \'\', \'<span style="font-size:16pt">2019-09</span>\', \'\', \'<span style="font-size:16pt">SP#85</span>\', \'\', \'<span style="font-size:16pt">SP-190606</span>\', \'\', \'<span style="font-size:16pt">0002</span>\', \'\', \'<span style="font-size:16pt">1</span>\', \'\', \'<span style="font-size:16pt">F</span>\', \'\', \'<span style="font-size:16pt">Correction on LCS privacy selection flow rule</span>\', \'\', \'<span style="font-size:16pt">16.1.0</span>\ ...

# %%
# Visualize the results using the scatter plot, where
# the x-axis is the distance to the average requirement
# the y-axis is always 1
# the color is red for the requirements

# Create a color map based on x[2]
color_map = {0: 'blue', 1: 'green', 2: 'red'}
colors = [color_map[0] for x in lstDist]

# we plot the t-SNE results
plt.figure(figsize=(16,10))

random.seed(42)

plt.scatter([x[2] for x in lstDist], [random.random() * 2 for x in lstDist], c=colors, s=100, alpha=0.5)

# Add labels to each dot
#for i, label in enumerate([x[3] for x in lstDist]):
#    plt.text([x[2] for x in lstDist][i], 1, label[:20]+'...', rotation='vertical')

# Add vertical lines at 0.33 and 1.0
plt.axvline(x=thresholdPartial, color='orange', linestyle='--')
plt.axvline(x=thresholdCovered, color='red', linestyle='--')

# Set the limits of the x-axis
plt.xlim(0, 2)
plt.ylim(0, 2)

plt.show()

# %%
# now we separate them into three lists:
# - with distance below 0.33 -- these requirements are covered
# - with distance between 0.33 and 1.0 -- these requirements are partially covered
# - with distance above 1.0 -- these requirements are not covered

lstCovered = []
lstPartiallyCovered = []
lstNotCovered = []

for oneLine in lstDist:
    if oneLine[2] < thresholdPartial:
        lstCovered.append(oneLine)
    elif oneLine[2] < thresholdCovered:
        lstPartiallyCovered.append(oneLine)
    else:
        lstNotCovered.append(oneLine)

# %% [markdown]
# ## Step 5: create requirements based on each of these sections
#
# In the last step, we create new requirements based on the sections identified in the previous steps.

# %%
torch.random.manual_seed(0)

modelInstr = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3-mini-4k-instruct", 
    device_map="cuda", 
    torch_dtype="auto", 
    trust_remote_code=True, 
)
tokenizerInstr = AutoTokenizer.from_pretrained("microsoft/Phi-3-mini-4k-instruct")
# Out:
# `flash-attention` package not found, consider installing for better performance: No module named 'flash_attn'.
# Current `flash-attenton` does not support `window_size`. Either upgrade or use `attn_implementation='eager'`.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
def createRequirement(content, type, model, tokenizer):
    content1 = content.split(",")
    content1 = [x for x in content1[1:] if x not in ['', " ''", " '']"]]
    content_str = " ".join(content1)
    
    strContent = f"Based on this : {content_str}. Write the requirement in the following format 'The system shall ' "
    
    messages = [
        {"role": "user", "content": strContent},
    ]

    pipe = pipeline(
        "text-generation",
        model=model,
        tokenizer=tokenizer,
    )

    generation_args = {
        "max_new_tokens": 500,
        "return_full_text": False,
        "temperature": 0.0,
        "do_sample": False,
    }

    output = pipe(messages, **generation_args)
    
    return output[0]['generated_text']

# %%
lstGenerated = []
iCounter = 0

# we generate new requirements for the partially covered ones
if len(lstPartiallyCovered) > 0:
    for oneLine in tqdm(lstPartiallyCovered):
        iCounter += 1
        strRequirement = createRequirement(oneLine[3], oneLine[2], modelInstr, tokenizerInstr)
        lstGenerated.append([oneLine[0], oneLine[1], oneLine[2], oneLine[3], strRequirement])
        if iCounter % 10 == 0:
            # convert the list to a dataframe and save to excel
            dfOutput = pd.DataFrame(lstGenerated, columns=["Section", "Document", "Requirement type", "Content", "Distance", "Generated requirements"])
            dfOutput.to_excel("./output_partially_covered_generated_cont.xlsx", index=False)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Hmmm
# [" 'A 5GS-MT-LR may be applied to more than one LCS privacy data in the LCS privacy profile", " e.g. one or more privacy classes as defined in clause\\xa05.4.2.2 and LPI as defined in clause\\xa05.4.2.3. The 5GS-MT-LR may also require POI as defined in clause\\xa05.4.4. The Privacy selection flow is shown in Figure B.1-1.'", " '----media/image63.emf----'", " 'Figure B.1-1: Privacy selection flow diagram'", " 'Annex C (informative):'", " 'PNI-NPN architecture to support location service with signalling optimisation'", " 'Figure C-1 shows the PNI-NPN architecture to support location services with optimisation of signalling latency and privacy", " with the corresponding functional descriptions are defined in clause\\xa05.13.'", " 'When UE access the NG-RAN in the local network", ' during the registration procedure or service request procedure', ' NG-RAN selects the Serving AMF in the public network. With appropriate configuration', " local AMF cannot be selected as the serving AMF for the UE.'", " 'Assuming NG-RAN 1 is the serving RAN of UE. NG-RAN 2 and NG-RAN 3 illustrated in the figure below is for positioning signal measurement.'", " '----media/image64.emf----'", " 'Figure C-1 PNI-NPN architecture to support location service with signalling optimisation'", " 'Annex D (informative):'", " 'Change history'", " '<b>Change history</b>'", ' \'<span style="font-size:16pt"><b>Date</b></span>\'', ' \'<span style="font-size:16pt"><b>Meeting</b></span>\'', ' \'<span style="font-size:16pt"><b>TDoc</b></span>\'', ' \'<span style="font-size:16pt"><b>CR</b></span>\'', ' \'<span style="font-size:16pt"><b>Rev</b></span>\'', ' \'<span style="font-size:16pt"><b>Cat</b></span>\'', ' \'<span style="font-size:16pt"><b>Subject/Comment</b></span>\'', ' \'<span style="font-size:16pt"><b>New version</b></span>\'', ' \'<span style="color:0000FF;font-size:16pt">2019-05</span>\'', ' \'<span style="color:0000FF;font-size:16pt">SP#84</span>\'', ' \'<span style="color:0000FF;font-size:16pt">SP-190455</span>\'', ' \'<span style="color:0000FF;font-size:16pt">-</span>\'', ' \'<span style="color:0000FF;font-size:16pt">-</span>\'', ' \'<span style="color:0000FF;font-size:16pt">-</span>\'', ' \'<span style="color:0000FF;font-size:16pt">MCC Editorial update for presentation to TSG SA#84 for approval</span>\'', ' \'<span style="color:0000FF;font-size:16pt">1.0.0</span>\'', ' \'<span style="color:0000FF;font-size:16pt">2019-06</span>\'', ' \'<span style="color:0000FF;font-size:16pt">SP#84</span>\'', ' \'<span style="color:0000FF;font-size:16pt">-</span>\'', ' \'<span style="color:0000FF;font-size:16pt">-</span>\'', ' \'<span style="color:0000FF;font-size:16pt">-</span>\'', ' \'<span style="color:0000FF;font-size:16pt">-</span>\'', ' \'<span style="color:0000FF;font-size:16pt">MCC editorial update for publication after approval at TSG SA#84</span>\'', ' \'<span style="color:0000FF;font-size:16pt">16.0.0</span>\'', ' \'<span style="font-size:16pt">2019-09</span>\'', ' \'<span style="font-size:16pt">SP#85</span>\'', ' \'<span style="font-size:16pt">SP-190606</span>\'', ' \'<span style="font-size:16pt">0001 </span>\'', ' \'<span style="font-size:16pt">1</span>\'', ' \'<span style="font-size:16pt">F</span>\'', ' \'<span style="font-size:16pt">Correction on UE Assisted and UE Based Positioning Procedure</span>\'', ' \'<span style="font-size:16pt">16.1.0</span>\'', ' \'<span style="font-size:16pt">2019-09</span>\'', ' \'<span style="font-size:16pt">SP#85</span>\'', ' \'<span style="font-size:16pt">SP-190606</span>\'', ' \'<span style="font-size:16pt">0002</span>\'', ' \'<span style="font-size:16pt">1</span>\'', ' \'<span style="font-size:16pt">F</span>\'', ' \'<span style="font-size:16pt">Correction on LCS privacy selection flow rule</span>\'', ' \'<span style="font-size:16pt">16.1.0</span>\'', ' \'<span style="font-size:16pt">2019-09</span>\'', ' \'<span style="font-size:16pt">SP#85</span>\'', ' \'<span style="font-size:16pt">SP-190606</span>\'', ' \'<span style="font-siz ...
# Based on this :  'A 5GS-MT-LR may be applied to more than one LCS privacy data in the LCS privacy profile  e.g. one or more privacy classes as defined in clause\xa05.4.2.2 and LPI as defined in clause\xa05.4.2.3. The. Write the requirement in the following format 'The system shall '
# /mnt/d/venvs/standards/lib/python3.11/site-packages/transformers/generation/configuration_utils.py:410: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# You are not running the flash-attention implementation, expect numerical differences.
#   0%|          | 0/1 [04:32<?, ?it/s]

# %%
# we generate new requirements for the not covered requirements
if len(lstNotCovered) > 0:
    for oneLine in tqdm(lstNotCovered):
        iCounter += 1
        if (len(oneLine[3]) < 10000):
            strRequirement = createRequirement(oneLine[3], oneLine[2], modelInstr, tokenizerInstr)
            lstGenerated.append([oneLine[0], oneLine[1], oneLine[2], oneLine[3], strRequirement])
        if iCounter % 10 == 0:
            # convert the list to a dataframe and save to excel
            dfOutput = pd.DataFrame(lstGenerated, columns=["Section", "Document", "Requirement type", "Content", "Distance", "Generated requirements"])
            dfOutput.to_excel("./output_partially_covered_generated_cont.xlsx", index=False)

# %%
dfOutput = pd.DataFrame(lstGenerated, columns=["Section", "Document", "Content", "Distance", "Generated requirements"])
dfOutput.to_excel("./output_partially_covered_generated.xlsx", index=False)

# %%
lstGenerated[0]
# Out:
# ['<h1>B.1\tLCS privacy selection flow rule</h1>',
#  '23273-i20.docx',
#  0.13935287230814453,
#  '[\'\', \'A 5GS-MT-LR may be applied to more than one LCS privacy data in the LCS privacy profile, e.g. one or more privacy classes as defined in clause\\xa05.4.2.2 and LPI as defined in clause\\xa05.4.2.3. The 5GS-MT-LR may also require POI as defined in clause\\xa05.4.4. The Privacy selection flow is shown in Figure B.1-1.\', \'\', \'----media/image63.emf----\', \'\', \'Figure B.1-1: Privacy selection flow diagram\', \'\', \'\', \'\', \'\', \'Annex C (informative):\', \'PNI-NPN architecture to support location service with signalling optimisation\', \'\', \'Figure C-1 shows the PNI-NPN architecture to support location services with optimisation of signalling latency and privacy, with the corresponding functional descriptions are defined in clause\\xa05.13.\', \'\', \'When UE access the NG-RAN in the local network, during the registration procedure or service request procedure, NG-RAN selects the Serving AMF in the public network. With appropriate configuration, local AMF cannot be selected as the serving AMF for the UE.\', \'\', \'Assuming NG-RAN 1 is the serving RAN of UE. NG-RAN 2 and NG-RAN 3 illustrated in the figure below is for positioning signal measurement.\', \'\', \'----media/image64.emf----\', \'\', \'Figure C-1 PNI-NPN architecture to support location service with signalling optimisation\', \'\', \'\', \'Annex D (informative):\', \'Change history\', \'\', \'<b>Change history</b>\', \'\', \'<span style="font-size:16pt"><b>Date</b></span>\', \'\', \'<span style="font-size:16pt"><b>Meeting</b></span>\', \'\', \'<span style="font-size:16pt"><b>TDoc</b></span>\', \'\', \'<span style="font-size:16pt"><b>CR</b></span>\', \'\', \'<span style="font-size:16pt"><b>Rev</b></span>\', \'\', \'<span style="font-size:16pt"><b>Cat</b></span>\', \'\', \'<span style="font-size:16pt"><b>Subject/Comment</b></span>\', \'\', \'<span style="font-size:16pt"><b>New version</b></span>\', \'\', \'<span style="color:0000FF;font-size:16pt">2019-05</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">SP#84</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">SP-190455</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">MCC Editorial update for presentation to TSG SA#84 for approval</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">1.0.0</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">2019-06</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">SP#84</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">MCC editorial update for publication after approval at TSG SA#84</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">16.0.0</span>\', \'\', \'<span style="font-size:16pt">2019-09</span>\', \'\', \'<span style="font-size:16pt">SP#85</span>\', \'\', \'<span style="font-size:16pt">SP-190606</span>\', \'\', \'<span style="font-size:16pt">0001 </span>\', \'\', \'<span style="font-size:16pt">1</span>\', \'\', \'<span style="font-size:16pt">F</span>\', \'\', \'<span style="font-size:16pt">Correction on UE Assisted and UE Based Positioning Procedure</span>\', \'\', \'<span style="font-size:16pt">16.1.0</span>\', \'\', \'<span style="font-size:16pt">2019-09</span>\', \'\', \'<span style="font-size:16pt">SP#85</span>\', \'\', \'<span style="font-size:16pt">SP-190606</span>\', \'\', \'<span style="font-size:16pt">0002</span>\', \'\', \'<span style="font-size:16pt">1</span>\', \'\', \'<span style="font-size:16pt">F</span>\', \'\', \'<span style="font-size:16pt">Correction on LCS privacy selection flow rule</span>\', \'\', \'<span style="font-size:16pt">16.1.0</span>\ ...
#  ' The system shall allow the application of a 5GS-MT-LR privacy setting to multiple privacy classes within the LCS privacy profile, as specified in clause 5.4.2.2, and to one or more LPIs (Lawful Processing Impacts) as defined in clause 5.4.2.3.']
