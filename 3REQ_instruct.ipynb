# %% [markdown]
# # 3REQ system
#
# Requirement analysis system.
#
# The flow is presented in the following figure:
#
# <img src="flow.png" alt="drawing" width="700"/>
#
# Summary:
# 1. Extract sections that contain words like "latency"
# 2. Find if they resemble requirements or not
# 3. Check if they are specific kinds of requirements (like signalling)
# 4. Write new requirements based on the text in these sections.

# %%
# Importing required libraries

# docx2python is used to extract text, images, tables, and other data from .docx files
from docx2python import docx2python

# os module provides functions for interacting with the operating system
import os

# numpy is used for mathematical operations on large, multi-dimensional arrays and matrices
import numpy as np

# pandas is used for data manipulation and analysis
import pandas as pd

# TSNE from sklearn.manifold is used for dimensionality reduction
from sklearn.manifold import TSNE

# matplotlib.pyplot is used for creating static, animated, and interactive visualizations in Python
import matplotlib.pyplot as plt

# SentenceTransformer is used for training and using transformer models for generating sentence embeddings
from sentence_transformers import SentenceTransformer

# tqdm is used to make loops show a smart progress meter
from tqdm import tqdm

# torch is the main package in PyTorch, it provides a multi-dimensional array with support for autograd operations like backward()
import torch

# AutoModelForCausalLM, AutoTokenizer, pipeline are from the transformers library by Hugging Face which provides state-of-the-art machine learning models like BERT, GPT-2, etc.
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# euclidean distance and cosine distance
from scipy.spatial import distance

# random generator for the last figure
import random

# %%
# suppress warnings
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Step 1: List the documents's sections with "latency"
#
# In the first step, we go through the documents in the folder "input_standards" and we extract which sections of these documents contain th word "latency". We store the results in a dictionary.

# %%
def extractLatencySections(doc):
    strSectionTitle = ""
    dictSections = {}
    listLatency = []
    skippedSections = 0

    doc_result = docx2python(doc,paragraph_styles = True, html=True)

    # we iterate over all lines
    # look for the section titles (which have the tag <h1>, <h2>, <h3>, etc.)
    # then we add the content of each section to the dictionary
    # and if there is a word "latency" somewhere in the section, we add the section title to the listLatency
    for oneLine in tqdm(doc_result.text.split('\n')):
        if "<h" in oneLine:
            strSectionTitle = oneLine
            dictSections[strSectionTitle] = []

        if strSectionTitle != "":  
            dictSections[strSectionTitle].append(oneLine)

        keywordsInLine = ["latency", "latencies", "delay"]
        keywordsInSections = ["references", "introduction", "definition", "abstract", "conclusion", "acknowledgements", "appendix", "table of contents", "table of figures", "table of tables", "table of contents", "table of figures", "table of tables", "bibliography", "index", "glossary", "list of figures", "list of tables", "list of abbreviations", "list of symbols", "list of terms", "list of equations", "list of algorithms", "list of acronyms", "list of illustrations", "list of appendices"]

        if any(word in oneLine.lower() for word in keywordsInLine) and not any(word in strSectionTitle.lower() for word in keywordsInSections): 
            listLatency.append(strSectionTitle)
        else:
            skippedSections += 1

            
    # remove the keys from the dictionary if they are not part of the listLatency
    # as we want to get only the relevant sections, i.e., the one with the word latency
    for key in list(dictSections.keys()):
        if key not in listLatency:
            del dictSections[key]

    # print("Skipped sections: ", skippedSections)

    # return the dictionary with the relevant sections
    return dictSections

# %%
docInputFolder = "./23_standards"

# this is the return list of all the lines in the document
lstAllLines = []

# for each .docx file in the input folder
# extract the sections with latency using the extractLatencySections function
# and print the sections
for doc in tqdm(os.listdir(docInputFolder)):    

    if doc.endswith(".docx"):
        #print(f"Processing {doc}")

        # since things can go wrong with the latency library, 
        # we use a try except block to avoid the program to stop
        try: 
            dictSections = extractLatencySections(os.path.join(docInputFolder, doc))
        
            # we list the content
            # as a long list of sections 
            for key in dictSections:

                lstOneLine = [key, doc]

                for line in dictSections[key]:
                    lstOneLine.append(line)
                    
                lstAllLines.append(lstOneLine)

        except Exception as e:
            print(f"Error with {doc}: {e}")
# Out:
# 100%|██████████| 13952/13952 [00:00<00:00, 454071.58it/s]
# 100%|██████████| 25005/25005 [00:00<00:00, 683782.58it/s]
# 100%|██████████| 2171/2171 [00:00<00:00, 719373.83it/s]
# 100%|██████████| 17829/17829 [00:00<00:00, 727462.61it/s]
# 100%|██████████| 20633/20633 [00:00<00:00, 717433.01it/s]
# 100%|██████████| 9996/9996 [00:00<00:00, 610715.98it/s]
# 100%|██████████| 995/995 [00:00<00:00, 554816.87it/s]
# 100%|██████████| 17526/17526 [00:00<00:00, 718777.47it/s]
# 100%|██████████| 1025/1025 [00:00<00:00, 953462.32it/s]
# 100%|██████████| 4646/4646 [00:00<00:00, 717188.78it/s]
# 100%|██████████| 7526/7526 [00:00<00:00, 677621.76it/s]
# 100%|██████████| 4133/4133 [00:00<00:00, 713846.91it/s]
# 100%|██████████| 8896/8896 [00:00<00:00, 539877.13it/s]
# 100%|██████████| 4221/4221 [00:00<00:00, 753176.09it/s]
# 100%|██████████| 23365/23365 [00:00<00:00, 707994.66it/s]
# 100%|██████████| 5611/5611 [00:00<00:00, 656738.94it/s]
# 100%|██████████| 7979/7979 [00:00<00:00, 612443.30it/s]
# 100%|██████████| 5327/5327 [00:00<00:00, 663254.59it/s]
# 100%|██████████| 2991/2991 [00:00<00:00, 624572.50it/s]
# 100%|██████████| 4453/4453 [00:00<00:00, 770735.60it/s]
# 100%|██████████| 18108/18108 [00:00<00:00, 776295.85it/s]
# 100%|██████████| 8476/8476 [00:00<00:00, 787291.18it/s]
# 100%|██████████| 4412/4412 [00:00<00:00, 765313.04it/s]
# 100%|██████████| 64744/64744 [00:00<00:00, 772407.33it/s]
# 100%|██████████| 70210/70210 [00:00<00:00, 758935.32it/s]
# 100%|██████████| 70210/70210 [00:00<00:00, 599486.35it/s]
# 100%|██████████| 17918/17918 [00:00<00:00, 389711.58it/s]
# 100%|██████████| 2419/2419 [00:00<00:00, 552314.72it/s]
# 100%|██████████| 1933/1933 [00:00<00:00, 247401.35it/s]
# 100%|██████████| 7282/7282 [00:00<00:00, 164835.81it/s]
# 100%|██████████| 1587/1587 [00:00<00:00, 133763.93it/s]
# 100%|██████████| 3820/3820 [00:00<00:00, 369201.59it/s]
# 100%|██████████| 9286/9286 [00:00<00:00, 909688.36it/s]
# 100%|██████████| 21731/21731 [00:00<00:00, 841563.90it/s]
# 100%|██████████| 1885/1885 [00:00<00:00, 544358.51it/s]
# 100%|██████████| 2947/2947 [00:00<00:00, 773602.07it/s]
# 100%|██████████| 38/38 [01:23<00:00,  2.20s/it]

# %%
# model = SentenceTransformer("all-MiniLM-L6-v2")
# model = SentenceTransformer("sentence-transformers/gtr-t5-xxl")
model = SentenceTransformer("sentence-t5-large")

# list with all embeddings for the sections
lstEmbeddings = []
iCounter = 0

for oneLine in tqdm(lstAllLines):

    # the content of the section starts on the third position of the list
    sentences = oneLine[3:]

    # Sentences are encoded by calling model.encode()
    embeddings = model.encode(sentences)
    
    # Print the average embeddings for all the sentences 
    # in this section
    avg_embeddings = embeddings.mean(axis=0)
    
    lstOneLine = [oneLine[0], oneLine[1], 2, str(sentences).replace("$", "_").replace("\n", "_"), avg_embeddings]

    lstEmbeddings.append(lstOneLine)

    iCounter += 1
    # the code below is for debug only
    # in case we want to stop the loop after a certain number of iterations
    #if iCounter == 100:
    #    break
# Out:
# 100%|██████████| 308/308 [03:48<00:00,  1.35it/s]

# %%
# let's plot these average embeddings using t-SNE

# we create a list with the embeddings
lstEmbeddingsNP = np.array([x[4] for x in lstEmbeddings])

# we use t-SNE to reduce the dimensionality of the embeddings
tsne = TSNE(n_components=2, verbose=0, perplexity=12, n_iter=300)
tsne_results = tsne.fit_transform(lstEmbeddingsNP)

# we plot the t-SNE results
plt.figure(figsize=(16,10))

plt.scatter(tsne_results[:,0], tsne_results[:,1])

# Add labels to each dot
for i, label in enumerate([x[0] for x in lstEmbeddings]):
    plt.text(tsne_results[i, 0], tsne_results[i, 1], label[3:10])


plt.show()

# %% [markdown]
# ## Step 2: Find the relevant sections
#
# In this step, we take the sections identified in Step 1 and we compare them to a list of right and wrong requirements. The list is stored in the file List.xlsx

# %%
# open the file List.xlsx using pandas
# and read the workshop NR
df = pd.read_excel("req_classes.xlsx", sheet_name="R_NR")

# convert the dataframe to a list of lists
lstReference = df.values.tolist()

lstReference[0]
# Out:
# ['L4S (Low Latency, Low Loss and Scalable Throughput) is described in IETF RFC 9330, IETF RFC 9331 and IETF RFC 9332.',
#  1]

# %%
# list with all embeddings for the sections
lstEmbeddingsRef = []

for oneLine in tqdm(lstReference):

    # the content of the section starts on the third position of the list
    sentences = oneLine[0]

    # Sentences are encoded by calling model.encode()
    embeddings = model.encode(sentences)
    
    # Print the average embeddings for all the sentences 
    # in this section
    avg_embedding = embeddings
    
    lstOneLine = [oneLine[0], 'REF', oneLine[1], oneLine[1], avg_embedding]

    lstEmbeddingsRef.append(lstOneLine)
# Out:
# 100%|██████████| 55/55 [00:01<00:00, 38.88it/s]

# %%
# concatenate the two lists
lstEmbeddingsAll = lstEmbeddings + lstEmbeddingsRef

# %%
# let's plot these average embeddings using t-SNE

# we create a list with the embeddings
lstEmbeddingsNP = np.array([x[4] for x in lstEmbeddingsAll])

# we use t-SNE to reduce the dimensionality of the embeddings
tsne = TSNE(n_components=2, verbose=0, perplexity=12, n_iter=300)
tsne_results = tsne.fit_transform(lstEmbeddingsNP)

# Create a color map based on x[2]
color_map = {0: 'red', 1: 'green', 2: 'blue'}
colors = [color_map[x[2]] for x in lstEmbeddingsAll]

# we plot the t-SNE results
plt.figure(figsize=(16,10))

plt.scatter(tsne_results[:,0], tsne_results[:,1],c=colors, s=100, alpha=0.5)

# Add labels to each dot
for i, label in enumerate([x[0] for x in lstEmbeddingsAll]):
    plt.text(tsne_results[i, 0], tsne_results[i, 1], label[:10]+'...')


plt.show()

# %%
from sklearn.metrics.pairwise import euclidean_distances

# for each line in lstEmbeddings
# we calculate the euclidean distance with each line in lstEmbeddingsRef

lstDistPos = []
lstDistNeg = []

lstRelevant = []

for oneLine in tqdm(lstEmbeddings):    
    for oneLineRef in lstEmbeddingsRef:
        if oneLineRef[2] == 1:
            # euclidean distance between the two embeddings
            dist = distance.cosine(oneLine[4], oneLineRef[4])
            lstDistPos.append(dist)
        if oneLineRef[2] == 0:
            # euclidean distance between the two embeddings
            dist = distance.cosine(oneLine[4], oneLineRef[4])
            lstDistNeg.append(dist)
    
    # now calculate the average for both lists
    avgDistPos = np.mean(lstDistPos)
    avgDistNeg = np.mean(lstDistNeg)

    if avgDistPos < avgDistNeg:
        #print(f"Section {oneLine[0]} is relevant")
        # add the class to the list
        oneLine.append(1)
        lstRelevant.append(oneLine)
    else:
        #print(f"Section {oneLine[0]} is not relevant")
        # add the class to the list
        oneLine.append(0)
# Out:
# 100%|██████████| 308/308 [00:00<00:00, 1711.00it/s]

# %%
print(f'Relevant sections: {len(lstRelevant)}')
# Out:
# Relevant sections: 308

# %%
lstEmbeddings[0]
# Out:
# ['<h4>4.1a.5.1\tTypes of event</h4>',
#  '23273-i20.docx',
#  2,
#  "['', 'The following types of event are defined for a deferred location request.', '', 'a)\\tUE availability: Any event in which the 5GCN has established a contact with the UE. This event is considered to be applicable when the UE is temporarily unavailable due to inaction by the user, or for temporarily loss of radio connectivity or IMSI detach and so on. The UE Available event only requires one response to an LCS client/AF and after this response, the UE Available event is concluded.', '', 'b)\\tArea: An event where the UE enters, leaves or remains within a pre-defined geographical area. At least one type of area event can be defined (i.e. entering, leaving or remaining within the area). The LCS client or AF may define the target area as a geographical area or as a geopolitical name of an area. The PLMN may translate and define the target area as the identities of one or more radio cells or tracking areas. The LCS client or AF may request an additional check about whether the UE is located within the provisioned target area. The area event may be reported one time only, or multiple times. The area event report shall contain an indication of the event occurrence. The location estimate may be included in the report. If an area event is detected by the UE but an event report cannot be sent (e.g. because the UE cannot access the network or due to a minimum reporting interval), a report shall be sent later when possible irrespective of whether the area event still applies for the current UE location. Area event reporting is controlled by a minimum and a maximum reporting time. The minimum reporting time defines the minimum allowed time between successive area events. The maximum reporting time defines the maximum time between successive reports. When a UE sends a report due to expiration of the maximum reporting time, the UE indicates expiration of the maximum reporting time as the trigger event. The maximum reporting time enables the AF, LCS client and HGMLC to remain aware of continuing support by the UE for the area event (e.g. to detect if area event reporting may have been aborted due to UE power off).', '', 'NOTE:\\tTo achieve more precise usage of area event in some scenario, e.g. for small target area, it may be useful if LCS Client/AF requests UE location estimate and compares the location estimate with the target area.', '', 'c)\\tPeriodic Location: An event where a defined periodic timer expires in the UE and activates a location report. If a periodic event is detected by the UE but an event report cannot be sent (e.g. because the UE cannot access the network temporarily), a report shall be sent later when possible and the periodic timer for the next event shall then be started. The reporting duration for periodic location shall equal the requested number of reports multiplied by the periodic
#          6.47230959e-03, -1.69156156e-02, -3.29721346e-02, -1.14962589e-02,
#          1.00731719e-02, -3.98486061e-03, -2.98521146e-02,  1.74821671e-02,
#          1.42849376e-02, -6.51450828e-02, -9.95361898e-03,  2.35566963e-02,
#          5.80967963e-03, -2.48973034e-02,  1.01522785e-02,  1.12923961e-02,
#          1.33120520e-02,  1.56967100e-02,  2.66636703e-02,  1.97875388e-02,
#         -5.01523688e-02, -1.48514407e-02,  1.40481880e-02,  1.34576112e-02,
#          4.78236862e-02, -3.28191593e-02,  4.20737788e-02,  4.00850922e-02,
#          1.93392895e-02,  4.25154753e-02, -2.46439259e-02, -2.17587687e-02,
#          2.48744301e-02, -4.54161912e-02,  2.02772543e-02, -1.80256031e-02,
#         -5.23833185e-02, -2.10788120e-02, -1.96763873e-02, -1.76605303e-02,
#          2.21565701e-02, -2.45189928e-02,  1.96912922e-02,  3.09415963e-02,
#          3.18299271e-02, -5.51670790e-02, -6.78133443e-02, -2.70938389e-02,
#         -2.42346618e-02,  3.64552140e-02,  3.13365012e-02, -4.37565446e-02,
#         -1.50891775e-02, -3.61551382e-02, -2.32557021e-02,  5.97681925e-02,
#         -1.55600607e-02, -5.77585883e-02,  4.69443351e-02,  6.10011816e-02,
#         -3.14450786e-02,  1.73569545e-02,  4.21474054e-02, -2.64438484e-02,
#          4.70204726e-02,  1.92900021e-02,  2.27004793e-02,  3.97376195e-02,
#          4.06528786e-02, -1.74192116e-02, -3.46006937e-02, -4.14440632e-02,
#         -2.69501526e-02, -1.82475671e-02,  7.76675856e-03,  6.40965179e-02],
#        dtype=float32),
#  1]

# %%
# here we save all the relevant sections to an Excel file
# and the non-relevant ones too
import pandas as pd

dfOutput = pd.DataFrame(lstEmbeddings, columns=["Section", "Document", "Class", "Content", "Embedding", "Relevance"])

dfOutput.to_excel("./output.xlsx", index=False)

# %% [markdown]
# ## Step 3: Find which requirements are impacted
#
# In this step, we compare the relevant sections with the existing requirements. Based on the distance, we can determine which requirements are impacted. The requirements are provided as a separete list.

# %%
print(f'Percentage relevant: {len(lstRelevant)/len(lstEmbeddings)*100:.2f}%')
# Out:
# Percentage relevant: 100.00%

# %%
# read the requirements from the excel file requirements.xlsx, worksheet LR
df = pd.read_excel("req_classes.xlsx", sheet_name="LR")

# convert to list
lstRequirements = df.values.tolist()
lstRequirements[0]

# now we calculate the embeddings for each of these requirements
lstEmbeddingsReq = []

for oneLine in tqdm(lstRequirements):
    
        # the content of the section starts on the third position of the list
        sentences = oneLine[1]
    
        # Sentences are encoded by calling model.encode()
        embeddings = model.encode(sentences)
        
        # Print the average embeddings for all the sentences 
        # in this section
        avg_embedding = embeddings
        
        lstOneLine = [oneLine[0], 'latency', oneLine[1], oneLine[1], avg_embedding]
    
        lstEmbeddingsReq.append(lstOneLine)
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
# 100%|██████████| 16/16 [00:00<00:00, 26.42it/s]

# %%
# now we calculate the euclidean distance between the requirements and the sections
# that are relevant
lstDist = []
lstRelevantDist = []

for oneLine in tqdm(lstRelevant):
    for oneLineReq in lstEmbeddingsReq:
        # euclidean distance between the two embeddings
        dist = distance.cosine(oneLine[4], oneLineReq[4])
        lstDist.append([oneLine[0], oneLine[1], oneLineReq[0], dist, oneLine[3]])

# now we sort the list by the distance
lstDist.sort(key=lambda x: x[2])

# and we print them
for i in range(len(lstDist)):
    print(f"Section {lstDist[i][0]} is close to requirement {lstDist[i][2]} with distance {lstDist[i][3]:.2f}")
    # add this to a list
    lstRelevantDist.append([lstDist[i][0], lstDist[i][1], lstDist[i][2], lstDist[i][3], lstDist[i][4]])

# save the list to an Excel file
dfOutput = pd.DataFrame(lstRelevantDist, columns=["Section", "Document", "Requirement", "Distance", "Content"])

# sort it by section and document
dfOutput = dfOutput.sort_values(by=["Section", "Document"])

dfOutput.to_excel("./output_requirements_distances_b.xlsx", index=False)
# Out:
# 100%|██████████| 308/308 [00:00<00:00, 10679.32it/s]
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR1_signalling with distance 0.20
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h4>4.1a.5.1	Types of event</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR1_signalling with distance 0.21
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR1_signalling with distance 0.21
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR1_signalling with distance 0.18
# Section <h2>4.1b	LCS Quality of Service</h2> is close to requirement LR1_signalling with distance 0.19
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR1_signalling with distance 0.22
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR1_signalling with distance 0.23
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR1_signalling with distance 0.19
# Section <h2>5.1	LMF Discovery and Selection</h2> is close to requirement LR1_signalling with distance 0.19
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR1_signalling with distance 0.19
# Section <h3>6.16.1	Reporting of Location Events to an LCS Client or AF via user plane</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h3>6.18.3	Modification of User Plane Connection between UE and LMF</h3> is close to requirement LR1_signalling with distance 0.19
# Section <h1>B.1	LCS privacy selection flow rule</h1> is close to requirement LR1_signalling with distance 0.26
# Section <h1>B.1	LCS privacy selection flow rule</h1> is close to requirement LR1_signalling with distance 0.27
# Section <h1>B.1	LCS privacy selection flow rule</h1> is close to requirement LR1_signalling with distance 0.25
# Section <h1>B.1	LCS privacy selection flow rule</h1> is close to requirement LR1_signalling with distance 0.26
# Section <h4>5.2.2.2	V2X message reception via MBS</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>5.2.2.2	V2X message reception via MBS</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.2.2.2	V2X message reception via MBS</h4> is close to requirement LR1_signalling with distance 0.18
# Section <h4>5.2.2.2	V2X message reception via MBS</h4> is close to requirement LR1_signalling with distance 0.20
# Section <h4>5.2.3.1	General</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>5.2.3.1	General</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>5.2.3.1	General</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h4>5.2.3.1	General</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h5>5.4.1.1.2	Deriving PC5 QoS parameters and assigning PFI for PC5 QoS Flow</h5> is close to requirement LR1_signalling with distance 0.21
# Section <h5>5.4.1.1.2	Deriving PC5 QoS parameters and assigning PFI for PC5 QoS Flow</h5> is close to requirement LR1_signalling with distance 0.22
# Section <h5>5.4.1.1.2	Deriving PC5 QoS parameters and assigning PFI for PC5 QoS Flow</h5> is close to requirement LR1_signalling with distance 0.17
# Section <h5>5.4.1.1.2	Deriving PC5 QoS parameters and assigning PFI for PC5 QoS Flow</h5> is close to requirement LR1_signalling with distance 0.18
# Section <h4>5.4.3.1	General</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.4.3.1	General</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.4.3.1	General</h4> is close to requirement LR1_signalling with distance 0.18
# Section <h4>5.4.3.1	General</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h4>5.4.3.3	Priority Level</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>5.4.3.3	Priority Level</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.4.3.3	Priority Level</h4> is close to requirement LR1_signalling with distance 0.18
# Section <h4>5.4.3.3	Priority Level</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h4>5.4.3.4	Packet Delay Budget</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.4.3.4	Packet Delay Budget</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>5.4.3.4	Packet Delay Budget</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h4>5.4.3.4	Packet Delay Budget</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h3>5.4.4	Standardized PQI to QoS characteristics mapping</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>5.4.4	Standardized PQI to QoS characteristics mapping</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h3>5.4.4	Standardized PQI to QoS characteristics mapping</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h3>5.4.4	Standardized PQI to QoS characteristics mapping</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h4>5.4.5.1	General</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>5.4.5.1	General</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>5.4.5.1	General</h4> is close to requirement LR1_signalling with distance 0.20
# Section <h4>5.4.5.1	General</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>5.4.5.3	QoS Change based on Extended NG-RAN Notification to support Alternative Service Requirements</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.4.5.3	QoS Change based on Extended NG-RAN Notification to support Alternative Service Requirements</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>5.4.5.3	QoS Change based on Extended NG-RAN Notification to support Alternative Service Requirements</h4> is close to requirement LR1_signalling with distance 0.17
# Section <h4>5.4.5.3	QoS Change based on Extended NG-RAN Notification to support Alternative Service Requirements</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h3>6.1.3	Contents of Analytics Exposure</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h3>6.1.3	Contents of Analytics Exposure</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>6.1.3	Contents of Analytics Exposure</h3> is close to requirement LR1_signalling with distance 0.19
# Section <h3>6.1.3	Contents of Analytics Exposure</h3> is close to requirement LR1_signalling with distance 0.19
# Section <h4>6.1A.3.1	Procedure for analytics aggregation with Provision of Area of Interest</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>6.1A.3.1	Procedure for analytics aggregation with Provision of Area of Interest</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>6.1A.3.1	Procedure for analytics aggregation with Provision of Area of Interest</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h4>6.1A.3.1	Procedure for analytics aggregation with Provision of Area of Interest</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h4>6.1A.3.2	Procedure for Analytics Aggregation without Provision of Area of Interest</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>6.1A.3.2	Procedure for Analytics Aggregation without Provision of Area of Interest</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>6.1A.3.2	Procedure for Analytics Aggregation without Provision of Area of Interest</h4> is close to requirement LR1_signalling with distance 0.20
# Section <h4>6.1A.3.2	Procedure for Analytics Aggregation without Provision of Area of Interest</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h4>6.2C.2.2	General procedure for Federated Learning among Multiple NWDAF Instances</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>6.2C.2.2	General procedure for Federated Learning among Multiple NWDAF Instances</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>6.2C.2.2	General procedure for Federated Learning among Multiple NWDAF Instances</h4> is close to requirement LR1_signalling with distance 0.20
# Section <h4>6.2C.2.2	General procedure for Federated Learning among Multiple NWDAF Instances</h4> is close to requirement LR1_signalling with distance 0.20
# Section <h3>6.2F.2	Contents of ML Model Training</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>6.2F.2	Contents of ML Model Training</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.2F.2	Contents of ML Model Training</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h3>6.2F.2	Contents of ML Model Training</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h3>6.4.2	Input Data</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.4.2	Input Data</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h3>6.4.2	Input Data</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h3>6.4.2	Input Data</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h3>6.6.1	General</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>6.6.1	General</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.6.1	General</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h3>6.6.1	General</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h3>6.6.3	Output Analytics</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>6.6.3	Output Analytics</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.6.3	Output Analytics</h3> is close to requirement LR1_signalling with distance 0.19
# Section <h3>6.6.3	Output Analytics</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h3>6.9.1	General</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h3>6.9.1	General</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>6.9.1	General</h3> is close to requirement LR1_signalling with distance 0.19
# Section <h3>6.9.1	General</h3> is close to requirement LR1_signalling with distance 0.19
# Section <h3>6.9.2	Input data</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.9.2	Input data</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h3>6.9.2	Input data</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h3>6.9.2	Input data</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h4>6.9.4.2	Procedure for QoS Sustainability in a fine granularity area</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>6.9.4.2	Procedure for QoS Sustainability in a fine granularity area</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>6.9.4.2	Procedure for QoS Sustainability in a fine granularity area</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h4>6.9.4.2	Procedure for QoS Sustainability in a fine granularity area</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h3>6.13.1	General</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>6.13.1	General</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.13.1	General</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h3>6.13.1	General</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h3>6.13.2	Input Data</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>6.13.2	Input Data</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.13.2	Input Data</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h3>6.13.2	Input Data</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h3>6.13.3	Output Analytics</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h3>6.13.3	Output Analytics</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.13.3	Output Analytics</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h3>6.13.3	Output Analytics</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h3>6.14.1	General</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.14.1	General</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.14.1	General</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h3>6.14.1	General</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h3>6.14.2	Input Data</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.14.2	Input Data</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h3>6.14.2	Input Data</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h3>6.14.2	Input Data</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h3>6.14.3	Output Analytics</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h3>6.14.3	Output Analytics</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>6.14.3	Output Analytics</h3> is close to requirement LR1_signalling with distance 0.19
# Section <h3>6.14.3	Output Analytics</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h3>6.18.1	General</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>6.18.1	General</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>6.18.1	General</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h3>6.18.1	General</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h3>6.18.2	Input Data</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.18.2	Input Data</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>6.18.2	Input Data</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h3>6.18.2	Input Data</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h3>7.10.4	Nnwdaf_MLModelTraining_Notify service operation</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>7.10.4	Nnwdaf_MLModelTraining_Notify service operation</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>7.10.4	Nnwdaf_MLModelTraining_Notify service operation</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h3>7.10.4	Nnwdaf_MLModelTraining_Notify service operation</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h3>7.11.2	Nnwdaf_MLModelTrainingInfo_Request service operation</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>7.11.2	Nnwdaf_MLModelTrainingInfo_Request service operation</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>7.11.2	Nnwdaf_MLModelTrainingInfo_Request service operation</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h3>7.11.2	Nnwdaf_MLModelTrainingInfo_Request service operation</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h3>10.3.4	Nadrf_MLModelManagement_Retrieval Request service operation</h3> is close to requirement LR1_signalling with distance 0.26
# Section <h3>10.3.4	Nadrf_MLModelManagement_Retrieval Request service operation</h3> is close to requirement LR1_signalling with distance 0.27
# Section <h3>10.3.4	Nadrf_MLModelManagement_Retrieval Request service operation</h3> is close to requirement LR1_signalling with distance 0.25
# Section <h3>10.3.4	Nadrf_MLModelManagement_Retrieval Request service operation</h3> is close to requirement LR1_signalling with distance 0.27
# Section <h3>4.6.2	Public network utilization</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>4.6.2	Public network utilization</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h3>4.6.2	Public network utilization</h3> is close to requirement LR1_signalling with distance 0.19
# Section <h3>4.6.2	Public network utilization</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h5>7.3.3.13.2	FEC encoding by the MBSTF</h5> is close to requirement LR1_signalling with distance 0.22
# Section <h5>7.3.3.13.2	FEC encoding by the MBSTF</h5> is close to requirement LR1_signalling with distance 0.23
# Section <h5>7.3.3.13.2	FEC encoding by the MBSTF</h5> is close to requirement LR1_signalling with distance 0.18
# Section <h5>7.3.3.13.2	FEC encoding by the MBSTF</h5> is close to requirement LR1_signalling with distance 0.19
# Section <h3>5.2.4	5G ProSe Direct Discovery Characteristics</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>5.2.4	5G ProSe Direct Discovery Characteristics</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>5.2.4	5G ProSe Direct Discovery Characteristics</h3> is close to requirement LR1_signalling with distance 0.17
# Section <h3>5.2.4	5G ProSe Direct Discovery Characteristics</h3> is close to requirement LR1_signalling with distance 0.18
# Section <h3>5.6.1	QoS handling for 5G ProSe Direct Communication</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h3>5.6.1	QoS handling for 5G ProSe Direct Communication</h3> is close to requirement LR1_signalling with distance 0.24
# Section <h3>5.6.1	QoS handling for 5G ProSe Direct Communication</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h3>5.6.1	QoS handling for 5G ProSe Direct Communication</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h4>9.7.2.1	Data transmission quality measurement </h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>9.7.2.1	Data transmission quality measurement </h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>9.7.2.1	Data transmission quality measurement </h4> is close to requirement LR1_signalling with distance 0.19
# Section <h4>9.7.2.1	Data transmission quality measurement </h4> is close to requirement LR1_signalling with distance 0.20
# Section <h4>9.7.2.2	Data transmission quality query</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>9.7.2.2	Data transmission quality query</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>9.7.2.2	Data transmission quality query</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>9.7.2.2	Data transmission quality query</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>9.7.2.3	Data transmission quality measurement reported by SEALDD client</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>9.7.2.3	Data transmission quality measurement reported by SEALDD client</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>9.7.2.3	Data transmission quality measurement reported by SEALDD client</h4> is close to requirement LR1_signalling with distance 0.20
# Section <h4>9.7.2.3	Data transmission quality measurement reported by SEALDD client</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>9.7.3.1	SEALDD enabled data transmission quality measurement subscription request</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>9.7.3.1	SEALDD enabled data transmission quality measurement subscription request</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>9.7.3.1	SEALDD enabled data transmission quality measurement subscription request</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>9.7.3.1	SEALDD enabled data transmission quality measurement subscription request</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>9.7.3.3	SEALDD enabled data transmission quality measurement notification</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>9.7.3.3	SEALDD enabled data transmission quality measurement notification</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>9.7.3.3	SEALDD enabled data transmission quality measurement notification</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>9.7.3.3	SEALDD enabled data transmission quality measurement notification</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>9.7.3.5	SEALDD enabled data transmission quality query response</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>9.7.3.5	SEALDD enabled data transmission quality query response</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>9.7.3.5	SEALDD enabled data transmission quality query response</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>9.7.3.5	SEALDD enabled data transmission quality query response</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>9.7.3.6	Transmission quality measurement subscription request</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>9.7.3.6	Transmission quality measurement subscription request</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>9.7.3.6	Transmission quality measurement subscription request</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>9.7.3.6	Transmission quality measurement subscription request</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>9.7.3.8	Transmission quality measurement notification</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>9.7.3.8	Transmission quality measurement notification</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>9.7.3.8	Transmission quality measurement notification</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>9.7.3.8	Transmission quality measurement notification</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>9.9.2.2	SEALDD enabled data transmission quality guarantee with redundant transport</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>9.9.2.2	SEALDD enabled data transmission quality guarantee with redundant transport</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>9.9.2.2	SEALDD enabled data transmission quality guarantee with redundant transport</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h4>9.9.2.2	SEALDD enabled data transmission quality guarantee with redundant transport</h4> is close to requirement LR1_signalling with distance 0.20
# Section <h4>14.3.2.13	end-to-end QoS management request </h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>14.3.2.13	end-to-end QoS management request </h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>14.3.2.13	end-to-end QoS management request </h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>14.3.2.13	end-to-end QoS management request </h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>14.3.2.15	QoS downgrade indication</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>14.3.2.15	QoS downgrade indication</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>14.3.2.15	QoS downgrade indication</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>14.3.2.15	QoS downgrade indication</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>14.3.2.20	Unicast QoS monitoring subscription request</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>14.3.2.20	Unicast QoS monitoring subscription request</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>14.3.2.20	Unicast QoS monitoring subscription request</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>14.3.2.20	Unicast QoS monitoring subscription request</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>14.3.2.24	TSC stream availability discovery response</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>14.3.2.24	TSC stream availability discovery response</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>14.3.2.24	TSC stream availability discovery response</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>14.3.2.24	TSC stream availability discovery response</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>14.3.2.25	TSC stream creation request</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>14.3.2.25	TSC stream creation request</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>14.3.2.25	TSC stream creation request</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>14.3.2.25	TSC stream creation request</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>14.3.2.33	Unicast QoS monitoring data request</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>14.3.2.33	Unicast QoS monitoring data request</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>14.3.2.33	Unicast QoS monitoring data request</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>14.3.2.33	Unicast QoS monitoring data request</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>14.3.2.35	Application connectivity request</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>14.3.2.35	Application connectivity request</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>14.3.2.35	Application connectivity request</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>14.3.2.35	Application connectivity request</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h6>14.3.3.4.1.2	Procedure</h6> is close to requirement LR1_signalling with distance 0.22
# Section <h6>14.3.3.4.1.2	Procedure</h6> is close to requirement LR1_signalling with distance 0.22
# Section <h6>14.3.3.4.1.2	Procedure</h6> is close to requirement LR1_signalling with distance 0.19
# Section <h6>14.3.3.4.1.2	Procedure</h6> is close to requirement LR1_signalling with distance 0.20
# Section <h4>14.3.5.1	General</h4> is close to requirement LR1_signalling with distance 0.20
# Section <h4>14.3.5.1	General</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>14.3.5.1	General</h4> is close to requirement LR1_signalling with distance 0.17
# Section <h4>14.3.5.1	General</h4> is close to requirement LR1_signalling with distance 0.18
# Section <h5>14.3.5.2.2	Procedure for a group of UEs</h5> is close to requirement LR1_signalling with distance 0.21
# Section <h5>14.3.5.2.2	Procedure for a group of UEs</h5> is close to requirement LR1_signalling with distance 0.22
# Section <h5>14.3.5.2.2	Procedure for a group of UEs</h5> is close to requirement LR1_signalling with distance 0.18
# Section <h5>14.3.5.2.2	Procedure for a group of UEs</h5> is close to requirement LR1_signalling with distance 0.19
# Section <h5>14.3.5.3.1	Procedure for a single pair of UEs</h5> is close to requirement LR1_signalling with distance 0.21
# Section <h5>14.3.5.3.1	Procedure for a single pair of UEs</h5> is close to requirement LR1_signalling with distance 0.22
# Section <h5>14.3.5.3.1	Procedure for a single pair of UEs</h5> is close to requirement LR1_signalling with distance 0.18
# Section <h5>14.3.5.3.1	Procedure for a single pair of UEs</h5> is close to requirement LR1_signalling with distance 0.18
# Section <h4>14.3.7.2	TSC stream availability discovery procedure</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>14.3.7.2	TSC stream availability discovery procedure</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>14.3.7.2	TSC stream availability discovery procedure</h4> is close to requirement LR1_signalling with distance 0.20
# Section <h4>14.3.7.2	TSC stream availability discovery procedure</h4> is close to requirement LR1_signalling with distance 0.20
# Section <h4>14.3.7.3	TSC stream creation procedure</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>14.3.7.3	TSC stream creation procedure</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>14.3.7.3	TSC stream creation procedure</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h4>14.3.7.3	TSC stream creation procedure</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h4>14.3.8.2	5GS TSN Bridge information reporting</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>14.3.8.2	5GS TSN Bridge information reporting</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>14.3.8.2	5GS TSN Bridge information reporting</h4> is close to requirement LR1_signalling with distance 0.20
# Section <h4>14.3.8.2	5GS TSN Bridge information reporting</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h5>14.3.9.2.1	Procedure triggered by correlated source and destination requests</h5> is close to requirement LR1_signalling with distance 0.21
# Section <h5>14.3.9.2.1	Procedure triggered by correlated source and destination requests</h5> is close to requirement LR1_signalling with distance 0.22
# Section <h5>14.3.9.2.1	Procedure triggered by correlated source and destination requests</h5> is close to requirement LR1_signalling with distance 0.18
# Section <h5>14.3.9.2.1	Procedure triggered by correlated source and destination requests</h5> is close to requirement LR1_signalling with distance 0.19
# Section <h5>14.3.12.4.3	Network parameter coordination procedure</h5> is close to requirement LR1_signalling with distance 0.20
# Section <h5>14.3.12.4.3	Network parameter coordination procedure</h5> is close to requirement LR1_signalling with distance 0.22
# Section <h5>14.3.12.4.3	Network parameter coordination procedure</h5> is close to requirement LR1_signalling with distance 0.18
# Section <h5>14.3.12.4.3	Network parameter coordination procedure</h5> is close to requirement LR1_signalling with distance 0.18
# Section <h4>14.3.13.2	Request and Select Background Data Transfer Policy </h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>14.3.13.2	Request and Select Background Data Transfer Policy </h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>14.3.13.2	Request and Select Background Data Transfer Policy </h4> is close to requirement LR1_signalling with distance 0.18
# Section <h4>14.3.13.2	Request and Select Background Data Transfer Policy </h4> is close to requirement LR1_signalling with distance 0.19
# Section <h4>9.1.1.2	Service requirement</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>9.1.1.2	Service requirement</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>9.1.1.2	Service requirement</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>9.1.1.2	Service requirement</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>9.4.2.1	Procedures on slice lifecycle management</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>9.4.2.1	Procedures on slice lifecycle management</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>9.4.2.1	Procedures on slice lifecycle management</h4> is close to requirement LR1_signalling with distance 0.18
# Section <h4>9.4.2.1	Procedures on slice lifecycle management</h4> is close to requirement LR1_signalling with distance 0.18
# Section <h4>9.4.3.5	QoE metrics subscribe</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>9.4.3.5	QoE metrics subscribe</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>9.4.3.5	QoE metrics subscribe</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>9.4.3.5	QoE metrics subscribe</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h5>9.5.2.1.1	VAL server policy provisioning </h5> is close to requirement LR1_signalling with distance 0.21
# Section <h5>9.5.2.1.1	VAL server policy provisioning </h5> is close to requirement LR1_signalling with distance 0.22
# Section <h5>9.5.2.1.1	VAL server policy provisioning </h5> is close to requirement LR1_signalling with distance 0.19
# Section <h5>9.5.2.1.1	VAL server policy provisioning </h5> is close to requirement LR1_signalling with distance 0.18
# Section <h4>9.5.2.2	Network slice optimization based on VAL server policy</h4> is close to requirement LR1_signalling with distance 0.20
# Section <h4>9.5.2.2	Network slice optimization based on VAL server policy</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>9.5.2.2	Network slice optimization based on VAL server policy</h4> is close to requirement LR1_signalling with distance 0.18
# Section <h4>9.5.2.2	Network slice optimization based on VAL server policy</h4> is close to requirement LR1_signalling with distance 0.17
# Section <h4>9.7.2.1	Network slice related performance and analytics monitoring job creation request</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>9.7.2.1	Network slice related performance and analytics monitoring job creation request</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>9.7.2.1	Network slice related performance and analytics monitoring job creation request</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h4>9.7.2.1	Network slice related performance and analytics monitoring job creation request</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h4>9.7.2.3	Multiple slices related performance and analytics consolidated report request</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>9.7.2.3	Multiple slices related performance and analytics consolidated report request</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>9.7.2.3	Multiple slices related performance and analytics consolidated report request</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h4>9.7.2.3	Multiple slices related performance and analytics consolidated report request</h4> is close to requirement LR1_signalling with distance 0.18
# Section <h4>9.8.3.2	Information collection from NSCE server(s) subscribe request</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>9.8.3.2	Information collection from NSCE server(s) subscribe request</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>9.8.3.2	Information collection from NSCE server(s) subscribe request</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>9.8.3.2	Information collection from NSCE server(s) subscribe request</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>9.11.2.1	Procedure for VAL server-triggered and network-based network slice adaptation for VAL application</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>9.11.2.1	Procedure for VAL server-triggered and network-based network slice adaptation for VAL application</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>9.11.2.1	Procedure for VAL server-triggered and network-based network slice adaptation for VAL application</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h4>9.11.2.1	Procedure for VAL server-triggered and network-based network slice adaptation for VAL application</h4> is close to requirement LR1_signalling with distance 0.18
# Section <h4>9.11.3.1	Network slice adaptation request</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>9.11.3.1	Network slice adaptation request</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>9.11.3.1	Network slice adaptation request</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>9.11.3.1	Network slice adaptation request</h4> is close to requirement LR1_signalling with distance 0.20
# Section <h5>9.12.2.1.1	Slice related Communication Service Creation</h5> is close to requirement LR1_signalling with distance 0.22
# Section <h5>9.12.2.1.1	Slice related Communication Service Creation</h5> is close to requirement LR1_signalling with distance 0.23
# Section <h5>9.12.2.1.1	Slice related Communication Service Creation</h5> is close to requirement LR1_signalling with distance 0.20
# Section <h5>9.12.2.1.1	Slice related Communication Service Creation</h5> is close to requirement LR1_signalling with distance 0.19
# Section <h4>9.12.3.2	Slice related communication service creation </h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>9.12.3.2	Slice related communication service creation </h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>9.12.3.2	Slice related communication service creation </h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>9.12.3.2	Slice related communication service creation </h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>9.12.3.3	Slice related communication service reconfiguration</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>9.12.3.3	Slice related communication service reconfiguration</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>9.12.3.3	Slice related communication service reconfiguration</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>9.12.3.3	Slice related communication service reconfiguration</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>9.17.2.1	Network Slice Information delivery request</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>9.17.2.1	Network Slice Information delivery request</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>9.17.2.1	Network Slice Information delivery request</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h4>9.17.2.1	Network Slice Information delivery request</h4> is close to requirement LR1_signalling with distance 0.18
# Section <h4>9.18.3.2	Network Slice Allocation</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>9.18.3.2	Network Slice Allocation</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>9.18.3.2	Network Slice Allocation</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>9.18.3.2	Network Slice Allocation</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h3>8.2.2	Procedure on VAL server performance analytics</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>8.2.2	Procedure on VAL server performance analytics</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>8.2.2	Procedure on VAL server performance analytics</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h3>8.2.2	Procedure on VAL server performance analytics</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h3>8<span style="font-size:20pt">.</span>3.2	Procedure</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>8<span style="font-size:20pt">.</span>3.2	Procedure</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>8<span style="font-size:20pt">.</span>3.2	Procedure</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h3>8<span style="font-size:20pt">.</span>3.2	Procedure</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h3>8<span style="font-size:20pt">.</span>4.2	Procedure</h3> is close to requirement LR1_signalling with distance 0.22
# Section <h3>8<span style="font-size:20pt">.</span>4.2	Procedure</h3> is close to requirement LR1_signalling with distance 0.23
# Section <h3>8<span style="font-size:20pt">.</span>4.2	Procedure</h3> is close to requirement LR1_signalling with distance 0.20
# Section <h3>8<span style="font-size:20pt">.</span>4.2	Procedure</h3> is close to requirement LR1_signalling with distance 0.21
# Section <h4>8.4.3.4	UE-to-UE analytics request</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>8.4.3.4	UE-to-UE analytics request</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>8.4.3.4	UE-to-UE analytics request</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>8.4.3.4	UE-to-UE analytics request</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h2>3.2	Abbreviations</h2> is close to requirement LR1_signalling with distance 0.21
# Section <h2>3.2	Abbreviations</h2> is close to requirement LR1_signalling with distance 0.23
# Section <h2>3.2	Abbreviations</h2> is close to requirement LR1_signalling with distance 0.19
# Section <h2>3.2	Abbreviations</h2> is close to requirement LR1_signalling with distance 0.19
# Section <h2>4.1	General concepts</h2> is close to requirement LR1_signalling with distance 0.21
# Section <h2>4.1	General concepts</h2> is close to requirement LR1_signalling with distance 0.24
# Section <h2>4.1	General concepts</h2> is close to requirement LR1_signalling with distance 0.18
# Section <h2>4.1	General concepts</h2> is close to requirement LR1_signalling with distance 0.18
# Section <h4>5.4.1.4	Support of Unavailability Period</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.4.1.4	Support of Unavailability Period</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.4.1.4	Support of Unavailability Period</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h4>5.4.1.4	Support of Unavailability Period</h4> is close to requirement LR1_signalling with distance 0.20
# Section <h4>5.4.9.1	General</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.4.9.1	General</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>5.4.9.1	General</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h4>5.4.9.1	General</h4> is close to requirement LR1_signalling with distance 0.20
# Section <h4>5.4.12.2	Core Network Assistance for PEIPS</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.4.12.2	Core Network Assistance for PEIPS</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.4.12.2	Core Network Assistance for PEIPS</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h4>5.4.12.2	Core Network Assistance for PEIPS</h4> is close to requirement LR1_signalling with distance 0.20
# Section <h4>5.4.13.1	Mobility Management and Power Saving Optimization</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>5.4.13.1	Mobility Management and Power Saving Optimization</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>5.4.13.1	Mobility Management and Power Saving Optimization</h4> is close to requirement LR1_signalling with distance 0.18
# Section <h4>5.4.13.1	Mobility Management and Power Saving Optimization</h4> is close to requirement LR1_signalling with distance 0.18
# Section <h4>5.6.7.1	General</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.6.7.1	General</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>5.6.7.1	General</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h4>5.6.7.1	General</h4> is close to requirement LR1_signalling with distance 0.20
# Section <h4>5.7.1.2a	Alternative QoS Profile</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>5.7.1.2a	Alternative QoS Profile</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>5.7.1.2a	Alternative QoS Profile</h4> is close to requirement LR1_signalling with distance 0.18
# Section <h4>5.7.1.2a	Alternative QoS Profile</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h5>5.7.2.4.1a	Notification Control without Alternative QoS Profiles</h5> is close to requirement LR1_signalling with distance 0.21
# Section <h5>5.7.2.4.1a	Notification Control without Alternative QoS Profiles</h5> is close to requirement LR1_signalling with distance 0.22
# Section <h5>5.7.2.4.1a	Notification Control without Alternative QoS Profiles</h5> is close to requirement LR1_signalling with distance 0.19
# Section <h5>5.7.2.4.1a	Notification Control without Alternative QoS Profiles</h5> is close to requirement LR1_signalling with distance 0.19
# Section <h5>5.7.2.4.2	Usage of Notification control with Alternative QoS Profiles at handover</h5> is close to requirement LR1_signalling with distance 0.20
# Section <h5>5.7.2.4.2	Usage of Notification control with Alternative QoS Profiles at handover</h5> is close to requirement LR1_signalling with distance 0.23
# Section <h5>5.7.2.4.2	Usage of Notification control with Alternative QoS Profiles at handover</h5> is close to requirement LR1_signalling with distance 0.19
# Section <h5>5.7.2.4.2	Usage of Notification control with Alternative QoS Profiles at handover</h5> is close to requirement LR1_signalling with distance 0.19
# Section <h4>5.7.2.5	Flow Bit Rates</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>5.7.2.5	Flow Bit Rates</h4> is close to requirement LR1_signalling with distance 0.23
# Section <h4>5.7.2.5	Flow Bit Rates</h4> is close to requirement LR1_signalling with distance 0.18
# Section <h4>5.7.2.5	Flow Bit Rates</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h4>5.7.3.1	General</h4> is close to requirement LR1_signalling with distance 0.21
# Section <h4>5.7.3.1	General</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.7.3.1	General</h4> is close to requirement LR1_signalling with distance 0.17
# Section <h4>5.7.3.1	General</h4> is close to requirement LR1_signalling with distance 0.18
# Section <h4>5.7.3.2	Resource Type</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.7.3.2	Resource Type</h4> is close to requirement LR1_signalling with distance 0.24
# Section <h4>5.7.3.2	Resource Type</h4> is close to requirement LR1_signalling with distance 0.19
# Section <h4>5.7.3.2	Resource Type</h4> is close to requirement LR1_signalling with distance 0.20
# Section <h4>5.7.3.4	Packet Delay Budget</h4> is close to requirement LR1_signalling with distance 0.20
# Section <h4>5.7.3.4	Packet Delay Budget</h4> is close to requirement LR1_signalling with distance 0.22
# Section <h4>5.7.3.4	Packet Delay Budget</h4> is close to requirement LR1_signalling with distance 0.17
# Section <h4>5.7.3.4	Packet Delay Budget</h4> is close to requirement LR1_signalling with distance 0.18
# ...
# Section <h4>6.2.2.4	QoS control</h4> is close to requirement LR3_other with distance 0.20
# Section <h3>6.3.1	General</h3> is close to requirement LR3_other with distance 0.22
# Section <h3>6.3.1	General</h3> is close to requirement LR3_other with distance 0.22
# Section <h3>6.3.1	General</h3> is close to requirement LR3_other with distance 0.22
# Section <h3>6.3.1	General</h3> is close to requirement LR3_other with distance 0.26
# Section <h3>6.3.1	General</h3> is close to requirement LR3_other with distance 0.23
# Section <h3>6.3.1	General</h3> is close to requirement LR3_other with distance 0.20
# Section <h3>6.3.1	General</h3> is close to requirement LR3_other with distance 0.23
# Section <h3>6.3.1	General</h3> is close to requirement LR3_other with distance 0.23
# Section <h1>D.2	Reporting for sponsored data connectivity</h1> is close to requirement LR3_other with distance 0.26
# Section <h1>D.2	Reporting for sponsored data connectivity</h1> is close to requirement LR3_other with distance 0.26
# Section <h1>D.2	Reporting for sponsored data connectivity</h1> is close to requirement LR3_other with distance 0.26
# Section <h1>D.2	Reporting for sponsored data connectivity</h1> is close to requirement LR3_other with distance 0.30
# Section <h1>D.2	Reporting for sponsored data connectivity</h1> is close to requirement LR3_other with distance 0.28
# Section <h1>D.2	Reporting for sponsored data connectivity</h1> is close to requirement LR3_other with distance 0.22
# Section <h1>D.2	Reporting for sponsored data connectivity</h1> is close to requirement LR3_other with distance 0.27
# Section <h1>D.2	Reporting for sponsored data connectivity</h1> is close to requirement LR3_other with distance 0.27
# Section <h3>4.7.1	General</h3> is close to requirement LR3_other with distance 0.20
# Section <h3>4.7.1	General</h3> is close to requirement LR3_other with distance 0.21
# Section <h3>4.7.1	General</h3> is close to requirement LR3_other with distance 0.19
# Section <h3>4.7.1	General</h3> is close to requirement LR3_other with distance 0.25
# Section <h3>4.7.1	General</h3> is close to requirement LR3_other with distance 0.22
# Section <h3>4.7.1	General</h3> is close to requirement LR3_other with distance 0.20
# Section <h3>4.7.1	General</h3> is close to requirement LR3_other with distance 0.22
# Section <h3>4.7.1	General</h3> is close to requirement LR3_other with distance 0.22
# Section <h4>8.6.3.2	PIN Communication Create Request</h4> is close to requirement LR3_other with distance 0.24
# Section <h4>8.6.3.2	PIN Communication Create Request</h4> is close to requirement LR3_other with distance 0.24
# Section <h4>8.6.3.2	PIN Communication Create Request</h4> is close to requirement LR3_other with distance 0.23
# Section <h4>8.6.3.2	PIN Communication Create Request</h4> is close to requirement LR3_other with distance 0.27
# Section <h4>8.6.3.2	PIN Communication Create Request</h4> is close to requirement LR3_other with distance 0.25
# Section <h4>8.6.3.2	PIN Communication Create Request</h4> is close to requirement LR3_other with distance 0.22
# Section <h4>8.6.3.2	PIN Communication Create Request</h4> is close to requirement LR3_other with distance 0.25
# Section <h4>8.6.3.2	PIN Communication Create Request</h4> is close to requirement LR3_other with distance 0.25
# Section <h4>8.6.3.4	PIN Communication Update Request</h4> is close to requirement LR3_other with distance 0.24
# Section <h4>8.6.3.4	PIN Communication Update Request</h4> is close to requirement LR3_other with distance 0.24
# Section <h4>8.6.3.4	PIN Communication Update Request</h4> is close to requirement LR3_other with distance 0.24
# Section <h4>8.6.3.4	PIN Communication Update Request</h4> is close to requirement LR3_other with distance 0.27
# Section <h4>8.6.3.4	PIN Communication Update Request</h4> is close to requirement LR3_other with distance 0.25
# Section <h4>8.6.3.4	PIN Communication Update Request</h4> is close to requirement LR3_other with distance 0.22
# Section <h4>8.6.3.4	PIN Communication Update Request</h4> is close to requirement LR3_other with distance 0.25
# Section <h4>8.6.3.4	PIN Communication Update Request</h4> is close to requirement LR3_other with distance 0.25
# Section <h2>4.1	General</h2> is close to requirement LR3_other with distance 0.17
# Section <h2>4.1	General</h2> is close to requirement LR3_other with distance 0.17
# Section <h2>4.1	General</h2> is close to requirement LR3_other with distance 0.17
# Section <h2>4.1	General</h2> is close to requirement LR3_other with distance 0.24
# Section <h2>4.1	General</h2> is close to requirement LR3_other with distance 0.21
# Section <h2>4.1	General</h2> is close to requirement LR3_other with distance 0.20
# Section <h2>4.1	General</h2> is close to requirement LR3_other with distance 0.20
# Section <h2>4.1	General</h2> is close to requirement LR3_other with distance 0.21
# Section <h3>6.2.1	General</h3> is close to requirement LR3_other with distance 0.19
# Section <h3>6.2.1	General</h3> is close to requirement LR3_other with distance 0.19
# Section <h3>6.2.1	General</h3> is close to requirement LR3_other with distance 0.19
# Section <h3>6.2.1	General</h3> is close to requirement LR3_other with distance 0.23
# Section <h3>6.2.1	General</h3> is close to requirement LR3_other with distance 0.21
# Section <h3>6.2.1	General</h3> is close to requirement LR3_other with distance 0.19
# Section <h3>6.2.1	General</h3> is close to requirement LR3_other with distance 0.21
# Section <h3>6.2.1	General</h3> is close to requirement LR3_other with distance 0.21
# Section <h3>6.3.1	General</h3> is close to requirement LR3_other with distance 0.18
# Section <h3>6.3.1	General</h3> is close to requirement LR3_other with distance 0.19
# Section <h3>6.3.1	General</h3> is close to requirement LR3_other with distance 0.18
# Section <h3>6.3.1	General</h3> is close to requirement LR3_other with distance 0.23
# Section <h3>6.3.1	General</h3> is close to requirement LR3_other with distance 0.21
# Section <h3>6.3.1	General</h3> is close to requirement LR3_other with distance 0.20
# Section <h3>6.3.1	General</h3> is close to requirement LR3_other with distance 0.20
# Section <h3>6.3.1	General</h3> is close to requirement LR3_other with distance 0.20
# Section <h3>6.3.6	Edge Relocation Considering User Plane Latency Requirement</h3> is close to requirement LR3_other with distance 0.15
# Section <h3>6.3.6	Edge Relocation Considering User Plane Latency Requirement</h3> is close to requirement LR3_other with distance 0.17
# Section <h3>6.3.6	Edge Relocation Considering User Plane Latency Requirement</h3> is close to requirement LR3_other with distance 0.15
# Section <h3>6.3.6	Edge Relocation Considering User Plane Latency Requirement</h3> is close to requirement LR3_other with distance 0.22
# Section <h3>6.3.6	Edge Relocation Considering User Plane Latency Requirement</h3> is close to requirement LR3_other with distance 0.19
# Section <h3>6.3.6	Edge Relocation Considering User Plane Latency Requirement</h3> is close to requirement LR3_other with distance 0.20
# Section <h3>6.3.6	Edge Relocation Considering User Plane Latency Requirement</h3> is close to requirement LR3_other with distance 0.18
# Section <h3>6.3.6	Edge Relocation Considering User Plane Latency Requirement</h3> is close to requirement LR3_other with distance 0.18
# Section <h3>6.4.1	General</h3> is close to requirement LR3_other with distance 0.19
# Section <h3>6.4.1	General</h3> is close to requirement LR3_other with distance 0.19
# Section <h3>6.4.1	General</h3> is close to requirement LR3_other with distance 0.18
# Section <h3>6.4.1	General</h3> is close to requirement LR3_other with distance 0.23
# Section <h3>6.4.1	General</h3> is close to requirement LR3_other with distance 0.20
# Section <h3>6.4.1	General</h3> is close to requirement LR3_other with distance 0.20
# Section <h3>6.4.1	General</h3> is close to requirement LR3_other with distance 0.19
# Section <h3>6.4.1	General</h3> is close to requirement LR3_other with distance 0.19
# Section <h4>6.4.2.1	Usage of Nupf_EventExposure to Report QoS Monitoring results</h4> is close to requirement LR3_other with distance 0.18
# Section <h4>6.4.2.1	Usage of Nupf_EventExposure to Report QoS Monitoring results</h4> is close to requirement LR3_other with distance 0.19
# Section <h4>6.4.2.1	Usage of Nupf_EventExposure to Report QoS Monitoring results</h4> is close to requirement LR3_other with distance 0.17
# Section <h4>6.4.2.1	Usage of Nupf_EventExposure to Report QoS Monitoring results</h4> is close to requirement LR3_other with distance 0.23
# Section <h4>6.4.2.1	Usage of Nupf_EventExposure to Report QoS Monitoring results</h4> is close to requirement LR3_other with distance 0.21
# Section <h4>6.4.2.1	Usage of Nupf_EventExposure to Report QoS Monitoring results</h4> is close to requirement LR3_other with distance 0.20
# Section <h4>6.4.2.1	Usage of Nupf_EventExposure to Report QoS Monitoring results</h4> is close to requirement LR3_other with distance 0.20
# Section <h4>6.4.2.1	Usage of Nupf_EventExposure to Report QoS Monitoring results</h4> is close to requirement LR3_other with distance 0.20
# Section <h1>E.4	Session Breakout</h1> is close to requirement LR3_other with distance 0.26
# Section <h1>E.4	Session Breakout</h1> is close to requirement LR3_other with distance 0.26
# Section <h1>E.4	Session Breakout</h1> is close to requirement LR3_other with distance 0.26
# Section <h1>E.4	Session Breakout</h1> is close to requirement LR3_other with distance 0.29
# Section <h1>E.4	Session Breakout</h1> is close to requirement LR3_other with distance 0.27
# Section <h1>E.4	Session Breakout</h1> is close to requirement LR3_other with distance 0.22
# Section <h1>E.4	Session Breakout</h1> is close to requirement LR3_other with distance 0.27
# Section <h1>E.4	Session Breakout</h1> is close to requirement LR3_other with distance 0.27
# Section <h2>3.1	Terms</h2> is close to requirement LR3_other with distance 0.19
# Section <h2>3.1	Terms</h2> is close to requirement LR3_other with distance 0.18
# Section <h2>3.1	Terms</h2> is close to requirement LR3_other with distance 0.19
# Section <h2>3.1	Terms</h2> is close to requirement LR3_other with distance 0.23
# Section <h2>3.1	Terms</h2> is close to requirement LR3_other with distance 0.21
# Section <h2>3.1	Terms</h2> is close to requirement LR3_other with distance 0.20
# Section <h2>3.1	Terms</h2> is close to requirement LR3_other with distance 0.21
# Section <h2>3.1	Terms</h2> is close to requirement LR3_other with distance 0.21
# Section <h4>8.5.2.2	Request-response model</h4> is close to requirement LR3_other with distance 0.20
# Section <h4>8.5.2.2	Request-response model</h4> is close to requirement LR3_other with distance 0.20
# Section <h4>8.5.2.2	Request-response model</h4> is close to requirement LR3_other with distance 0.20
# Section <h4>8.5.2.2	Request-response model</h4> is close to requirement LR3_other with distance 0.22
# Section <h4>8.5.2.2	Request-response model</h4> is close to requirement LR3_other with distance 0.22
# Section <h4>8.5.2.2	Request-response model</h4> is close to requirement LR3_other with distance 0.20
# Section <h4>8.5.2.2	Request-response model</h4> is close to requirement LR3_other with distance 0.21
# Section <h4>8.5.2.2	Request-response model</h4> is close to requirement LR3_other with distance 0.21
# Section <h5>8.6.6.3.2	Session with QoS create request</h5> is close to requirement LR3_other with distance 0.22
# Section <h5>8.6.6.3.2	Session with QoS create request</h5> is close to requirement LR3_other with distance 0.22
# Section <h5>8.6.6.3.2	Session with QoS create request</h5> is close to requirement LR3_other with distance 0.22
# Section <h5>8.6.6.3.2	Session with QoS create request</h5> is close to requirement LR3_other with distance 0.25
# Section <h5>8.6.6.3.2	Session with QoS create request</h5> is close to requirement LR3_other with distance 0.22
# Section <h5>8.6.6.3.2	Session with QoS create request</h5> is close to requirement LR3_other with distance 0.20
# Section <h5>8.6.6.3.2	Session with QoS create request</h5> is close to requirement LR3_other with distance 0.23
# Section <h5>8.6.6.3.2	Session with QoS create request</h5> is close to requirement LR3_other with distance 0.23
# Section <h5>8.6.6.3.4	Session with QoS update request</h5> is close to requirement LR3_other with distance 0.22
# Section <h5>8.6.6.3.4	Session with QoS update request</h5> is close to requirement LR3_other with distance 0.22
# Section <h5>8.6.6.3.4	Session with QoS update request</h5> is close to requirement LR3_other with distance 0.21
# Section <h5>8.6.6.3.4	Session with QoS update request</h5> is close to requirement LR3_other with distance 0.25
# Section <h5>8.6.6.3.4	Session with QoS update request</h5> is close to requirement LR3_other with distance 0.22
# Section <h5>8.6.6.3.4	Session with QoS update request</h5> is close to requirement LR3_other with distance 0.20
# Section <h5>8.6.6.3.4	Session with QoS update request</h5> is close to requirement LR3_other with distance 0.22
# Section <h5>8.6.6.3.4	Session with QoS update request</h5> is close to requirement LR3_other with distance 0.22
# Section <h3>8.12.1	General</h3> is close to requirement LR3_other with distance 0.21
# Section <h3>8.12.1	General</h3> is close to requirement LR3_other with distance 0.20
# Section <h3>8.12.1	General</h3> is close to requirement LR3_other with distance 0.20
# Section <h3>8.12.1	General</h3> is close to requirement LR3_other with distance 0.22
# Section <h3>8.12.1	General</h3> is close to requirement LR3_other with distance 0.23
# Section <h3>8.12.1	General</h3> is close to requirement LR3_other with distance 0.21
# Section <h3>8.12.1	General</h3> is close to requirement LR3_other with distance 0.22
# Section <h3>8.12.1	General</h3> is close to requirement LR3_other with distance 0.22
# Section <h3>5.2.2	Located UE Discovery &amp; Selection</h3> is close to requirement LR3_other with distance 0.19
# Section <h3>5.2.2	Located UE Discovery &amp; Selection</h3> is close to requirement LR3_other with distance 0.20
# Section <h3>5.2.2	Located UE Discovery &amp; Selection</h3> is close to requirement LR3_other with distance 0.19
# Section <h3>5.2.2	Located UE Discovery &amp; Selection</h3> is close to requirement LR3_other with distance 0.24
# Section <h3>5.2.2	Located UE Discovery &amp; Selection</h3> is close to requirement LR3_other with distance 0.22
# Section <h3>5.2.2	Located UE Discovery &amp; Selection</h3> is close to requirement LR3_other with distance 0.19
# Section <h3>5.2.2	Located UE Discovery &amp; Selection</h3> is close to requirement LR3_other with distance 0.21
# Section <h3>5.2.2	Located UE Discovery &amp; Selection</h3> is close to requirement LR3_other with distance 0.22
# Section <h5>6.7.1.2.3	Procedure for Ranging/SL Positioning service exposure though 5GC network via control plane</h5> is close to requirement LR3_other with distance 0.19
# Section <h5>6.7.1.2.3	Procedure for Ranging/SL Positioning service exposure though 5GC network via control plane</h5> is close to requirement LR3_other with distance 0.20
# Section <h5>6.7.1.2.3	Procedure for Ranging/SL Positioning service exposure though 5GC network via control plane</h5> is close to requirement LR3_other with distance 0.18
# Section <h5>6.7.1.2.3	Procedure for Ranging/SL Positioning service exposure though 5GC network via control plane</h5> is close to requirement LR3_other with distance 0.24
# Section <h5>6.7.1.2.3	Procedure for Ranging/SL Positioning service exposure though 5GC network via control plane</h5> is close to requirement LR3_other with distance 0.21
# Section <h5>6.7.1.2.3	Procedure for Ranging/SL Positioning service exposure though 5GC network via control plane</h5> is close to requirement LR3_other with distance 0.19
# Section <h5>6.7.1.2.3	Procedure for Ranging/SL Positioning service exposure though 5GC network via control plane</h5> is close to requirement LR3_other with distance 0.20
# Section <h5>6.7.1.2.3	Procedure for Ranging/SL Positioning service exposure though 5GC network via control plane</h5> is close to requirement LR3_other with distance 0.20

# %%
# average the distance in dfOutput per section, document and requirement
dfOutput["Distance"] = dfOutput["Distance"].astype(float)
dfGrouped = dfOutput.groupby(["Section", "Document", "Requirement", "Content"])

#convert dfGrouped to a dataframe
dfGrouped = dfGrouped.agg({"Distance": "mean"}).reset_index()

dfGrouped.to_excel("./output_requirements_distances_g.xlsx", index=False)

# %%
# now check the minimum distance per section and document
dfGrouped = dfGrouped.sort_values(by=["Section", "Document", "Distance"])

dfGrouped = dfGrouped.groupby(["Section", "Document"]).first().reset_index()

dfGrouped.to_excel("./output_requirements_distances_g_min.xlsx", index=False)

# %%
# now we turn this into a list of lists
lstRelevantDist = dfGrouped.values.tolist()

print(len(lstRelevantDist))
# Out:
# 308

# %%
# convert to dataframe and save to excel lstRelevantDist
dfRelevantDist = pd.DataFrame(lstRelevantDist, columns=["Section", "Document", "Requirement", "Content", "Distance"])

dfRelevantDist.to_excel("./output_requirements_temp.xlsx", index=False)

# %% [markdown]
# ## Step 4: Check if the requirements exist in the database
#
# In this step, we check if the text that we identified so far is covered by the requirements that exist in the database. We use the sentence transformers to get the embeddings of the text and then we compare them to the existin sections.

# %%
thresholdPartial = 0.2
thresholdCovered = 1.0

# %%
# read the requirements from the Excel file
dfRelevantSections = pd.read_excel("./output_requirements_temp.xlsx")

lstRelevantSections = dfRelevantSections.values.tolist()

# %%
lstRelevantSections[0]
# Out:
# ['<h1>B.1\tLCS privacy selection flow rule</h1>',
#  '23273-i20.docx',
#  'LR1_signalling',
#  '[\'\', \'A 5GS-MT-LR may be applied to more than one LCS privacy data in the LCS privacy profile, e.g. one or more privacy classes as defined in clause\\xa05.4.2.2 and LPI as defined in clause\\xa05.4.2.3. The 5GS-MT-LR may also require POI as defined in clause\\xa05.4.4. The Privacy selection flow is shown in Figure B.1-1.\', \'\', \'----media/image63.emf----\', \'\', \'Figure B.1-1: Privacy selection flow diagram\', \'\', \'\', \'\', \'\', \'Annex C (informative):\', \'PNI-NPN architecture to support location service with signalling optimisation\', \'\', \'Figure C-1 shows the PNI-NPN architecture to support location services with optimisation of signalling latency and privacy, with the corresponding functional descriptions are defined in clause\\xa05.13.\', \'\', \'When UE access the NG-RAN in the local network, during the registration procedure or service request procedure, NG-RAN selects the Serving AMF in the public network. With appropriate configuration, local AMF cannot be selected as the serving AMF for the UE.\', \'\', \'Assuming NG-RAN 1 is the serving RAN of UE. NG-RAN 2 and NG-RAN 3 illustrated in the figure below is for positioning signal measurement.\', \'\', \'----media/image64.emf----\', \'\', \'Figure C-1 PNI-NPN architecture to support location service with signalling optimisation\', \'\', \'\', \'Annex D (informative):\', \'Change history\', \'\', \'<b>Change history</b>\', \'\', \'<span style="font-size:16pt"><b>Date</b></span>\', \'\', \'<span style="font-size:16pt"><b>Meeting</b></span>\', \'\', \'<span style="font-size:16pt"><b>TDoc</b></span>\', \'\', \'<span style="font-size:16pt"><b>CR</b></span>\', \'\', \'<span style="font-size:16pt"><b>Rev</b></span>\', \'\', \'<span style="font-size:16pt"><b>Cat</b></span>\', \'\', \'<span style="font-size:16pt"><b>Subject/Comment</b></span>\', \'\', \'<span style="font-size:16pt"><b>New version</b></span>\', \'\', \'<span style="color:0000FF;font-size:16pt">2019-05</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">SP#84</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">SP-190455</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">MCC Editorial update for presentation to TSG SA#84 for approval</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">1.0.0</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">2019-06</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">SP#84</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">-</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">MCC editorial update for publication after approval at TSG SA#84</span>\', \'\', \'<span style="color:0000FF;font-size:16pt">16.0.0</span>\', \'\', \'<span style="font-size:16pt">2019-09</span>\', \'\', \'<span style="font-size:16pt">SP#85</span>\', \'\', \'<span style="font-size:16pt">SP-190606</span>\', \'\', \'<span style="font-size:16pt">0001 </span>\', \'\', \'<span style="font-size:16pt">1</span>\', \'\', \'<span style="font-size:16pt">F</span>\', \'\', \'<span style="font-size:16pt">Correction on UE Assisted and UE Based Positioning Procedure</span>\', \'\', \'<span style="font-size:16pt">16.1.0</span>\', \'\', \'<span style="font-size:16pt">2019-09</span>\', \'\', \'<span style="font-size:16pt">SP#85</span>\', \'\', \'<span style="font-size:16pt">SP-190606</span>\', \'\', \'<span style="font-size:16pt">0002</span>\', \'\', \'<span style="font-size:16pt">1</span>\', \'\', \'<span style="font-size:16pt">F</span>\', \'\', \'<span style="font-size:16pt">Correction on LCS privacy selection flow rule</span>\', \'\', \'<span style="font-size:16pt">16.1.0</span>\ ...
#  0.2612412568377631]

# %%
model = SentenceTransformer("sentence-t5-large")

# list with all embeddings for the sections
lstRelevantEmbeddings = []
iCounter = 0

for oneLine in tqdm(lstRelevantSections):

    # the content of the section starts on the third position of the list
    sentences = oneLine[3]

    # Sentences are encoded by calling model.encode()
    embeddings = model.encode(sentences)
    
    # Print the average embeddings for all the sentences 
    # in this section
    # avg_embedding = np.mean(embeddings, axis=0)
    
    lstOneLine = [oneLine[0], oneLine[1], 2, str(sentences).replace("$", "_").replace("\n", "_"), embeddings]

    lstRelevantEmbeddings.append(lstOneLine)

    iCounter += 1
# Out:
# 100%|██████████| 308/308 [00:10<00:00, 30.46it/s]

# %%
# now, read the requirements from the requirements database, file 20_requirements.xlsx
dfTRequirements = pd.read_excel("existing_requirements.xlsx")

# convert to list
lstTRequirements = dfTRequirements.values.tolist()

# %%
lstTRequirements[0]
# Out:
# ['Req_1',
#  'Regarding support for infrastructure protection of electrical transmission, the 5G system shall support an end-to-end latency of less than 5 ms or 10 ms, as requested by the UE initiating the communication. ',
#  'NOTE 1: This requirement relates to TS 22.104, chapter 5.6C Support for infrastructure protection of electrical transmission.\nNOTE 2: Whether the end-to-end latency is 5 ms or 10 ms depends on the applied voltage level. \nNOTE 3: The end-to-end latency is between two UEs, including two wireless links.',
#  'Payload',
#  nan]

# %%
# make the embeddings
model = SentenceTransformer("sentence-t5-large")

# list with all embeddings for the sections
lstTRequirementsEmbeddings = []
iCounter = 0

for oneLine in tqdm(lstTRequirements):

    # the content of the section starts on the requirement text
    sentences = oneLine[1]

    # Sentences are encoded by calling model.encode()
    embeddings = model.encode(sentences)
    
    # Print the average embeddings for all the sentences 
    # in this section
    #avg_embedding = np.mean(embeddings, axis=0)
    
    lstOneLine = [oneLine[0], oneLine[1], 2, str(sentences).replace("$", "_").replace("\n", "_"), embeddings]

    lstTRequirementsEmbeddings.append(lstOneLine)

    iCounter += 1
# Out:
# 100%|██████████| 20/20 [00:00<00:00, 45.12it/s]

# %%
# average the embeddings for all the lstTRequirementsEmbeddings
lstTRequirementsEmbeddingsNP = np.array([x[4] for x in lstTRequirementsEmbeddings])

tRequirementsAvgEmbeddings = np.mean(lstTRequirementsEmbeddingsNP, axis=0)

# %%
# now, calculate the average distance of all the relevant sections to the average requirements
lstDist = []

for oneLine in tqdm(lstRelevantEmbeddings):
    # euclidean distance between the two embeddings
    dist = distance.cosine(oneLine[4], tRequirementsAvgEmbeddings)
    lstDist.append([oneLine[0], oneLine[1], dist, oneLine[3]])

# now we sort the list by the distance
lstDist.sort(key=lambda x: x[3])
# Out:
# 100%|██████████| 308/308 [00:00<00:00, 125604.83it/s]

# %%
lstDist[0]
# Out:
# ['<h2>4.1\tGeneral</h2>',
#  '23548-i20.docx',
#  0.116038754741146,
#  '[\'\', "Edge Computing enables operator and 3rd party services to be hosted close to the UE\'s access point of attachment, so as to achieve an efficient service delivery through the reduced end-to-end latency and load on the transport network.", \'\', \'5GS supports Edge Hosting Environment (EHE) deployed in the DN beyond the PSA UPF. An EHE may be under the control of either the operator or 3rd parties.\', \'\', \'The Edge Computing features defined in this specification are applicable to PLMN(s) and to SNPN(s).\', \'\', \'The Local part of the DN in which EHE is deployed may have user plane connectivity with both a centrally deployed PSA and locally deployed PSA of same DNN. Edge Computing enablers as described in clause\\xa05.13 of TS\\xa023.501\\xa0[2], e.g. local routing and traffic steering, session and service continuity, AF influenced traffic routing, are leveraged in this specification.\', \'\', \'Edge Computing in the serving network (e.g. for Local Break Out roaming scenario in case of PLMN access) is supported, but for AF guidance to PCF determination of URSP rules, the Serving network (e.g. VPLMN or serving SNPN) has no control on URSP, so cannot influence UE in selecting a specific Edge Computing related DNN and S-NSSAI.\', \'\']']

# %%
# Visualize the results using the scatter plot, where
# the x-axis is the distance to the average requirement
# the y-axis is always 1
# the color is red for the requirements

# Create a color map based on x[2]
color_map = {0: 'blue', 1: 'green', 2: 'red'}
colors = [color_map[0] for x in lstDist]

# we plot the t-SNE results
plt.figure(figsize=(16,10))

random.seed(42)

plt.scatter([x[2] for x in lstDist], [random.random() * 2 for x in lstDist], c=colors, s=100, alpha=0.5)

# Add labels to each dot
#for i, label in enumerate([x[3] for x in lstDist]):
#    plt.text([x[2] for x in lstDist][i], 1, label[:20]+'...', rotation='vertical')

# Add vertical lines at 0.33 and 1.0
plt.axvline(x=thresholdPartial, color='orange', linestyle='--')
plt.axvline(x=thresholdCovered, color='red', linestyle='--')

# Set the limits of the x-axis
plt.xlim(0, 2)
plt.ylim(0, 2)

plt.show()

# %%
# now we separate them into three lists:
# - with distance below 0.33 -- these requirements are covered
# - with distance between 0.33 and 1.0 -- these requirements are partially covered
# - with distance above 1.0 -- these requirements are not covered

lstCovered = []
lstPartiallyCovered = []
lstNotCovered = []

for oneLine in lstDist:
    if oneLine[2] < thresholdPartial:
        lstCovered.append(oneLine)
    elif oneLine[2] < thresholdCovered:
        lstPartiallyCovered.append(oneLine)
    else:
        lstNotCovered.append(oneLine)

# %% [markdown]
# ## Step 5: create requirements based on each of these sections
#
# In the last step, we create new requirements based on the sections identified in the previous steps.

# %%
torch.random.manual_seed(0)

modelInstr = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-3-mini-128k-instruct", 
    device_map="cuda", 
    torch_dtype="auto", 
    trust_remote_code=True, 
)
tokenizerInstr = AutoTokenizer.from_pretrained("microsoft/Phi-3-mini-4k-instruct")
# Out:
# `flash-attention` package not found, consider installing for better performance: No module named 'flash_attn'.
# Current `flash-attenton` does not support `window_size`. Either upgrade or use `attn_implementation='eager'`.
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
def createRequirement(content, type, model, tokenizer):
    content1 = content.split(",")
    content1 = [x for x in content1[1:] if x not in ['', " ''", " '']"]]
    content_str = " ".join(content1)
    
    strContent = f"Based on this : {content_str}. Write the requirement in the following format 'The system shall ' "
    
    messages = [
        {"role": "user", "content": strContent},
    ]

    pipe = pipeline(
        "text-generation",
        model=model,
        tokenizer=tokenizer,
    )

    generation_args = {
        "max_new_tokens": 500,
        "return_full_text": False,
        "temperature": 0.0,
        "do_sample": False,
    }

    output = pipe(messages, **generation_args)
    
    return output[0]['generated_text']

# %%
lstGenerated = []
iCounter = 0

# we generate new requirements for the partially covered ones
if len(lstPartiallyCovered) > 0:
    for oneLine in tqdm(lstPartiallyCovered):
        iCounter += 1
        strRequirement = createRequirement(oneLine[3], oneLine[2], modelInstr, tokenizerInstr)
        lstGenerated.append([oneLine[0], oneLine[1], oneLine[2], oneLine[3], strRequirement])
        if iCounter % 10 == 0:
            # convert the list to a dataframe and save to excel
            dfOutput = pd.DataFrame(lstGenerated, columns=["Section", "Document", "Requirement type", "Content", "Distance", "Generated requirements"])
            dfOutput.to_excel("./output_partially_covered_generated_cont.xlsx", index=False)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]You are not running the flash-attention implementation, expect numerical differences.
# 100%|██████████| 4/4 [01:31<00:00, 22.91s/it]

# %%
# we generate new requirements for the not covered requirements
if len(lstNotCovered) > 0:
    for oneLine in tqdm(lstNotCovered):
        iCounter += 1
        if (len(oneLine[3]) < 10000):
            strRequirement = createRequirement(oneLine[3], oneLine[2], modelInstr, tokenizerInstr)
            lstGenerated.append([oneLine[0], oneLine[1], oneLine[2], oneLine[3], strRequirement])
        if iCounter % 10 == 0:
            # convert the list to a dataframe and save to excel
            dfOutput = pd.DataFrame(lstGenerated, columns=["Section", "Document", "Requirement type", "Content", "Distance", "Generated requirements"])
            dfOutput.to_excel("./output_partially_covered_generated_cont.xlsx", index=False)

# %%
dfOutput = pd.DataFrame(lstGenerated, columns=["Section", "Document", "Content", "Distance", "Generated requirements"])
dfOutput.to_excel("./output_partially_covered_generated.xlsx", index=False)

# %%
# we generate new requirements for the not covered requirements
if len(lstCovered) > 0:
    for oneLine in tqdm(lstCovered):
        iCounter += 1
        if (len(oneLine[3]) < 10000):
            strRequirement = createRequirement(oneLine[3], oneLine[2], modelInstr, tokenizerInstr)
            lstGenerated.append([oneLine[0], oneLine[1], oneLine[2], oneLine[3], strRequirement])
        if iCounter % 10 == 0:
            # convert the list to a dataframe and save to excel
            dfOutput = pd.DataFrame(lstGenerated, columns=["Section", "Document", "Requirement type", "Content", "Distance", "Generated requirements"])
            dfOutput.to_excel("./output_covered_generated_cont.xlsx", index=False)
# Out:
#   2%|▏         | 5/304 [01:49<1:39:58, 20.06s/it]

# %%
lstGenerated[0]
# Out:
# ['<h2>5.33\tSupport for Ultra Reliable Low Latency Communication</h2>',
#  '23501-i22.docx',
#  0.23272037227432385,
#  "['']",
#  ' The system shall:\n\n1. Provide accurate and timely data processing capabilities to ensure efficient operation.\n2. Maintain data integrity and security to protect sensitive information from unauthorized access or breaches.\n3. Offer user-friendly interfaces and intuitive navigation to enhance user experience and productivity.\n4. Support scalability and flexibility to accommodate future growth and changing business needs.\n5. Implement robust error handling and recovery mechanisms to minimize downtime and data loss.\n6. Ensure compliance with relevant industry standards and regulations to maintain legal and ethical operations.\n7. Facilitate seamless integration with other systems and applications for streamlined workflows and data exchange.\n8. Deliver consistent performance and reliability to meet user expectations and operational demands.\n9. Provide comprehensive documentation and support resources to assist users in effectively utilizing the system.\n10. Continuously monitor and optimize system performance to identify and address potential issues proactively.']
