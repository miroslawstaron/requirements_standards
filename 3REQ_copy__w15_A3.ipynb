# %% [markdown]
# # 3REQ system
#
# Requirement analysis system.

# %%
from docx2python import docx2python
import os

import numpy as np
import pandas as pd

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

from sentence_transformers import SentenceTransformer

# %%
# suppress warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Step 1: List the documents's sections with "latency"
#
# In the first step, we go through the documents in the folder "input_standards" and we extract which sections of these documents contain th word "latency". We store the results in a dictionary.

# %%
def extractLatencySections(doc):
    strSectionTitle = ""
    dictSections = {}
    listLatency = []

    doc_result = docx2python(doc,paragraph_styles = True, html=True)

    # we iterate over all lines
    # look for the section titles (which have the tag <h1>, <h2>, <h3>, etc.)
    # then we add the content of each section to the dictionary
    # and if there is a word "latency" somewhere in the section, we add the section title to the listLatency
    for oneLine in doc_result.text.split('\n'):
        if "<h" in oneLine:
            strSectionTitle = oneLine
            dictSections[strSectionTitle] = []

        if strSectionTitle != "":  
            dictSections[strSectionTitle].append(oneLine)

        keywordsInLine = ["latency"]  #, "latencies"]
        keywordsInSections = ["references", "introduction"]

        if any(word in oneLine.lower() for word in keywordsInLine) and not any(word in strSectionTitle.lower() for word in keywordsInSections): 
            listLatency.append(strSectionTitle)

            
    # remove the keys from the dictionary if they are not part of the listLatency
    # as we want to get only the relevant sections, i.e., the one with the word latency
    for key in list(dictSections.keys()):
        if key not in listLatency:
            del dictSections[key]

    # return the dictionary with the relevant sections
    return dictSections

# %%
docInputFolder = "./23_standards"

# this is the return list of all the lines in the document
lstAllLines = []

# for each .docx file in the input folder
# extract the sections with latency using the extractLatencySections function
# and print the sections
for doc in os.listdir(docInputFolder):    

    if doc.endswith(".docx"):
        print(f"Processing {doc}")

        # since things can go wrong with the latency library, 
        # we use a try except block to avoid the program to stop
        try: 
            dictSections = extractLatencySections(os.path.join(docInputFolder, doc))
        
            # we list the content
            # as a long list of sections 
            for key in dictSections:

                lstOneLine = [key, doc]

                for line in dictSections[key]:
                    lstOneLine.append(line)
                    
                lstAllLines.append(lstOneLine)

        except Exception as e:
            print(f"Error with {doc}: {e}")
# Out:
# Processing 23003-i20.docx
# Processing 23008-i00.docx
# Processing 23015-i00.docx
# Processing 23038-i00.docx
# Processing 23040-i00.docx
# Processing 23042-i00.docx
# Processing 23053-h00.docx
# Processing 23122-i60.docx
# Processing 23142-i00.docx
# Processing 23218-i00.docx
# Processing 23247-i20.docx
# Processing 23256-i10.docx
# Processing 23273-i20.docx
# Processing 23287-i00.docx
# Processing 23288-i20.docx
# Processing 23289-i60.docx
# Processing 23304-i20.docx
# Processing 23316-i20.docx
# Processing 23380-i00.docx
# Processing 23433-i00.docx
# Processing 23434-i50.docx
# Processing 23435-i00.docx
# Processing 23436-i00.docx
# Processing 23501-i22.docx
# Processing 23502-i20.docx
# Processing 23503-i20.docx
# Processing 23527-i00.docx
# Processing 23540-i00.docx
# Processing 23542-i00.docx
# Processing 23545-090.docx
# Processing 23548-i20.docx
# Processing 23554-j10.docx
# Processing 23558-i30.docx
# Processing 23586-i00.docx
# Processing 23632-i20.docx

# %%
model = SentenceTransformer("sentence-t5-large")

# list with all embeddings for the sections
lstEmbeddings = []

for oneLine in lstAllLines:

    # the content of the section starts on the third position of the list
    sentences = oneLine[3:]

    # Sentences are encoded by calling model.encode()
    embeddings = model.encode(sentences)
    
    # Print the average embeddings for all the sentences 
    # in this section
    avg_embedding = np.mean(embeddings, axis=0)
    
    lstOneLine = [oneLine[0], oneLine[1], 2, str(sentences).replace("$", "_").replace("\n", "_"), avg_embedding]

    lstEmbeddings.append(lstOneLine)
# Out:
# modules.json:   0%|          | 0.00/461 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/1.99k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.39k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/670M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.92k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# 2_Dense/config.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# 2_Dense/model.safetensors:   0%|          | 0.00/3.15M [00:00<?, ?B/s]
# 2_Dense/pytorch_model.bin:   0%|          | 0.00/3.15M [00:00<?, ?B/s]

# %% [markdown]
# ## Step 2: Find the relevant sections
#
# In this step, we take the sections identified in Step 1 and we compare them to a list of right and wrong requirements. The list is stored in the file List.xlsx

# %%
# open the file List.xlsx using pandas
# and read the workshop NR
df = pd.read_excel("List_w15_A3.xlsx", sheet_name="R_NR")

# convert the dataframe to a list of lists
lstReference = df.values.tolist()

lstReference[0]
# Out:
# ['L4S (Low Latency, Low Loss and Scalable Throughput) is described in IETF RFC 9330, IETF RFC 9331 and IETF RFC 9332.',
#  1]

# %%
# list with all embeddings for the sections
lstEmbeddingsRef = []

for oneLine in lstReference:

    # the content of the section starts on the third position of the list
    sentences = oneLine[0]

    # Sentences are encoded by calling model.encode()
    embeddings = model.encode(sentences)
    
    # Print the average embeddings for all the sentences 
    # in this section
    avg_embedding = embeddings
    
    lstOneLine = [oneLine[0], 'REF', oneLine[1], oneLine[1], avg_embedding]

    lstEmbeddingsRef.append(lstOneLine)

# %%
# concatenate the two lists
lstEmbeddingsAll = lstEmbeddings + lstEmbeddingsRef
print(len(lstEmbeddings))
# Out:
# 105

# %%
print(lstEmbeddingsRef[0][4])
# Out:
# [ 4.50192615e-02 -8.73260014e-03 -3.91247012e-02 -6.23441115e-02
#   4.43251655e-02 -1.12622110e-02 -6.79076239e-02  4.40965109e-02
#   2.99488548e-02  2.12680660e-02 -2.46547069e-02  3.49943750e-02
#  -3.91768999e-02  8.50128126e-04 -3.32857333e-02 -2.51700804e-02
#  -2.06659292e-03  2.08867136e-02 -4.62291799e-02 -1.82003397e-02
#  -5.93135878e-02  1.85816791e-02 -3.79080661e-02  1.18638398e-02
#   4.27556410e-02 -1.34880794e-02  6.47856295e-02 -3.66393514e-02
#  -5.07304184e-02 -1.11454897e-01  1.29662856e-01 -2.12668423e-02
#  -9.30322856e-02 -6.19456246e-02 -2.84369830e-02  4.18962054e-02
#   8.66709575e-02  6.05601519e-02  1.13610402e-02 -3.62830944e-02
#   8.08306597e-03  1.52815273e-03  6.97853342e-02  5.89325652e-02
#   1.83691774e-02 -5.39535619e-02 -5.71012404e-03  8.99511278e-02
#   1.25655811e-03 -5.58300726e-02 -2.72353310e-02  1.51197901e-02
#  -5.62502109e-02  4.84878905e-02  4.10232246e-02  8.67890194e-02
#  -2.23692823e-02 -4.05724235e-02 -9.56834778e-02  2.00929195e-02
#   4.70989272e-02  4.04289626e-02 -2.48326454e-02  2.59648059e-02
#  -4.90502128e-03 -3.38574424e-02 -1.72721762e-02  7.56398542e-03
#  -4.75904113e-03  3.46300378e-03  1.90785713e-03 -2.93292291e-02
#   3.28094959e-02 -5.90482131e-02  2.34501306e-02 -5.22191152e-02
#  -1.77922975e-02  7.48089403e-02  1.13788107e-02  8.99525434e-02]

# %%
from sklearn.metrics.pairwise import euclidean_distances

# for each line in lstEmbeddings
# we calculate the euclidean distance with each line in lstEmbeddingsRef



lstRelevant = []

for oneLine in lstEmbeddings:  
    lstDistPos = []
    lstDistNeg = []
    for oneLineRef in lstEmbeddingsRef:
        if oneLineRef[2] == 1:
            # euclidean distance between the two embeddings
            dist = euclidean_distances([oneLine[4]], [oneLineRef[4]])
            lstDistPos.append(dist[0][0])
        if oneLineRef[2] == 0:
            # euclidean distance between the two embeddings
            dist = euclidean_distances([oneLine[4]], [oneLineRef[4]])
            lstDistNeg.append(dist[0][0])
    
    # now calculate the average for both lists
    avgDistPos = np.mean(lstDistPos)
    avgDistNeg = np.mean(lstDistNeg)

    if avgDistPos < avgDistNeg:
        print(f"Section {oneLine[0]} is relevant")
        # add the class to the list
        oneLine.append(1)
        lstRelevant.append(oneLine)
    else:
        #print(f"Section {oneLine[0]} is not relevant")
        # add the class to the list
        oneLine.append(0)
# Out:
# Section <h4>5.4.3.3	Priority Level</h4> is relevant
# Section <h4>9.7.2.1	Data transmission quality measurement </h4> is relevant
# Section <h4>9.7.2.3	Data transmission quality measurement reported by SEALDD client</h4> is relevant
# Section <h4>14.3.5.1	General</h4> is relevant
# Section <h5>14.3.5.2.2	Procedure for a group of UEs</h5> is relevant
# Section <h4>14.3.7.2	TSC stream availability discovery procedure</h4> is relevant
# Section <h5>14.3.9.2.1	Procedure triggered by correlated source and destination requests</h5> is relevant
# Section <h5>14.3.12.4.3	Network parameter coordination procedure</h5> is relevant
# Section <h4>9.5.2.2	Network slice optimization based on VAL server policy</h4> is relevant
# Section <h4>9.11.2.1	Procedure for VAL server-triggered and network-based network slice adaptation for VAL application</h4> is relevant
# Section <h4>9.17.2.1	Network Slice Information delivery request</h4> is relevant
# Section <h2>3.1	Definitions</h2> is relevant
# Section <h2>3.2	Abbreviations</h2> is relevant
# Section <h2>4.1	General concepts</h2> is relevant
# Section <h2>5.13	Support for Edge Computing</h2> is relevant
# Section <h5>5.31.7.2.4	Paging for extended DRX for RRC_INACTIVE in NR connected to 5GC</h5> is relevant
# Section <h3>5.31.8	High latency communication</h3> is relevant
# Section <h3>5.33.1	General</h3> is relevant
# Section <h3>5.37.1	General</h3> is relevant
# Section <h4>5.37.3.1	General</h4> is relevant
# Section <h3>5.37.6	UL/DL policy control based on round-trip latency requirement</h3> is relevant
# Section <h4>5.43.3.1	General</h4> is relevant
# Section <h3>6.2.3	UPF</h3> is relevant
# Section <h1>M.1	Mapping of the parameters between 5GS and TSN UNI</h1> is relevant
# Section <h4>4.8.2.2b	Network Triggered Connection Resume in RRC_INACTIVE with CN based MT communication handling</h4> is relevant
# Section <h5>4.15.3.2.3b	Specific NEF service operations information flow for loss of connectivity and UE reachability</h5> is relevant
# Section <h5>4.15.3.2.5	Information flow for downlink data delivery status with SMF buffering</h5> is relevant
# Section <h4>4.15.6.3a	Network Configuration parameters</h4> is relevant
# Section <h4>4.15.6.6	Setting up an AF session with required QoS procedure</h4> is relevant
# Section <h1>F.4	5GS interworking with TSN deployed in the transport network</h1> is relevant
# Section <h4>6.1.3.22	AF session with required QoS</h4> is relevant
# Section <h4>6.1.3.23b	Support of IETF Deterministic Networking</h4> is relevant
# Section <h5>6.1.3.27.2	UL/DL policy control based on round-trip latency requirement</h5> is relevant
# Section <h2>4.1	General</h2> is relevant
# Section <h3>6.3.6	Edge Relocation Considering User Plane Latency Requirement</h3> is relevant
# Section <h3>6.4.1	General</h3> is relevant

# %%
print(len(lstRelevant))
# Out:
# 36

# %%
# here we save all the relevant sections to an Excel file
# and the non-relevant ones too
import pandas as pd

dfOutput = pd.DataFrame(lstEmbeddings, columns=["Section", "Document", "Class", "Content", "Embedding", "Relevance"])

dfOutput.to_excel("./output__w15__23_A3.xlsx", index=False)

# %% [markdown]
# ## Step 3: Find which requirements are impacted
#
# In this step, we compare the relevant sections with the existing requirements. Based on the distance, we can determine which requirements are impacted. The requirements are provided as a separete list.

# %%
print(f'Percentage relevant: {len(lstRelevant)/len(lstEmbeddings)*100:.2f}%')
# Out:
# Percentage relevant: 34.29%

# %%
# read the requirements from the excel file requirements.xlsx, worksheet LR
df = pd.read_excel("List_w15_A3.xlsx", sheet_name="LR")

# convert to list
lstRequirements = df.values.tolist()
lstRequirements[0]

# now we calculate the embeddings for each of these requirements
lstEmbeddingsReq = []

for oneLine in lstRequirements:
    
        # the content of the section starts on the third position of the list
        sentences = oneLine[1]
    
        # Sentences are encoded by calling model.encode()
        embeddings = model.encode(sentences)
        
        # Print the average embeddings for all the sentences 
        # in this section
        avg_embedding = embeddings
        
        lstOneLine = [oneLine[0], 'latency', oneLine[1], oneLine[1], avg_embedding]
    
        lstEmbeddingsReq.append(lstOneLine)

# %%
print(len(lstEmbeddingsReq))
# Out:
# 16

# %%
# now we calculate the euclidean distance between the requirements and the sections
# that are relevant
lstDist = []
lstRelevantDist = []

for oneLine in lstRelevant:
    for oneLineReq in lstEmbeddingsReq:
        # euclidean distance between the two embeddings
        dist = euclidean_distances([oneLine[4]], [oneLineReq[4]])
        lstDist.append([oneLine[0], oneLine[1], oneLineReq[0], dist[0][0], oneLine[3]])

# now we sort the list by the distance
lstDist.sort(key=lambda x: x[2])

# and we print them
for i in range(len(lstDist)):
    print(f"Section {lstDist[i][0]} is close to requirement {lstDist[i][2]} with distance {lstDist[i][3]:.2f}")
    # add this to a list
    lstRelevantDist.append([lstDist[i][0], lstDist[i][1], lstDist[i][2], lstDist[i][3], lstDist[i][4]])

# save the list to an Excel file
dfOutput = pd.DataFrame(lstRelevantDist, columns=["Section", "Document", "Requirement", "Distance", "Content"])

# sort it by section and document
dfOutput = dfOutput.sort_values(by=["Section", "Document"])

dfOutput.to_excel("./output_reqs_distances_w15__23_A3.xlsx", index=False)
# Out:
# Section <h4>5.4.3.3	Priority Level</h4> is close to requirement LR1_signalling with distance 1.11
# Section <h4>5.4.3.3	Priority Level</h4> is close to requirement LR1_signalling with distance 1.12
# Section <h4>5.4.3.3	Priority Level</h4> is close to requirement LR1_signalling with distance 1.04
# Section <h4>5.4.3.3	Priority Level</h4> is close to requirement LR1_signalling with distance 1.05
# Section <h4>9.7.2.1	Data transmission quality measurement </h4> is close to requirement LR1_signalling with distance 1.09
# Section <h4>9.7.2.1	Data transmission quality measurement </h4> is close to requirement LR1_signalling with distance 1.05
# Section <h4>9.7.2.1	Data transmission quality measurement </h4> is close to requirement LR1_signalling with distance 1.07
# Section <h4>9.7.2.1	Data transmission quality measurement </h4> is close to requirement LR1_signalling with distance 1.08
# Section <h4>9.7.2.3	Data transmission quality measurement reported by SEALDD client</h4> is close to requirement LR1_signalling with distance 1.11
# Section <h4>9.7.2.3	Data transmission quality measurement reported by SEALDD client</h4> is close to requirement LR1_signalling with distance 1.06
# Section <h4>9.7.2.3	Data transmission quality measurement reported by SEALDD client</h4> is close to requirement LR1_signalling with distance 1.08
# Section <h4>9.7.2.3	Data transmission quality measurement reported by SEALDD client</h4> is close to requirement LR1_signalling with distance 1.09
# Section <h4>14.3.5.1	General</h4> is close to requirement LR1_signalling with distance 1.07
# Section <h4>14.3.5.1	General</h4> is close to requirement LR1_signalling with distance 1.10
# Section <h4>14.3.5.1	General</h4> is close to requirement LR1_signalling with distance 1.01
# Section <h4>14.3.5.1	General</h4> is close to requirement LR1_signalling with distance 1.03
# Section <h5>14.3.5.2.2	Procedure for a group of UEs</h5> is close to requirement LR1_signalling with distance 1.12
# Section <h5>14.3.5.2.2	Procedure for a group of UEs</h5> is close to requirement LR1_signalling with distance 1.13
# Section <h5>14.3.5.2.2	Procedure for a group of UEs</h5> is close to requirement LR1_signalling with distance 1.04
# Section <h5>14.3.5.2.2	Procedure for a group of UEs</h5> is close to requirement LR1_signalling with distance 1.05
# Section <h4>14.3.7.2	TSC stream availability discovery procedure</h4> is close to requirement LR1_signalling with distance 1.09
# Section <h4>14.3.7.2	TSC stream availability discovery procedure</h4> is close to requirement LR1_signalling with distance 1.10
# Section <h4>14.3.7.2	TSC stream availability discovery procedure</h4> is close to requirement LR1_signalling with distance 1.04
# Section <h4>14.3.7.2	TSC stream availability discovery procedure</h4> is close to requirement LR1_signalling with distance 1.06
# Section <h5>14.3.9.2.1	Procedure triggered by correlated source and destination requests</h5> is close to requirement LR1_signalling with distance 1.10
# Section <h5>14.3.9.2.1	Procedure triggered by correlated source and destination requests</h5> is close to requirement LR1_signalling with distance 1.12
# Section <h5>14.3.9.2.1	Procedure triggered by correlated source and destination requests</h5> is close to requirement LR1_signalling with distance 1.02
# Section <h5>14.3.9.2.1	Procedure triggered by correlated source and destination requests</h5> is close to requirement LR1_signalling with distance 1.04
# Section <h5>14.3.12.4.3	Network parameter coordination procedure</h5> is close to requirement LR1_signalling with distance 1.08
# Section <h5>14.3.12.4.3	Network parameter coordination procedure</h5> is close to requirement LR1_signalling with distance 1.10
# Section <h5>14.3.12.4.3	Network parameter coordination procedure</h5> is close to requirement LR1_signalling with distance 0.99
# Section <h5>14.3.12.4.3	Network parameter coordination procedure</h5> is close to requirement LR1_signalling with distance 1.01
# Section <h4>9.5.2.2	Network slice optimization based on VAL server policy</h4> is close to requirement LR1_signalling with distance 1.10
# Section <h4>9.5.2.2	Network slice optimization based on VAL server policy</h4> is close to requirement LR1_signalling with distance 1.08
# Section <h4>9.5.2.2	Network slice optimization based on VAL server policy</h4> is close to requirement LR1_signalling with distance 1.04
# Section <h4>9.5.2.2	Network slice optimization based on VAL server policy</h4> is close to requirement LR1_signalling with distance 0.98
# Section <h4>9.11.2.1	Procedure for VAL server-triggered and network-based network slice adaptation for VAL application</h4> is close to requirement LR1_signalling with distance 1.10
# Section <h4>9.11.2.1	Procedure for VAL server-triggered and network-based network slice adaptation for VAL application</h4> is close to requirement LR1_signalling with distance 1.12
# Section <h4>9.11.2.1	Procedure for VAL server-triggered and network-based network slice adaptation for VAL application</h4> is close to requirement LR1_signalling with distance 1.06
# Section <h4>9.11.2.1	Procedure for VAL server-triggered and network-based network slice adaptation for VAL application</h4> is close to requirement LR1_signalling with distance 0.98
# Section <h4>9.17.2.1	Network Slice Information delivery request</h4> is close to requirement LR1_signalling with distance 1.11
# Section <h4>9.17.2.1	Network Slice Information delivery request</h4> is close to requirement LR1_signalling with distance 1.11
# Section <h4>9.17.2.1	Network Slice Information delivery request</h4> is close to requirement LR1_signalling with distance 1.06
# Section <h4>9.17.2.1	Network Slice Information delivery request</h4> is close to requirement LR1_signalling with distance 0.99
# Section <h2>3.1	Definitions</h2> is close to requirement LR1_signalling with distance 1.08
# Section <h2>3.1	Definitions</h2> is close to requirement LR1_signalling with distance 1.11
# Section <h2>3.1	Definitions</h2> is close to requirement LR1_signalling with distance 1.03
# Section <h2>3.1	Definitions</h2> is close to requirement LR1_signalling with distance 1.03
# Section <h2>3.2	Abbreviations</h2> is close to requirement LR1_signalling with distance 1.07
# Section <h2>3.2	Abbreviations</h2> is close to requirement LR1_signalling with distance 1.08
# Section <h2>3.2	Abbreviations</h2> is close to requirement LR1_signalling with distance 1.02
# Section <h2>3.2	Abbreviations</h2> is close to requirement LR1_signalling with distance 1.03
# Section <h2>4.1	General concepts</h2> is close to requirement LR1_signalling with distance 1.07
# Section <h2>4.1	General concepts</h2> is close to requirement LR1_signalling with distance 1.11
# Section <h2>4.1	General concepts</h2> is close to requirement LR1_signalling with distance 1.04
# Section <h2>4.1	General concepts</h2> is close to requirement LR1_signalling with distance 1.02
# Section <h2>5.13	Support for Edge Computing</h2> is close to requirement LR1_signalling with distance 1.06
# Section <h2>5.13	Support for Edge Computing</h2> is close to requirement LR1_signalling with distance 1.09
# Section <h2>5.13	Support for Edge Computing</h2> is close to requirement LR1_signalling with distance 1.01
# Section <h2>5.13	Support for Edge Computing</h2> is close to requirement LR1_signalling with distance 1.00
# Section <h5>5.31.7.2.4	Paging for extended DRX for RRC_INACTIVE in NR connected to 5GC</h5> is close to requirement LR1_signalling with distance 1.13
# Section <h5>5.31.7.2.4	Paging for extended DRX for RRC_INACTIVE in NR connected to 5GC</h5> is close to requirement LR1_signalling with distance 1.08
# Section <h5>5.31.7.2.4	Paging for extended DRX for RRC_INACTIVE in NR connected to 5GC</h5> is close to requirement LR1_signalling with distance 1.02
# Section <h5>5.31.7.2.4	Paging for extended DRX for RRC_INACTIVE in NR connected to 5GC</h5> is close to requirement LR1_signalling with distance 1.05
# Section <h3>5.31.8	High latency communication</h3> is close to requirement LR1_signalling with distance 1.04
# Section <h3>5.31.8	High latency communication</h3> is close to requirement LR1_signalling with distance 1.03
# Section <h3>5.31.8	High latency communication</h3> is close to requirement LR1_signalling with distance 1.01
# Section <h3>5.31.8	High latency communication</h3> is close to requirement LR1_signalling with distance 1.02
# Section <h3>5.33.1	General</h3> is close to requirement LR1_signalling with distance 1.09
# Section <h3>5.33.1	General</h3> is close to requirement LR1_signalling with distance 1.07
# Section <h3>5.33.1	General</h3> is close to requirement LR1_signalling with distance 1.02
# Section <h3>5.33.1	General</h3> is close to requirement LR1_signalling with distance 1.06
# Section <h3>5.37.1	General</h3> is close to requirement LR1_signalling with distance 1.07
# Section <h3>5.37.1	General</h3> is close to requirement LR1_signalling with distance 1.07
# Section <h3>5.37.1	General</h3> is close to requirement LR1_signalling with distance 0.97
# Section <h3>5.37.1	General</h3> is close to requirement LR1_signalling with distance 1.00
# Section <h4>5.37.3.1	General</h4> is close to requirement LR1_signalling with distance 1.11
# Section <h4>5.37.3.1	General</h4> is close to requirement LR1_signalling with distance 1.11
# Section <h4>5.37.3.1	General</h4> is close to requirement LR1_signalling with distance 1.06
# Section <h4>5.37.3.1	General</h4> is close to requirement LR1_signalling with distance 1.08
# Section <h3>5.37.6	UL/DL policy control based on round-trip latency requirement</h3> is close to requirement LR1_signalling with distance 1.07
# Section <h3>5.37.6	UL/DL policy control based on round-trip latency requirement</h3> is close to requirement LR1_signalling with distance 1.05
# Section <h3>5.37.6	UL/DL policy control based on round-trip latency requirement</h3> is close to requirement LR1_signalling with distance 1.01
# Section <h3>5.37.6	UL/DL policy control based on round-trip latency requirement</h3> is close to requirement LR1_signalling with distance 1.04
# Section <h4>5.43.3.1	General</h4> is close to requirement LR1_signalling with distance 1.09
# Section <h4>5.43.3.1	General</h4> is close to requirement LR1_signalling with distance 1.11
# Section <h4>5.43.3.1	General</h4> is close to requirement LR1_signalling with distance 1.07
# Section <h4>5.43.3.1	General</h4> is close to requirement LR1_signalling with distance 1.05
# Section <h3>6.2.3	UPF</h3> is close to requirement LR1_signalling with distance 1.07
# Section <h3>6.2.3	UPF</h3> is close to requirement LR1_signalling with distance 1.09
# Section <h3>6.2.3	UPF</h3> is close to requirement LR1_signalling with distance 1.04
# Section <h3>6.2.3	UPF</h3> is close to requirement LR1_signalling with distance 1.05
# Section <h1>M.1	Mapping of the parameters between 5GS and TSN UNI</h1> is close to requirement LR1_signalling with distance 1.07
# Section <h1>M.1	Mapping of the parameters between 5GS and TSN UNI</h1> is close to requirement LR1_signalling with distance 1.06
# Section <h1>M.1	Mapping of the parameters between 5GS and TSN UNI</h1> is close to requirement LR1_signalling with distance 1.03
# Section <h1>M.1	Mapping of the parameters between 5GS and TSN UNI</h1> is close to requirement LR1_signalling with distance 1.04
# Section <h4>4.8.2.2b	Network Triggered Connection Resume in RRC_INACTIVE with CN based MT communication handling</h4> is close to requirement LR1_signalling with distance 1.10
# Section <h4>4.8.2.2b	Network Triggered Connection Resume in RRC_INACTIVE with CN based MT communication handling</h4> is close to requirement LR1_signalling with distance 1.06
# Section <h4>4.8.2.2b	Network Triggered Connection Resume in RRC_INACTIVE with CN based MT communication handling</h4> is close to requirement LR1_signalling with distance 1.04
# Section <h4>4.8.2.2b	Network Triggered Connection Resume in RRC_INACTIVE with CN based MT communication handling</h4> is close to requirement LR1_signalling with distance 1.06
# Section <h5>4.15.3.2.3b	Specific NEF service operations information flow for loss of connectivity and UE reachability</h5> is close to requirement LR1_signalling with distance 1.10
# Section <h5>4.15.3.2.3b	Specific NEF service operations information flow for loss of connectivity and UE reachability</h5> is close to requirement LR1_signalling with distance 1.06
# Section <h5>4.15.3.2.3b	Specific NEF service operations information flow for loss of connectivity and UE reachability</h5> is close to requirement LR1_signalling with distance 1.04
# Section <h5>4.15.3.2.3b	Specific NEF service operations information flow for loss of connectivity and UE reachability</h5> is close to requirement LR1_signalling with distance 1.05
# Section <h5>4.15.3.2.5	Information flow for downlink data delivery status with SMF buffering</h5> is close to requirement LR1_signalling with distance 1.10
# Section <h5>4.15.3.2.5	Information flow for downlink data delivery status with SMF buffering</h5> is close to requirement LR1_signalling with distance 1.08
# Section <h5>4.15.3.2.5	Information flow for downlink data delivery status with SMF buffering</h5> is close to requirement LR1_signalling with distance 1.07
# Section <h5>4.15.3.2.5	Information flow for downlink data delivery status with SMF buffering</h5> is close to requirement LR1_signalling with distance 1.07
# Section <h4>4.15.6.3a	Network Configuration parameters</h4> is close to requirement LR1_signalling with distance 1.07
# Section <h4>4.15.6.3a	Network Configuration parameters</h4> is close to requirement LR1_signalling with distance 1.05
# Section <h4>4.15.6.3a	Network Configuration parameters</h4> is close to requirement LR1_signalling with distance 1.02
# Section <h4>4.15.6.3a	Network Configuration parameters</h4> is close to requirement LR1_signalling with distance 1.04
# Section <h4>4.15.6.6	Setting up an AF session with required QoS procedure</h4> is close to requirement LR1_signalling with distance 1.13
# Section <h4>4.15.6.6	Setting up an AF session with required QoS procedure</h4> is close to requirement LR1_signalling with distance 1.11
# Section <h4>4.15.6.6	Setting up an AF session with required QoS procedure</h4> is close to requirement LR1_signalling with distance 1.04
# Section <h4>4.15.6.6	Setting up an AF session with required QoS procedure</h4> is close to requirement LR1_signalling with distance 1.08
# Section <h1>F.4	5GS interworking with TSN deployed in the transport network</h1> is close to requirement LR1_signalling with distance 1.11
# Section <h1>F.4	5GS interworking with TSN deployed in the transport network</h1> is close to requirement LR1_signalling with distance 1.11
# Section <h1>F.4	5GS interworking with TSN deployed in the transport network</h1> is close to requirement LR1_signalling with distance 1.03
# Section <h1>F.4	5GS interworking with TSN deployed in the transport network</h1> is close to requirement LR1_signalling with distance 1.08
# Section <h4>6.1.3.22	AF session with required QoS</h4> is close to requirement LR1_signalling with distance 1.09
# Section <h4>6.1.3.22	AF session with required QoS</h4> is close to requirement LR1_signalling with distance 1.09
# Section <h4>6.1.3.22	AF session with required QoS</h4> is close to requirement LR1_signalling with distance 1.02
# Section <h4>6.1.3.22	AF session with required QoS</h4> is close to requirement LR1_signalling with distance 1.06
# Section <h4>6.1.3.23b	Support of IETF Deterministic Networking</h4> is close to requirement LR1_signalling with distance 1.08
# Section <h4>6.1.3.23b	Support of IETF Deterministic Networking</h4> is close to requirement LR1_signalling with distance 1.07
# Section <h4>6.1.3.23b	Support of IETF Deterministic Networking</h4> is close to requirement LR1_signalling with distance 1.01
# Section <h4>6.1.3.23b	Support of IETF Deterministic Networking</h4> is close to requirement LR1_signalling with distance 1.02
# Section <h5>6.1.3.27.2	UL/DL policy control based on round-trip latency requirement</h5> is close to requirement LR1_signalling with distance 1.07
# Section <h5>6.1.3.27.2	UL/DL policy control based on round-trip latency requirement</h5> is close to requirement LR1_signalling with distance 1.05
# Section <h5>6.1.3.27.2	UL/DL policy control based on round-trip latency requirement</h5> is close to requirement LR1_signalling with distance 1.00
# Section <h5>6.1.3.27.2	UL/DL policy control based on round-trip latency requirement</h5> is close to requirement LR1_signalling with distance 1.03
# Section <h2>4.1	General</h2> is close to requirement LR1_signalling with distance 1.10
# Section <h2>4.1	General</h2> is close to requirement LR1_signalling with distance 1.12
# Section <h2>4.1	General</h2> is close to requirement LR1_signalling with distance 1.05
# Section <h2>4.1	General</h2> is close to requirement LR1_signalling with distance 1.03
# Section <h3>6.3.6	Edge Relocation Considering User Plane Latency Requirement</h3> is close to requirement LR1_signalling with distance 1.05
# Section <h3>6.3.6	Edge Relocation Considering User Plane Latency Requirement</h3> is close to requirement LR1_signalling with distance 1.07
# Section <h3>6.3.6	Edge Relocation Considering User Plane Latency Requirement</h3> is close to requirement LR1_signalling with distance 1.00
# Section <h3>6.3.6	Edge Relocation Considering User Plane Latency Requirement</h3> is close to requirement LR1_signalling with distance 1.02
# Section <h3>6.4.1	General</h3> is close to requirement LR1_signalling with distance 1.11
# Section <h3>6.4.1	General</h3> is close to requirement LR1_signalling with distance 1.10
# Section <h3>6.4.1	General</h3> is close to requirement LR1_signalling with distance 1.08
# Section <h3>6.4.1	General</h3> is close to requirement LR1_signalling with distance 1.10
# Section <h4>5.4.3.3	Priority Level</h4> is close to requirement LR2_payload with distance 1.05
# Section <h4>5.4.3.3	Priority Level</h4> is close to requirement LR2_payload with distance 1.14
# Section <h4>5.4.3.3	Priority Level</h4> is close to requirement LR2_payload with distance 1.11
# Section <h4>5.4.3.3	Priority Level</h4> is close to requirement LR2_payload with distance 1.08
# Section <h4>9.7.2.1	Data transmission quality measurement </h4> is close to requirement LR2_payload with distance 0.98
# Section <h4>9.7.2.1	Data transmission quality measurement </h4> is close to requirement LR2_payload with distance 1.09
# Section <h4>9.7.2.1	Data transmission quality measurement </h4> is close to requirement LR2_payload with distance 1.06
# Section <h4>9.7.2.1	Data transmission quality measurement </h4> is close to requirement LR2_payload with distance 1.04
# Section <h4>9.7.2.3	Data transmission quality measurement reported by SEALDD client</h4> is close to requirement LR2_payload with distance 0.99
# Section <h4>9.7.2.3	Data transmission quality measurement reported by SEALDD client</h4> is close to requirement LR2_payload with distance 1.10
# Section <h4>9.7.2.3	Data transmission quality measurement reported by SEALDD client</h4> is close to requirement LR2_payload with distance 1.07
# Section <h4>9.7.2.3	Data transmission quality measurement reported by SEALDD client</h4> is close to requirement LR2_payload with distance 1.05
# Section <h4>14.3.5.1	General</h4> is close to requirement LR2_payload with distance 1.04
# Section <h4>14.3.5.1	General</h4> is close to requirement LR2_payload with distance 1.12
# Section <h4>14.3.5.1	General</h4> is close to requirement LR2_payload with distance 1.09
# Section <h4>14.3.5.1	General</h4> is close to requirement LR2_payload with distance 1.06
# Section <h5>14.3.5.2.2	Procedure for a group of UEs</h5> is close to requirement LR2_payload with distance 1.02
# Section <h5>14.3.5.2.2	Procedure for a group of UEs</h5> is close to requirement LR2_payload with distance 1.12
# Section <h5>14.3.5.2.2	Procedure for a group of UEs</h5> is close to requirement LR2_payload with distance 1.09
# Section <h5>14.3.5.2.2	Procedure for a group of UEs</h5> is close to requirement LR2_payload with distance 1.07
# Section <h4>14.3.7.2	TSC stream availability discovery procedure</h4> is close to requirement LR2_payload with distance 1.01
# Section <h4>14.3.7.2	TSC stream availability discovery procedure</h4> is close to requirement LR2_payload with distance 1.12
# Section <h4>14.3.7.2	TSC stream availability discovery procedure</h4> is close to requirement LR2_payload with distance 1.07
# Section <h4>14.3.7.2	TSC stream availability discovery procedure</h4> is close to requirement LR2_payload with distance 1.04
# Section <h5>14.3.9.2.1	Procedure triggered by correlated source and destination requests</h5> is close to requirement LR2_payload with distance 1.02
# Section <h5>14.3.9.2.1	Procedure triggered by correlated source and destination requests</h5> is close to requirement LR2_payload with distance 1.12
# Section <h5>14.3.9.2.1	Procedure triggered by correlated source and destination requests</h5> is close to requirement LR2_payload with distance 1.06
# Section <h5>14.3.9.2.1	Procedure triggered by correlated source and destination requests</h5> is close to requirement LR2_payload with distance 1.04
# Section <h5>14.3.12.4.3	Network parameter coordination procedure</h5> is close to requirement LR2_payload with distance 1.00
# Section <h5>14.3.12.4.3	Network parameter coordination procedure</h5> is close to requirement LR2_payload with distance 1.10
# Section <h5>14.3.12.4.3	Network parameter coordination procedure</h5> is close to requirement LR2_payload with distance 1.03
# Section <h5>14.3.12.4.3	Network parameter coordination procedure</h5> is close to requirement LR2_payload with distance 1.01
# Section <h4>9.5.2.2	Network slice optimization based on VAL server policy</h4> is close to requirement LR2_payload with distance 1.01
# Section <h4>9.5.2.2	Network slice optimization based on VAL server policy</h4> is close to requirement LR2_payload with distance 1.12
# Section <h4>9.5.2.2	Network slice optimization based on VAL server policy</h4> is close to requirement LR2_payload with distance 1.09
# Section <h4>9.5.2.2	Network slice optimization based on VAL server policy</h4> is close to requirement LR2_payload with distance 1.06
# Section <h4>9.11.2.1	Procedure for VAL server-triggered and network-based network slice adaptation for VAL application</h4> is close to requirement LR2_payload with distance 1.00
# Section <h4>9.11.2.1	Procedure for VAL server-triggered and network-based network slice adaptation for VAL application</h4> is close to requirement LR2_payload with distance 1.13
# Section <h4>9.11.2.1	Procedure for VAL server-triggered and network-based network slice adaptation for VAL application</h4> is close to requirement LR2_payload with distance 1.10
# Section <h4>9.11.2.1	Procedure for VAL server-triggered and network-based network slice adaptation for VAL application</h4> is close to requirement LR2_payload with distance 1.05
# Section <h4>9.17.2.1	Network Slice Information delivery request</h4> is close to requirement LR2_payload with distance 1.01
# Section <h4>9.17.2.1	Network Slice Information delivery request</h4> is close to requirement LR2_payload with distance 1.13
# Section <h4>9.17.2.1	Network Slice Information delivery request</h4> is close to requirement LR2_payload with distance 1.10
# Section <h4>9.17.2.1	Network Slice Information delivery request</h4> is close to requirement LR2_payload with distance 1.05
# Section <h2>3.1	Definitions</h2> is close to requirement LR2_payload with distance 1.00
# Section <h2>3.1	Definitions</h2> is close to requirement LR2_payload with distance 1.08
# Section <h2>3.1	Definitions</h2> is close to requirement LR2_payload with distance 1.07
# Section <h2>3.1	Definitions</h2> is close to requirement LR2_payload with distance 1.05
# Section <h2>3.2	Abbreviations</h2> is close to requirement LR2_payload with distance 1.02
# Section <h2>3.2	Abbreviations</h2> is close to requirement LR2_payload with distance 1.08
# Section <h2>3.2	Abbreviations</h2> is close to requirement LR2_payload with distance 1.08
# Section <h2>3.2	Abbreviations</h2> is close to requirement LR2_payload with distance 1.05
# Section <h2>4.1	General concepts</h2> is close to requirement LR2_payload with distance 1.02
# Section <h2>4.1	General concepts</h2> is close to requirement LR2_payload with distance 1.12
# Section <h2>4.1	General concepts</h2> is close to requirement LR2_payload with distance 1.10
# Section <h2>4.1	General concepts</h2> is close to requirement LR2_payload with distance 1.07
# Section <h2>5.13	Support for Edge Computing</h2> is close to requirement LR2_payload with distance 1.01
# Section <h2>5.13	Support for Edge Computing</h2> is close to requirement LR2_payload with distance 1.11
# Section <h2>5.13	Support for Edge Computing</h2> is close to requirement LR2_payload with distance 1.07
# Section <h2>5.13	Support for Edge Computing</h2> is close to requirement LR2_payload with distance 1.04
# Section <h5>5.31.7.2.4	Paging for extended DRX for RRC_INACTIVE in NR connected to 5GC</h5> is close to requirement LR2_payload with distance 1.04
# Section <h5>5.31.7.2.4	Paging for extended DRX for RRC_INACTIVE in NR connected to 5GC</h5> is close to requirement LR2_payload with distance 1.12
# Section <h5>5.31.7.2.4	Paging for extended DRX for RRC_INACTIVE in NR connected to 5GC</h5> is close to requirement LR2_payload with distance 1.07
# Section <h5>5.31.7.2.4	Paging for extended DRX for RRC_INACTIVE in NR connected to 5GC</h5> is close to requirement LR2_payload with distance 1.04
# Section <h3>5.31.8	High latency communication</h3> is close to requirement LR2_payload with distance 0.99
# Section <h3>5.31.8	High latency communication</h3> is close to requirement LR2_payload with distance 1.10
# Section <h3>5.31.8	High latency communication</h3> is close to requirement LR2_payload with distance 1.05
# Section <h3>5.31.8	High latency communication</h3> is close to requirement LR2_payload with distance 1.02
# Section <h3>5.33.1	General</h3> is close to requirement LR2_payload with distance 1.05
# Section <h3>5.33.1	General</h3> is close to requirement LR2_payload with distance 1.11
# Section <h3>5.33.1	General</h3> is close to requirement LR2_payload with distance 1.10
# Section <h3>5.33.1	General</h3> is close to requirement LR2_payload with distance 1.08
# Section <h3>5.37.1	General</h3> is close to requirement LR2_payload with distance 1.01
# Section <h3>5.37.1	General</h3> is close to requirement LR2_payload with distance 1.12
# Section <h3>5.37.1	General</h3> is close to requirement LR2_payload with distance 1.04
# Section <h3>5.37.1	General</h3> is close to requirement LR2_payload with distance 1.01
# Section <h4>5.37.3.1	General</h4> is close to requirement LR2_payload with distance 1.05
# Section <h4>5.37.3.1	General</h4> is close to requirement LR2_payload with distance 1.15
# Section <h4>5.37.3.1	General</h4> is close to requirement LR2_payload with distance 1.11
# Section <h4>5.37.3.1	General</h4> is close to requirement LR2_payload with distance 1.09
# Section <h3>5.37.6	UL/DL policy control based on round-trip latency requirement</h3> is close to requirement LR2_payload with distance 0.99
# Section <h3>5.37.6	UL/DL policy control based on round-trip latency requirement</h3> is close to requirement LR2_payload with distance 1.12
# Section <h3>5.37.6	UL/DL policy control based on round-trip latency requirement</h3> is close to requirement LR2_payload with distance 1.05
# Section <h3>5.37.6	UL/DL policy control based on round-trip latency requirement</h3> is close to requirement LR2_payload with distance 1.02
# Section <h4>5.43.3.1	General</h4> is close to requirement LR2_payload with distance 1.03
# Section <h4>5.43.3.1	General</h4> is close to requirement LR2_payload with distance 1.13
# Section <h4>5.43.3.1	General</h4> is close to requirement LR2_payload with distance 1.10
# Section <h4>5.43.3.1	General</h4> is close to requirement LR2_payload with distance 1.07
# Section <h3>6.2.3	UPF</h3> is close to requirement LR2_payload with distance 1.00
# Section <h3>6.2.3	UPF</h3> is close to requirement LR2_payload with distance 1.10
# Section <h3>6.2.3	UPF</h3> is close to requirement LR2_payload with distance 1.09
# Section <h3>6.2.3	UPF</h3> is close to requirement LR2_payload with distance 1.07
# Section <h1>M.1	Mapping of the parameters between 5GS and TSN UNI</h1> is close to requirement LR2_payload with distance 0.99
# Section <h1>M.1	Mapping of the parameters between 5GS and TSN UNI</h1> is close to requirement LR2_payload with distance 1.08
# Section <h1>M.1	Mapping of the parameters between 5GS and TSN UNI</h1> is close to requirement LR2_payload with distance 1.06
# Section <h1>M.1	Mapping of the parameters between 5GS and TSN UNI</h1> is close to requirement LR2_payload with distance 1.05
# Section <h4>4.8.2.2b	Network Triggered Connection Resume in RRC_INACTIVE with CN based MT communication handling</h4> is close to requirement LR2_payload with distance 1.03
# Section <h4>4.8.2.2b	Network Triggered Connection Resume in RRC_INACTIVE with CN based MT communication handling</h4> is close to requirement LR2_payload with distance 1.09
# Section <h4>4.8.2.2b	Network Triggered Connection Resume in RRC_INACTIVE with CN based MT communication handling</h4> is close to requirement LR2_payload with distance 1.09
# Section <h4>4.8.2.2b	Network Triggered Connection Resume in RRC_INACTIVE with CN based MT communication handling</h4> is close to requirement LR2_payload with distance 1.06
# Section <h5>4.15.3.2.3b	Specific NEF service operations information flow for loss of connectivity and UE reachability</h5> is close to requirement LR2_payload with distance 1.03
# Section <h5>4.15.3.2.3b	Specific NEF service operations information flow for loss of connectivity and UE reachability</h5> is close to requirement LR2_payload with distance 1.09
# Section <h5>4.15.3.2.3b	Specific NEF service operations information flow for loss of connectivity and UE reachability</h5> is close to requirement LR2_payload with distance 1.07
# Section <h5>4.15.3.2.3b	Specific NEF service operations information flow for loss of connectivity and UE reachability</h5> is close to requirement LR2_payload with distance 1.05
# Section <h5>4.15.3.2.5	Information flow for downlink data delivery status with SMF buffering</h5> is close to requirement LR2_payload with distance 1.01
# Section <h5>4.15.3.2.5	Information flow for downlink data delivery status with SMF buffering</h5> is close to requirement LR2_payload with distance 1.10
# Section <h5>4.15.3.2.5	Information flow for downlink data delivery status with SMF buffering</h5> is close to requirement LR2_payload with distance 1.10
# Section <h5>4.15.3.2.5	Information flow for downlink data delivery status with SMF buffering</h5> is close to requirement LR2_payload with distance 1.07
# Section <h4>4.15.6.3a	Network Configuration parameters</h4> is close to requirement LR2_payload with distance 1.01
# Section <h4>4.15.6.3a	Network Configuration parameters</h4> is close to requirement LR2_payload with distance 1.11
# Section <h4>4.15.6.3a	Network Configuration parameters</h4> is close to requirement LR2_payload with distance 1.06
# Section <h4>4.15.6.3a	Network Configuration parameters</h4> is close to requirement LR2_payload with distance 1.04
# Section <h4>4.15.6.6	Setting up an AF session with required QoS procedure</h4> is close to requirement LR2_payload with distance 1.03
# Section <h4>4.15.6.6	Setting up an AF session with required QoS procedure</h4> is close to requirement LR2_payload with distance 1.10
# Section <h4>4.15.6.6	Setting up an AF session with required QoS procedure</h4> is close to requirement LR2_payload with distance 1.11
# Section <h4>4.15.6.6	Setting up an AF session with required QoS procedure</h4> is close to requirement LR2_payload with distance 1.08
# Section <h1>F.4	5GS interworking with TSN deployed in the transport network</h1> is close to requirement LR2_payload with distance 1.02
# Section <h1>F.4	5GS interworking with TSN deployed in the transport network</h1> is close to requirement LR2_payload with distance 1.10
# Section <h1>F.4	5GS interworking with TSN deployed in the transport network</h1> is close to requirement LR2_payload with distance 1.10
# Section <h1>F.4	5GS interworking with TSN deployed in the transport network</h1> is close to requirement LR2_payload with distance 1.07
# Section <h4>6.1.3.22	AF session with required QoS</h4> is close to requirement LR2_payload with distance 1.01
# Section <h4>6.1.3.22	AF session with required QoS</h4> is close to requirement LR2_payload with distance 1.11
# Section <h4>6.1.3.22	AF session with required QoS</h4> is close to requirement LR2_payload with distance 1.09
# Section <h4>6.1.3.22	AF session with required QoS</h4> is close to requirement LR2_payload with distance 1.07
# Section <h4>6.1.3.23b	Support of IETF Deterministic Networking</h4> is close to requirement LR2_payload with distance 1.00
# Section <h4>6.1.3.23b	Support of IETF Deterministic Networking</h4> is close to requirement LR2_payload with distance 1.09
# Section <h4>6.1.3.23b	Support of IETF Deterministic Networking</h4> is close to requirement LR2_payload with distance 1.06
# Section <h4>6.1.3.23b	Support of IETF Deterministic Networking</h4> is close to requirement LR2_payload with distance 1.04
# Section <h5>6.1.3.27.2	UL/DL policy control based on round-trip latency requirement</h5> is close to requirement LR2_payload with distance 0.99
# Section <h5>6.1.3.27.2	UL/DL policy control based on round-trip latency requirement</h5> is close to requirement LR2_payload with distance 1.13
# Section <h5>6.1.3.27.2	UL/DL policy control based on round-trip latency requirement</h5> is close to requirement LR2_payload with distance 1.04
# Section <h5>6.1.3.27.2	UL/DL policy control based on round-trip latency requirement</h5> is close to requirement LR2_payload with distance 1.01
# Section <h2>4.1	General</h2> is close to requirement LR2_payload with distance 1.05
# Section <h2>4.1	General</h2> is close to requirement LR2_payload with distance 1.16
# Section <h2>4.1	General</h2> is close to requirement LR2_payload with distance 1.11
# Section <h2>4.1	General</h2> is close to requirement LR2_payload with distance 1.08
# Section <h3>6.3.6	Edge Relocation Considering User Plane Latency Requirement</h3> is close to requirement LR2_payload with distance 1.02
# Section <h3>6.3.6	Edge Relocation Considering User Plane Latency Requirement</h3> is close to requirement LR2_payload with distance 1.15
# Section <h3>6.3.6	Edge Relocation Considering User Plane Latency Requirement</h3> is close to requirement LR2_payload with distance 1.07
# Section <h3>6.3.6	Edge Relocation Considering User Plane Latency Requirement</h3> is close to requirement LR2_payload with distance 1.02
# Section <h3>6.4.1	General</h3> is close to requirement LR2_payload with distance 1.04
# Section <h3>6.4.1	General</h3> is close to requirement LR2_payload with distance 1.17
# Section <h3>6.4.1	General</h3> is close to requirement LR2_payload with distance 1.11
# Section <h3>6.4.1	General</h3> is close to requirement LR2_payload with distance 1.10
# Section <h4>5.4.3.3	Priority Level</h4> is close to requirement LR3_configuration with distance 1.06
# Section <h4>5.4.3.3	Priority Level</h4> is close to requirement LR3_configuration with distance 1.08
# Section <h4>5.4.3.3	Priority Level</h4> is close to requirement LR3_configuration with distance 1.07
# Section <h4>5.4.3.3	Priority Level</h4> is close to requirement LR3_configuration with distance 1.14
# Section <h4>9.7.2.1	Data transmission quality measurement </h4> is close to requirement LR3_configuration with distance 1.07
# Section <h4>9.7.2.1	Data transmission quality measurement </h4> is close to requirement LR3_configuration with distance 1.06
# Section <h4>9.7.2.1	Data transmission quality measurement </h4> is close to requirement LR3_configuration with distance 1.08
# Section <h4>9.7.2.1	Data transmission quality measurement </h4> is close to requirement LR3_configuration with distance 1.08
# Section <h4>9.7.2.3	Data transmission quality measurement reported by SEALDD client</h4> is close to requirement LR3_configuration with distance 1.08
# Section <h4>9.7.2.3	Data transmission quality measurement reported by SEALDD client</h4> is close to requirement LR3_configuration with distance 1.07
# Section <h4>9.7.2.3	Data transmission quality measurement reported by SEALDD client</h4> is close to requirement LR3_configuration with distance 1.09
# Section <h4>9.7.2.3	Data transmission quality measurement reported by SEALDD client</h4> is close to requirement LR3_configuration with distance 1.09
# Section <h4>14.3.5.1	General</h4> is close to requirement LR3_configuration with distance 1.04
# Section <h4>14.3.5.1	General</h4> is close to requirement LR3_configuration with distance 1.06
# Section <h4>14.3.5.1	General</h4> is close to requirement LR3_configuration with distance 1.04
# Section <h4>14.3.5.1	General</h4> is close to requirement LR3_configuration with distance 1.12
# Section <h5>14.3.5.2.2	Procedure for a group of UEs</h5> is close to requirement LR3_configuration with distance 1.05
# Section <h5>14.3.5.2.2	Procedure for a group of UEs</h5> is close to requirement LR3_configuration with distance 1.07
# Section <h5>14.3.5.2.2	Procedure for a group of UEs</h5> is close to requirement LR3_configuration with distance 1.05
# Section <h5>14.3.5.2.2	Procedure for a group of UEs</h5> is close to requirement LR3_configuration with distance 1.07
# Section <h4>14.3.7.2	TSC stream availability discovery procedure</h4> is close to requirement LR3_configuration with distance 1.04
# Section <h4>14.3.7.2	TSC stream availability discovery procedure</h4> is close to requirement LR3_configuration with distance 1.06
# Section <h4>14.3.7.2	TSC stream availability discovery procedure</h4> is close to requirement LR3_configuration with distance 1.06
# Section <h4>14.3.7.2	TSC stream availability discovery procedure</h4> is close to requirement LR3_configuration with distance 1.09
# Section <h5>14.3.9.2.1	Procedure triggered by correlated source and destination requests</h5> is close to requirement LR3_configuration with distance 1.03
# Section <h5>14.3.9.2.1	Procedure triggered by correlated source and destination requests</h5> is close to requirement LR3_configuration with distance 1.05
# Section <h5>14.3.9.2.1	Procedure triggered by correlated source and destination requests</h5> is close to requirement LR3_configuration with distance 1.04
# Section <h5>14.3.9.2.1	Procedure triggered by correlated source and destination requests</h5> is close to requirement LR3_configuration with distance 1.08
# Section <h5>14.3.12.4.3	Network parameter coordination procedure</h5> is close to requirement LR3_configuration with distance 0.98
# Section <h5>14.3.12.4.3	Network parameter coordination procedure</h5> is close to requirement LR3_configuration with distance 1.01
# Section <h5>14.3.12.4.3	Network parameter coordination procedure</h5> is close to requirement LR3_configuration with distance 0.99
# Section <h5>14.3.12.4.3	Network parameter coordination procedure</h5> is close to requirement LR3_configuration with distance 1.05
# Section <h4>9.5.2.2	Network slice optimization based on VAL server policy</h4> is close to requirement LR3_configuration with distance 1.04
# Section <h4>9.5.2.2	Network slice optimization based on VAL server policy</h4> is close to requirement LR3_configuration with distance 1.04
# Section <h4>9.5.2.2	Network slice optimization based on VAL server policy</h4> is close to requirement LR3_configuration with distance 1.04
# Section <h4>9.5.2.2	Network slice optimization based on VAL server policy</h4> is close to requirement LR3_configuration with distance 1.09
# Section <h4>9.11.2.1	Procedure for VAL server-triggered and network-based network slice adaptation for VAL application</h4> is close to requirement LR3_configuration with distance 1.03
# Section <h4>9.11.2.1	Procedure for VAL server-triggered and network-based network slice adaptation for VAL application</h4> is close to requirement LR3_configuration with distance 1.04
# Section <h4>9.11.2.1	Procedure for VAL server-triggered and network-based network slice adaptation for VAL application</h4> is close to requirement LR3_configuration with distance 1.03
# Section <h4>9.11.2.1	Procedure for VAL server-triggered and network-based network slice adaptation for VAL application</h4> is close to requirement LR3_configuration with distance 1.10
# Section <h4>9.17.2.1	Network Slice Information delivery request</h4> is close to requirement LR3_configuration with distance 1.05
# Section <h4>9.17.2.1	Network Slice Information delivery request</h4> is close to requirement LR3_configuration with distance 1.05
# Section <h4>9.17.2.1	Network Slice Information delivery request</h4> is close to requirement LR3_configuration with distance 1.04
# Section <h4>9.17.2.1	Network Slice Information delivery request</h4> is close to requirement LR3_configuration with distance 1.12
# Section <h2>3.1	Definitions</h2> is close to requirement LR3_configuration with distance 1.02
# Section <h2>3.1	Definitions</h2> is close to requirement LR3_configuration with distance 1.05
# Section <h2>3.1	Definitions</h2> is close to requirement LR3_configuration with distance 1.03
# Section <h2>3.1	Definitions</h2> is close to requirement LR3_configuration with distance 1.08
# Section <h2>3.2	Abbreviations</h2> is close to requirement LR3_configuration with distance 1.02
# Section <h2>3.2	Abbreviations</h2> is close to requirement LR3_configuration with distance 1.05
# Section <h2>3.2	Abbreviations</h2> is close to requirement LR3_configuration with distance 1.04
# Section <h2>3.2	Abbreviations</h2> is close to requirement LR3_configuration with distance 1.09
# Section <h2>4.1	General concepts</h2> is close to requirement LR3_configuration with distance 1.03
# Section <h2>4.1	General concepts</h2> is close to requirement LR3_configuration with distance 1.05
# Section <h2>4.1	General concepts</h2> is close to requirement LR3_configuration with distance 1.02
# Section <h2>4.1	General concepts</h2> is close to requirement LR3_configuration with distance 1.11
# Section <h2>5.13	Support for Edge Computing</h2> is close to requirement LR3_configuration with distance 1.00
# Section <h2>5.13	Support for Edge Computing</h2> is close to requirement LR3_configuration with distance 1.00
# Section <h2>5.13	Support for Edge Computing</h2> is close to requirement LR3_configuration with distance 1.00
# Section <h2>5.13	Support for Edge Computing</h2> is close to requirement LR3_configuration with distance 1.07
# Section <h5>5.31.7.2.4	Paging for extended DRX for RRC_INACTIVE in NR connected to 5GC</h5> is close to requirement LR3_configuration with distance 1.03
# Section <h5>5.31.7.2.4	Paging for extended DRX for RRC_INACTIVE in NR connected to 5GC</h5> is close to requirement LR3_configuration with distance 1.05
# Section <h5>5.31.7.2.4	Paging for extended DRX for RRC_INACTIVE in NR connected to 5GC</h5> is close to requirement LR3_configuration with distance 1.03
# Section <h5>5.31.7.2.4	Paging for extended DRX for RRC_INACTIVE in NR connected to 5GC</h5> is close to requirement LR3_configuration with distance 1.06
# Section <h3>5.31.8	High latency communication</h3> is close to requirement LR3_configuration with distance 1.00
# Section <h3>5.31.8	High latency communication</h3> is close to requirement LR3_configuration with distance 1.03
# Section <h3>5.31.8	High latency communication</h3> is close to requirement LR3_configuration with distance 1.01
# Section <h3>5.31.8	High latency communication</h3> is close to requirement LR3_configuration with distance 1.04
# Section <h3>5.33.1	General</h3> is close to requirement LR3_configuration with distance 1.06
# Section <h3>5.33.1	General</h3> is close to requirement LR3_configuration with distance 1.07
# Section <h3>5.33.1	General</h3> is close to requirement LR3_configuration with distance 1.06
# Section <h3>5.33.1	General</h3> is close to requirement LR3_configuration with distance 1.10
# Section <h3>5.37.1	General</h3> is close to requirement LR3_configuration with distance 0.99
# Section <h3>5.37.1	General</h3> is close to requirement LR3_configuration with distance 1.00
# Section <h3>5.37.1	General</h3> is close to requirement LR3_configuration with distance 0.99
# Section <h3>5.37.1	General</h3> is close to requirement LR3_configuration with distance 1.07
# Section <h4>5.37.3.1	General</h4> is close to requirement LR3_configuration with distance 1.05
# Section <h4>5.37.3.1	General</h4> is close to requirement LR3_configuration with distance 1.07
# Section <h4>5.37.3.1	General</h4> is close to requirement LR3_configuration with distance 1.07
# Section <h4>5.37.3.1	General</h4> is close to requirement LR3_configuration with distance 1.07
# Section <h3>5.37.6	UL/DL policy control based on round-trip latency requirement</h3> is close to requirement LR3_configuration with distance 0.98
# Section <h3>5.37.6	UL/DL policy control based on round-trip latency requirement</h3> is close to requirement LR3_configuration with distance 1.04
# Section <h3>5.37.6	UL/DL policy control based on round-trip latency requirement</h3> is close to requirement LR3_configuration with distance 1.02
# Section <h3>5.37.6	UL/DL policy control based on round-trip latency requirement</h3> is close to requirement LR3_configuration with distance 1.06
# Section <h4>5.43.3.1	General</h4> is close to requirement LR3_configuration with distance 1.01
# Section <h4>5.43.3.1	General</h4> is close to requirement LR3_configuration with distance 1.08
# Section <h4>5.43.3.1	General</h4> is close to requirement LR3_configuration with distance 1.06
# Section <h4>5.43.3.1	General</h4> is close to requirement LR3_configuration with distance 1.10
# Section <h3>6.2.3	UPF</h3> is close to requirement LR3_configuration with distance 1.02
# Section <h3>6.2.3	UPF</h3> is close to requirement LR3_configuration with distance 1.07
# Section <h3>6.2.3	UPF</h3> is close to requirement LR3_configuration with distance 1.05
# Section <h3>6.2.3	UPF</h3> is close to requirement LR3_configuration with distance 1.09
# Section <h1>M.1	Mapping of the parameters between 5GS and TSN UNI</h1> is close to requirement LR3_configuration with distance 1.03
# Section <h1>M.1	Mapping of the parameters between 5GS and TSN UNI</h1> is close to requirement LR3_configuration with distance 1.06
# Section <h1>M.1	Mapping of the parameters between 5GS and TSN UNI</h1> is close to requirement LR3_configuration with distance 1.04
# Section <h1>M.1	Mapping of the parameters between 5GS and TSN UNI</h1> is close to requirement LR3_configuration with distance 1.08
# Section <h4>4.8.2.2b	Network Triggered Connection Resume in RRC_INACTIVE with CN based MT communication handling</h4> is close to requirement LR3_configuration with distance 1.03
# Section <h4>4.8.2.2b	Network Triggered Connection Resume in RRC_INACTIVE with CN based MT communication handling</h4> is close to requirement LR3_configuration with distance 1.06
# Section <h4>4.8.2.2b	Network Triggered Connection Resume in RRC_INACTIVE with CN based MT communication handling</h4> is close to requirement LR3_configuration with distance 1.03
# Section <h4>4.8.2.2b	Network Triggered Connection Resume in RRC_INACTIVE with CN based MT communication handling</h4> is close to requirement LR3_configuration with distance 1.04
# Section <h5>4.15.3.2.3b	Specific NEF service operations information flow for loss of connectivity and UE reachability</h5> is close to requirement LR3_configuration with distance 1.05
# Section <h5>4.15.3.2.3b	Specific NEF service operations information flow for loss of connectivity and UE reachability</h5> is close to requirement LR3_configuration with distance 1.07
# Section <h5>4.15.3.2.3b	Specific NEF service operations information flow for loss of connectivity and UE reachability</h5> is close to requirement LR3_configuration with distance 1.06
# Section <h5>4.15.3.2.3b	Specific NEF service operations information flow for loss of connectivity and UE reachability</h5> is close to requirement LR3_configuration with distance 1.07
# Section <h5>4.15.3.2.5	Information flow for downlink data delivery status with SMF buffering</h5> is close to requirement LR3_configuration with distance 1.05
# ...
# Section <h5>14.3.5.2.2	Procedure for a group of UEs</h5> is close to requirement LR4_calculation with distance 1.02
# Section <h5>14.3.5.2.2	Procedure for a group of UEs</h5> is close to requirement LR4_calculation with distance 1.12
# Section <h5>14.3.5.2.2	Procedure for a group of UEs</h5> is close to requirement LR4_calculation with distance 1.09
# Section <h5>14.3.5.2.2	Procedure for a group of UEs</h5> is close to requirement LR4_calculation with distance 1.07
# Section <h4>14.3.7.2	TSC stream availability discovery procedure</h4> is close to requirement LR4_calculation with distance 1.01
# Section <h4>14.3.7.2	TSC stream availability discovery procedure</h4> is close to requirement LR4_calculation with distance 1.12
# Section <h4>14.3.7.2	TSC stream availability discovery procedure</h4> is close to requirement LR4_calculation with distance 1.07
# Section <h4>14.3.7.2	TSC stream availability discovery procedure</h4> is close to requirement LR4_calculation with distance 1.04
# Section <h5>14.3.9.2.1	Procedure triggered by correlated source and destination requests</h5> is close to requirement LR4_calculation with distance 1.02
# Section <h5>14.3.9.2.1	Procedure triggered by correlated source and destination requests</h5> is close to requirement LR4_calculation with distance 1.12
# Section <h5>14.3.9.2.1	Procedure triggered by correlated source and destination requests</h5> is close to requirement LR4_calculation with distance 1.06
# Section <h5>14.3.9.2.1	Procedure triggered by correlated source and destination requests</h5> is close to requirement LR4_calculation with distance 1.04
# Section <h5>14.3.12.4.3	Network parameter coordination procedure</h5> is close to requirement LR4_calculation with distance 1.00
# Section <h5>14.3.12.4.3	Network parameter coordination procedure</h5> is close to requirement LR4_calculation with distance 1.10
# Section <h5>14.3.12.4.3	Network parameter coordination procedure</h5> is close to requirement LR4_calculation with distance 1.03
# Section <h5>14.3.12.4.3	Network parameter coordination procedure</h5> is close to requirement LR4_calculation with distance 1.01
# Section <h4>9.5.2.2	Network slice optimization based on VAL server policy</h4> is close to requirement LR4_calculation with distance 1.01
# Section <h4>9.5.2.2	Network slice optimization based on VAL server policy</h4> is close to requirement LR4_calculation with distance 1.12
# Section <h4>9.5.2.2	Network slice optimization based on VAL server policy</h4> is close to requirement LR4_calculation with distance 1.09
# Section <h4>9.5.2.2	Network slice optimization based on VAL server policy</h4> is close to requirement LR4_calculation with distance 1.06
# Section <h4>9.11.2.1	Procedure for VAL server-triggered and network-based network slice adaptation for VAL application</h4> is close to requirement LR4_calculation with distance 1.00
# Section <h4>9.11.2.1	Procedure for VAL server-triggered and network-based network slice adaptation for VAL application</h4> is close to requirement LR4_calculation with distance 1.13
# Section <h4>9.11.2.1	Procedure for VAL server-triggered and network-based network slice adaptation for VAL application</h4> is close to requirement LR4_calculation with distance 1.10
# Section <h4>9.11.2.1	Procedure for VAL server-triggered and network-based network slice adaptation for VAL application</h4> is close to requirement LR4_calculation with distance 1.05
# Section <h4>9.17.2.1	Network Slice Information delivery request</h4> is close to requirement LR4_calculation with distance 1.01
# Section <h4>9.17.2.1	Network Slice Information delivery request</h4> is close to requirement LR4_calculation with distance 1.13
# Section <h4>9.17.2.1	Network Slice Information delivery request</h4> is close to requirement LR4_calculation with distance 1.10
# Section <h4>9.17.2.1	Network Slice Information delivery request</h4> is close to requirement LR4_calculation with distance 1.05
# Section <h2>3.1	Definitions</h2> is close to requirement LR4_calculation with distance 1.00
# Section <h2>3.1	Definitions</h2> is close to requirement LR4_calculation with distance 1.08
# Section <h2>3.1	Definitions</h2> is close to requirement LR4_calculation with distance 1.07
# Section <h2>3.1	Definitions</h2> is close to requirement LR4_calculation with distance 1.05
# Section <h2>3.2	Abbreviations</h2> is close to requirement LR4_calculation with distance 1.02
# Section <h2>3.2	Abbreviations</h2> is close to requirement LR4_calculation with distance 1.08
# Section <h2>3.2	Abbreviations</h2> is close to requirement LR4_calculation with distance 1.08
# Section <h2>3.2	Abbreviations</h2> is close to requirement LR4_calculation with distance 1.05
# Section <h2>4.1	General concepts</h2> is close to requirement LR4_calculation with distance 1.02
# Section <h2>4.1	General concepts</h2> is close to requirement LR4_calculation with distance 1.12
# Section <h2>4.1	General concepts</h2> is close to requirement LR4_calculation with distance 1.10
# Section <h2>4.1	General concepts</h2> is close to requirement LR4_calculation with distance 1.07
# Section <h2>5.13	Support for Edge Computing</h2> is close to requirement LR4_calculation with distance 1.01
# Section <h2>5.13	Support for Edge Computing</h2> is close to requirement LR4_calculation with distance 1.11
# Section <h2>5.13	Support for Edge Computing</h2> is close to requirement LR4_calculation with distance 1.07
# Section <h2>5.13	Support for Edge Computing</h2> is close to requirement LR4_calculation with distance 1.04
# Section <h5>5.31.7.2.4	Paging for extended DRX for RRC_INACTIVE in NR connected to 5GC</h5> is close to requirement LR4_calculation with distance 1.04
# Section <h5>5.31.7.2.4	Paging for extended DRX for RRC_INACTIVE in NR connected to 5GC</h5> is close to requirement LR4_calculation with distance 1.12
# Section <h5>5.31.7.2.4	Paging for extended DRX for RRC_INACTIVE in NR connected to 5GC</h5> is close to requirement LR4_calculation with distance 1.07
# Section <h5>5.31.7.2.4	Paging for extended DRX for RRC_INACTIVE in NR connected to 5GC</h5> is close to requirement LR4_calculation with distance 1.04
# Section <h3>5.31.8	High latency communication</h3> is close to requirement LR4_calculation with distance 0.99
# Section <h3>5.31.8	High latency communication</h3> is close to requirement LR4_calculation with distance 1.10
# Section <h3>5.31.8	High latency communication</h3> is close to requirement LR4_calculation with distance 1.05
# Section <h3>5.31.8	High latency communication</h3> is close to requirement LR4_calculation with distance 1.02
# Section <h3>5.33.1	General</h3> is close to requirement LR4_calculation with distance 1.05
# Section <h3>5.33.1	General</h3> is close to requirement LR4_calculation with distance 1.11
# Section <h3>5.33.1	General</h3> is close to requirement LR4_calculation with distance 1.10
# Section <h3>5.33.1	General</h3> is close to requirement LR4_calculation with distance 1.08
# Section <h3>5.37.1	General</h3> is close to requirement LR4_calculation with distance 1.01
# Section <h3>5.37.1	General</h3> is close to requirement LR4_calculation with distance 1.12
# Section <h3>5.37.1	General</h3> is close to requirement LR4_calculation with distance 1.04
# Section <h3>5.37.1	General</h3> is close to requirement LR4_calculation with distance 1.01
# Section <h4>5.37.3.1	General</h4> is close to requirement LR4_calculation with distance 1.05
# Section <h4>5.37.3.1	General</h4> is close to requirement LR4_calculation with distance 1.15
# Section <h4>5.37.3.1	General</h4> is close to requirement LR4_calculation with distance 1.11
# Section <h4>5.37.3.1	General</h4> is close to requirement LR4_calculation with distance 1.09
# Section <h3>5.37.6	UL/DL policy control based on round-trip latency requirement</h3> is close to requirement LR4_calculation with distance 0.99
# Section <h3>5.37.6	UL/DL policy control based on round-trip latency requirement</h3> is close to requirement LR4_calculation with distance 1.12
# Section <h3>5.37.6	UL/DL policy control based on round-trip latency requirement</h3> is close to requirement LR4_calculation with distance 1.05
# Section <h3>5.37.6	UL/DL policy control based on round-trip latency requirement</h3> is close to requirement LR4_calculation with distance 1.02
# Section <h4>5.43.3.1	General</h4> is close to requirement LR4_calculation with distance 1.03
# Section <h4>5.43.3.1	General</h4> is close to requirement LR4_calculation with distance 1.13
# Section <h4>5.43.3.1	General</h4> is close to requirement LR4_calculation with distance 1.10
# Section <h4>5.43.3.1	General</h4> is close to requirement LR4_calculation with distance 1.07
# Section <h3>6.2.3	UPF</h3> is close to requirement LR4_calculation with distance 1.00
# Section <h3>6.2.3	UPF</h3> is close to requirement LR4_calculation with distance 1.10
# Section <h3>6.2.3	UPF</h3> is close to requirement LR4_calculation with distance 1.09
# Section <h3>6.2.3	UPF</h3> is close to requirement LR4_calculation with distance 1.07
# Section <h1>M.1	Mapping of the parameters between 5GS and TSN UNI</h1> is close to requirement LR4_calculation with distance 0.99
# Section <h1>M.1	Mapping of the parameters between 5GS and TSN UNI</h1> is close to requirement LR4_calculation with distance 1.08
# Section <h1>M.1	Mapping of the parameters between 5GS and TSN UNI</h1> is close to requirement LR4_calculation with distance 1.06
# Section <h1>M.1	Mapping of the parameters between 5GS and TSN UNI</h1> is close to requirement LR4_calculation with distance 1.05
# Section <h4>4.8.2.2b	Network Triggered Connection Resume in RRC_INACTIVE with CN based MT communication handling</h4> is close to requirement LR4_calculation with distance 1.03
# Section <h4>4.8.2.2b	Network Triggered Connection Resume in RRC_INACTIVE with CN based MT communication handling</h4> is close to requirement LR4_calculation with distance 1.09
# Section <h4>4.8.2.2b	Network Triggered Connection Resume in RRC_INACTIVE with CN based MT communication handling</h4> is close to requirement LR4_calculation with distance 1.09
# Section <h4>4.8.2.2b	Network Triggered Connection Resume in RRC_INACTIVE with CN based MT communication handling</h4> is close to requirement LR4_calculation with distance 1.06
# Section <h5>4.15.3.2.3b	Specific NEF service operations information flow for loss of connectivity and UE reachability</h5> is close to requirement LR4_calculation with distance 1.03
# Section <h5>4.15.3.2.3b	Specific NEF service operations information flow for loss of connectivity and UE reachability</h5> is close to requirement LR4_calculation with distance 1.09
# Section <h5>4.15.3.2.3b	Specific NEF service operations information flow for loss of connectivity and UE reachability</h5> is close to requirement LR4_calculation with distance 1.07
# Section <h5>4.15.3.2.3b	Specific NEF service operations information flow for loss of connectivity and UE reachability</h5> is close to requirement LR4_calculation with distance 1.05
# Section <h5>4.15.3.2.5	Information flow for downlink data delivery status with SMF buffering</h5> is close to requirement LR4_calculation with distance 1.01
# Section <h5>4.15.3.2.5	Information flow for downlink data delivery status with SMF buffering</h5> is close to requirement LR4_calculation with distance 1.10
# Section <h5>4.15.3.2.5	Information flow for downlink data delivery status with SMF buffering</h5> is close to requirement LR4_calculation with distance 1.10
# Section <h5>4.15.3.2.5	Information flow for downlink data delivery status with SMF buffering</h5> is close to requirement LR4_calculation with distance 1.07
# Section <h4>4.15.6.3a	Network Configuration parameters</h4> is close to requirement LR4_calculation with distance 1.01
# Section <h4>4.15.6.3a	Network Configuration parameters</h4> is close to requirement LR4_calculation with distance 1.11
# Section <h4>4.15.6.3a	Network Configuration parameters</h4> is close to requirement LR4_calculation with distance 1.06
# Section <h4>4.15.6.3a	Network Configuration parameters</h4> is close to requirement LR4_calculation with distance 1.04
# Section <h4>4.15.6.6	Setting up an AF session with required QoS procedure</h4> is close to requirement LR4_calculation with distance 1.03
# Section <h4>4.15.6.6	Setting up an AF session with required QoS procedure</h4> is close to requirement LR4_calculation with distance 1.10
# Section <h4>4.15.6.6	Setting up an AF session with required QoS procedure</h4> is close to requirement LR4_calculation with distance 1.11
# Section <h4>4.15.6.6	Setting up an AF session with required QoS procedure</h4> is close to requirement LR4_calculation with distance 1.08
# Section <h1>F.4	5GS interworking with TSN deployed in the transport network</h1> is close to requirement LR4_calculation with distance 1.02
# Section <h1>F.4	5GS interworking with TSN deployed in the transport network</h1> is close to requirement LR4_calculation with distance 1.10
# Section <h1>F.4	5GS interworking with TSN deployed in the transport network</h1> is close to requirement LR4_calculation with distance 1.10
# Section <h1>F.4	5GS interworking with TSN deployed in the transport network</h1> is close to requirement LR4_calculation with distance 1.07
# Section <h4>6.1.3.22	AF session with required QoS</h4> is close to requirement LR4_calculation with distance 1.01
# Section <h4>6.1.3.22	AF session with required QoS</h4> is close to requirement LR4_calculation with distance 1.11
# Section <h4>6.1.3.22	AF session with required QoS</h4> is close to requirement LR4_calculation with distance 1.09
# Section <h4>6.1.3.22	AF session with required QoS</h4> is close to requirement LR4_calculation with distance 1.07
# Section <h4>6.1.3.23b	Support of IETF Deterministic Networking</h4> is close to requirement LR4_calculation with distance 1.00
# Section <h4>6.1.3.23b	Support of IETF Deterministic Networking</h4> is close to requirement LR4_calculation with distance 1.09
# Section <h4>6.1.3.23b	Support of IETF Deterministic Networking</h4> is close to requirement LR4_calculation with distance 1.06
# Section <h4>6.1.3.23b	Support of IETF Deterministic Networking</h4> is close to requirement LR4_calculation with distance 1.04
# Section <h5>6.1.3.27.2	UL/DL policy control based on round-trip latency requirement</h5> is close to requirement LR4_calculation with distance 0.99
# Section <h5>6.1.3.27.2	UL/DL policy control based on round-trip latency requirement</h5> is close to requirement LR4_calculation with distance 1.13
# Section <h5>6.1.3.27.2	UL/DL policy control based on round-trip latency requirement</h5> is close to requirement LR4_calculation with distance 1.04
# Section <h5>6.1.3.27.2	UL/DL policy control based on round-trip latency requirement</h5> is close to requirement LR4_calculation with distance 1.01
# Section <h2>4.1	General</h2> is close to requirement LR4_calculation with distance 1.05
# Section <h2>4.1	General</h2> is close to requirement LR4_calculation with distance 1.16
# Section <h2>4.1	General</h2> is close to requirement LR4_calculation with distance 1.11
# Section <h2>4.1	General</h2> is close to requirement LR4_calculation with distance 1.08
# Section <h3>6.3.6	Edge Relocation Considering User Plane Latency Requirement</h3> is close to requirement LR4_calculation with distance 1.02
# Section <h3>6.3.6	Edge Relocation Considering User Plane Latency Requirement</h3> is close to requirement LR4_calculation with distance 1.15
# Section <h3>6.3.6	Edge Relocation Considering User Plane Latency Requirement</h3> is close to requirement LR4_calculation with distance 1.07
# Section <h3>6.3.6	Edge Relocation Considering User Plane Latency Requirement</h3> is close to requirement LR4_calculation with distance 1.02
# Section <h3>6.4.1	General</h3> is close to requirement LR4_calculation with distance 1.04
# Section <h3>6.4.1	General</h3> is close to requirement LR4_calculation with distance 1.17
# Section <h3>6.4.1	General</h3> is close to requirement LR4_calculation with distance 1.11
# Section <h3>6.4.1	General</h3> is close to requirement LR4_calculation with distance 1.10

# %%
print(len(lstDist))
print(len(lstRelevant))
print(len(lstEmbeddingsReq))
# Out:
# 576
# 36
# 16

# %%
# average the distance in dfOutput per section, document and requirement
dfOutput["Distance"] = dfOutput["Distance"].astype(float)
dfGrouped = dfOutput.groupby(["Section", "Document", "Requirement", "Content"])

#convert dfGrouped to a dataframe
dfGrouped = dfGrouped.agg({"Distance": "mean"}).reset_index()

dfGrouped.to_excel("./output_reqs_distances_w15__23_A3.xlsx", index=False)

# %% [markdown]
# ## Step 4: Find if it is a new requirement
#
# In the last step, we look at the distances and then we find if they too far away from the existing requirements. If they are, we can consider them as new requirements.
